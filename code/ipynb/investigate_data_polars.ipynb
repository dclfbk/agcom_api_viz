# %%
import polars as pl
import os
import warnings
import json
warnings.filterwarnings('ignore')
from datetime import datetime
import datetime as dt

# %%
data = pl.read_parquet(".." + os.sep + ".." + os.sep + "docs"  + os.sep +  "data" + os.sep + "agcomdata.parquet")

# %%
data.columns
# Out:
# ['channel',
#  'program',
#  'day',
#  'lastname',
#  'name',
#  'affiliation',
#  'topic',
#  'duration',
#  'kind',
#  '__index_level_0__']

# %%
data.select('channel').unique().to_series().to_list()
# Out:
# ['RAI 2',
#  'CANALE 5',
#  'ITALIA 1',
#  'CIELO',
#  'NOVE',
#  'RETE 4',
#  'RAINEWS',
#  'Mediaset TgCom 24',
#  'Rai Radio2',
#  'LA7',
#  'RTL102.5',
#  'LA7D',
#  'RAI 3',
#  'RAI 1',
#  'Rai Radio1',
#  'SKY TG24',
#  'SKY TG 24 CAN. 50',
#  'TV8',
#  'Rai Radio3']

# %%
data.select('program').unique().to_series().to_list()
# Out:
# ['OGNI MATTINA',
#  'TG1 DIRETTA: GIORNATA INTERNAZIONALE DELLA DONNA',
#  'SKY TG24 SPECIALE - BERLINO 89',
#  'INFERNO SULLA TERRA',
#  "TG1: DAVID SASSOLI - L'OMAGGIO DEL PARLAMENTO EUROPEO",
#  'CLIP: CATANIA TRA I COMUNI AL VOTO IL PROSSIMO 10 GIUGNO 2018',
#  'TG SPORT',
#  'I FATTI VOSTRI SPECIALE (RETE)',
#  'IL MIX DELLE CINQUE',
#  "TG5 - L'ARCA DI NOE'",
#  'QUARTA REPUBBLICA AL VOTO (TGCOM24)',
#  "TG1 - L'INCARICO",
#  'NEWS ROOM ITALIA - SPECIALE LA SFIDA DI CONTE',
#  'TG5 SPECIALE - REBUS COLLE',
#  'IO E TE DI NOTTE',
#  'RAI NEWS - DIARIO DELLA CRISI',
#  'RAI QUIRINALE E TG1: IL GIORNO DELLA MEMORIA',
#  'MEDIASET TGCOM24 - SPECIALE PIAZZA FONTANA, STRAGE DI STATO',
#  'LA VITA IN DIRETTA ESTATE (RETE)',
#  'ANTICAMERA CON VISTA (TESTATA)',
#  'RAI NEWS24 - IL TG DELLE 12.00',
#  'CLIP: MESSAGGIO DI FINE ANNO DEL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA',
#  'RAI NEWS 24 - FOCUS 24 SPECIALE',
#  'QUARTA REPUBBLICA - VINCITORI E VINTI',
#  'SKY TG24 - BUONGIORNO TELEGIORNALE',
#  'ANTEPRIMA #CARTABIANCA (RETE)',
#  'RAI EDUCATIONAL - TV TALK EXTRA',
#  'SKY TG24 - LIVE IN COURMAYEUR',
#  'SKY TG24 - SKY IN ITALIA',
#  'SPECIALE #CARTABIANCA (RETE)',
#  'SPECIALE FRONTIERE',
#  'VUOI SCOMMETTERE?',
#  'PRES. ACCORDI & DISACCORDI (TESTATA)',
#  'RAI NEWS IN DIRETTA (L.I.S.)',
#  'STASERA ITALIA',
#  'SKY TG24 - VOTO COMUNE',
#  'TGR - BELLITALIA',
#  'GUSTIBUS',
#  'UNO MATTINA IN FAMIGLIA (RETE)',
#  'TG2 - REGATA STORICA DI VENEZIA 2021 (TESTATA)',
#  '100 AUGURI ALBERTO',
#  'VENTI20... QUASI 21',
#  'PROPAGANDA THE MOVIE #UNESTATEFA (TESTATA)',
#  'STASERA ITALIA SPECIALE ELEZIONI (VN)',
#  'GRAND PRIX - FORMULA E',
#  'IN VACANZA CON VIVA RAI 2!',
#  'HIT THE ROAD MAN',
#  'RAI PARLAMENTO - PUNTO EUROPA',
#  'MAREMMA FELIX',
#  'RAI NEWS24 SPECIALE: LE CARTE IN REGOLA - PIERSANTI MATTARELLA',
#  'STUDIO APERTO LIVE (TGCOM24)',
#  'STASERA ITALIA WEEKEND',
#  'TG5 SPECIALE ELEZIONI',
#  'RAI EDUCATIONAL - TV TALK ANTEPRIMA',
#  'BELVE AFTER',
#  "TAGADA' PRIMA PAGINA (TESTATA)",
#  "SKY TG4 SPECIALE - GENOVA CITTA' SPEZZATA",
#  "RAI NEWS24 SPECIALE: LA MEMORIA E LA RINASCITA - L'AQUILA A 14 ANNI DAL TERREMOTO",
#  'IL CASO CRAXI - UNA STORIA ITALIANA',
#  'CROZZA NEL PAESE DELLE MERAVIGLIE (TESTATA)',
#  'RAI NEWS - REPORTAGE',
#  'MOKA',
#  'CHE TEMPO CHE FA - IL TAVOLO',
#  'MI MANDA RAITRE IN FESTA',
#  'TG1 - VERSO IL QUIRINALE',
#  "RAI NEWS24 SPECIALE: GIORNATA DELLA MEMORIA E DELL'IMPEGNO - VITTIME INNOCENTI",
#  'SKY TG24 - EUROPEE 2019',
#  'VAR CONDICIO (TESTATA)',
#  'RAI NEWS: VOTO DEL 4 MARZO - I COLLEGI',
#  'TG1 E RAI VATICANO: PREGHIERA PER LA PACE',
#  'RAI NEWS24 - STUDIO 24 - ANTEPRIMA',
#  'RABONA - IL COLPO A SORPRESA',
#  'TG1: LA CRISI',
#  'TG1 - ESEQUIE DI STATO DI SILVIO BERLUSCONI',
#  'TGR - REGIONEUROPA',
#  'TG3 (L.I.S.)',
#  'RAI NEWS24 SPECIALE: BULLISMO',
#  'ORE 14 (RETE)',
#  'PROPAGANDA LIVE SPECIAL (TESTATA)',
#  'STUDIO APERTO SPECIALE',
#  'MEDIASET TGCOM 24 - DIRETTA DA ROMA: PARLA RENZI',
#  "RAI NEWS24 SPECIALE: PATRICK UNO DI NOI - UN ANNO FA L'ARRESTO DI ZAKY IN EGITTO",
#  'FILO DIRETTO UCRAINA - ANTEPRIMA RASSEGNA STAMPA',
#  'DRITTO E ROVESCIO OFF',
#  'RAI NEWS24 - PRIMA DI DOMANI',
#  'ATLANTIDE FILES (TESTATA)',
#  'PAOLO BORSELLINO ERA MIO PADRE',
#  'RAI NEWS24 - IL TG DI MEZZANOTTE',
#  'SKY TG24 - CASA ITALIA',
#  'ANTEPRIMA LA VITA IN DIRETTA ESTATE (TESTATA)',
#  'PRES. SOTTOVOCE',
#  'M (TESTATA)',
#  "FILO DIRETTO - L'ADDIO A SILVIO BERLUSCONI",
#  'CLIP: INTERVISTA A WALTER RICCIARDI',
#  'LE PAROLE (RETE)',
#  'CHE SUCC3DE? GAME (RETE)',
#  'POMERIGGIO CINQUE - SPECIALE PRIMO MAGGIO',
#  'IN ONDA FOCUS (TESTATA)',
#  '#BASTA LA SALUTE',
#  'LE PAROLE (TESTATA)',
#  'ROAD TO CORTINA 2021',
#  "TECHETECHETE' - IL MEGLIO DELLA TV",
#  'DOMENICA IN (RETE)',
#  'UNO NESSUNO CENTO NINO',
#  'SKY TG24 - LIVE IN VENEZIA',
#  'TG2',
#  'TG5 PRIMA PAGINA (TGCOM24)',
#  'LA VITA IN DIRETTA ESTATE (TESTATA)',
#  'RAI NEWS24 - MATTINA 24',
#  "PRESENTAZIONE 103° EDIZIONE GIRO D'ITALIA",
#  'RAI NEWS24 SPECIALE - GOVERNO NEUTRALE',
#  'ANTEPRIMA LA VITA IN DIRETTA ESTATE (RETE)',
#  'SPORT MEDIASET - LA GIORNATA',
#  'ANTEPRIMA RESTART (RETE)',
#  'CHE CI FACCIO QUI',
#  'STASERA ITALIA SPECIALE CORONAVIRUS (VN)',
#  'MI MANDA RAITRE (TESTATA)',
#  'RAI 1 E TG1 - SPECIALE PORTA A PORTA (RETE)',
#  'GENERAZIONE GIOVANI',
#  'ANNI 20',
#  'TRA POCO LIVE',
#  "RAI NEWS24 - E' GIA' DOMANI",
#  'RAI NEWS - RASSEGNA STAMPA',
#  'CHE TEMPO CHE FA RICORDA MAURIZIO COSTANZO',
#  "TG2 - RELAZIONE ANNUALE AL PARLAMENTO DELL'AUTORITA' DI REGOLAZIONE PER ENERGIA, RETI E AMBIENTE",
#  'STASERA ITALIA WEEKEND (TGCOM24)',
#  'PRESADIRETTA SABATO (RETE)',
#  'I SALUTI DI ZONA BIANCA',
#  'SKY TG24 - DIRETTA',
#  'FILO DIRETTO',
#  'CLIP: CONFERENZE STAMPA DEI VARI LEADER POLITICI',
#  'TGR - IL SETTIMANALE ESTATE',
#  'UOZZAP! COLLEZIONE AUTUNNO INVERNO',
#  'TG1 E RAI PARLAMENTO EDIZIONE SPECIALE',
#  'LA MIA PASSIONE',
#  'CERNOBBIO 2019...E ADESSO QUALE MANOVRA?',
#  'ELISIR',
#  'ANTEPRIMA REPORT CULT',
#  "PRES. SPECIALE MEZZ'ORA IN PIU' - IL MONDO CHE VERRA' (RETE)",
#  'ANTEPRIMA REPORT (RETE)',
#  'QUELLI CHE ASPETTANO',
#  'TG2 (L.I.S.)',
#  'SKY TG24 SPECIALE - BERLINO 89 OLTRE IL MURO',
#  'SKY TG24 - MATTINA',
#  'LA NOSTRA STORIA',
#  "TG4 ULTIM'ORA",
#  'ANTEPRIMA AGORÀ ESTATE \\(TESTATA\\)',
#  'RAI PIPOL LO SPETTACOLO SIETE NOI (TESTATA)',
#  'FIGLI DEL DESTINO',
#  'LA7 RICORDA',
#  'GR 1 - FOCUS ECONOMIA',
#  'TG LA7 SPECIALE: NOTTE AMERICANA - TRUMP O BIDEN',
#  'CASA ITALIA',
#  'MATTINO CINQUE LE STORIE',
#  'SEMBRA IERI - CRONACA E STORIA',
#  'STASERA ITALIA WEEKEND (VN)',
#  'REPORTAGE: ESSO QUISSU',
#  "FILO DIRETTO - L'ITALIA DI DOMANI",
#  'I DIECI COMANDAMENTI',
#  'MEDIASET TGCOM 24 DIRETTA',
#  "VIVA RAI 2! UN PO' ANCHE RAI 1",
#  'TG4 - DIARIO DI GUERRA',
#  'SERGIO ZAVOLI STORIA DI UN CRONISTA',
#  'SEVEN',
#  'TIKI TAKA IL CALCIO È IL NOSTRO GIOCO',
#  'BLOB 30',
#  'PRES. POMERIGGIO CINQUE',
#  'LA MALAEDUCAXXXION',
#  'RADIO1 IN VIVA VOCE',
#  'MATTINO CINQUE - NEWS 2021',
#  "RAI PARLAMENTO - CERIMONIA CELEBRATIVA DEL CENTENARIO DELL'AULA DI MONTECITORIO",
#  'VROOOM',
#  'LA VITA IN DIRETTA (TESTATA)',
#  'NONSOLOLIKE',
#  'SPORT MEDIASET LA GIORNATA',
#  'CONTROCORRENTE QUIRINALE',
#  'MATRIX PRIME - LA SFIDA DEI LEADER',
#  'TG LA7 SPECIALE ELEZIONI 2019',
#  "ANTEPRIMA CHE C'E' DI NUOVO",
#  "NON È L'ARENA \\(TESTATA\\)",
#  'SKY TG24 - SPECIALE REGIONI AL VOTO',
#  'LA DIFESA DELLA RAZZA',
#  'MI MANDA RAITRE ESTATE (RETE)',
#  'A SUA IMMAGINE',
#  'SKY TG24 SPECIALE: LUNA 50 1969-2019',
#  'DRITTO E ROVESCIO...E OLTRE',
#  "ANTEPRIMA AGORA' (RETE)",
#  'MEDIASET TGCOM 24 - CARTE SCOPERTE',
#  "AGORA' ESTATE (RETE)",
#  'GR 3',
#  'ASPETTANDO LE PAROLE',
#  'RAI NEWS',
#  'SPECIALE TG1: ITALIA AL VOTO',
#  'MAURIZIO COSTANZO SHOW - BUONANOTTE',
#  'ASPETTANDO GEO',
#  'TELETHON',
#  'LE PAROLE PER DIRLO',
#  'SPECIALE TG4 (NEWS MEDIASET)',
#  'TG2 POST - SPECIALE BALLOTTAGGI',
#  'PORTA A PORTA (RETE)',
#  'RAI CULTURA - SENATO & CULTURA',
#  "PRIMA DELL'ALBA",
#  'CLANDESTINO',
#  'TGR - 91° ADUNATA NAZIONALE ALPINI',
#  'VIVAVOCE',
#  'MEDIASET TGCOM 24 - DENTRO I FATTI SPECIALE ELEZIONI 2018',
#  'CHE SUCC3DE?',
#  'RAI NEWS24 SPECIALE: COVID 19 - DOMANDE E RISPOSTE',
#  'MEDIASET TGCOM 24 - ORE 12',
#  'SKY TG24 SPECIALE: GENOVA PER NOI - UN ANNO DOPO',
#  'ANTEPRIMA RAI 1 E TG1 - SPECIALE PORTA A PORTA (RETE)',
#  'RAI NEWS24 - SABATO E DOMENICA 24',
#  'LE IENE (RETE)',
#  'TG2 - SPECIALE ELEZIONI 2022',
#  'RAI EDUCATIONAL - TV TALK (TESTATA)',
#  'PROPAGANDA LIVE (TESTATA)',
#  'MATTINO CINQUE NEWS - ELEZIONI',
#  'SKY TG24 - AGENDA',
#  'TG1 E RAI QUIRINALE - CELEBRAZIONE DEL 73° ANNIVERSARIO DELLA LIBERAZIONE',
#  'RAI NEWS24 SPECIALE: AMMINISTRATIVE 2022 - REFERENDUM GIUSTIZIA',
#  'QUANTE STORIE (TESTATA)',
#  'PORTA A PORTA SPECIALE ELEZIONI (TESTATA)',
#  'CR4 - LA REPUBBLICA DELLE DONNE #I MIGLIORI MESI DELLA MIA VITA',
#  'IL NUOVO PONTE DI GENOVA - ORGOGLIO ITALIANO',
#  'DOMENICA LIVE',
#  'LE PAROLE DELLA SETTIMANA (RETE)',
#  "PRES. AGORA' ESTATE (RETE)",
#  'STORIE ITALIANE (TESTATA)',
#  'IL CAVALLO E LA TORRE (TESTATA)',
#  'TG LA7 SPECIALE ELEZIONI 2021',
#  'MEDIASET TGCOM 24 EDIZIONE SPECIALE',
#  'STUDIO APERTO LA DOMENICA (TGCOM24)',
#  'OMNIBUS LA7 (TESTATA)',
#  "AGORA' (TESTATA)",
#  'SPECIALE TG4 - ELEZIONI EUROPEE 2019',
#  'IMPACT - SOLUZIONI PER UNA CRISI',
#  'TELEGRAM',
#  "L'ARIA DI DOMENICA (TESTATA)",
#  'SPECIALE TG4',
#  'SKY TG24 - DENTRO I FATTI, CON LE TUE DOMANDE',
#  "OGGI E' UN ALTRO GIORNO SHORT (RETE)",
#  'IN ONDA (TESTATA)',
#  'UMBERTO B. IL SENATUR',
#  'TG3 - SPECIALE ELEZIONI',
#  "SKY TG24 - IL PAESE CHE NON C'E'",
#  'TG LA7',
#  "IL CAFFE' DI RAIUNO (RETE)",
#  'MEDIASET TGCOM 24 - IN DIRETTA DA MILANO PARLA MATTEO SALVINI',
#  "TRIBU' - EUROPA 19",
#  'TGR - PALIO DELLA MARCILIANA',
#  'TGR: PALIO DE LA MARCILIANA',
#  'TG3 SPECIALE',
#  'SKY TG 24 EDICOLA (I)',
#  'COMING SOON LE IENE (RETE)',
#  'SKY TG24 - LEZIONI DI VOTO',
#  'PRES. SKY TG24 POMERIGGIO',
#  'SKY TG24 - I GIORNI DI CONTE',
#  'MORNING NEWS SALUTI FINALI',
#  "ANTEPRIMA W L'ITALIA OGGI E DOMANI",
#  'IL TG DEI RAGAZZI',
#  'GEO',
#  'RTL 102.5 GIORNALE ORARIO',
#  'STASERA ITALIA NEWS SPECIALE I SALUTI (VN)',
#  'ALBERTO SORDI - STORIA DI UN ITALIANO',
#  "ITALIA SI'",
#  'FATTI E MISFATTI',
#  'MORNING NEWS SALUTI FINALI (TGCOM24)',
#  '100 OPERE TORNANO A CASA',
#  'TUTTI A SCUOLA (TESTATA)',
#  'LA NOTTE AMERICANA (VN)',
#  'I FATTI VOSTRI (RETE)',
#  'TGR SPECIALE',
#  'FILOROSSO SPECIALE (RETE)',
#  "ANTEPRIMA NON E' L'ARENA (TESTATA)",
#  'CLIP: LE ELEZIONI IN FRIULI VENEZIA GIULIA',
#  "NON È L'ARENA SPECIALE \\(TESTATA\\)",
#  'STASERA ITALIA SPECIALE PRIMA DEL VOTO (VN)',
#  "ANTEPRIMA LIVE NON E' LA D'URSO",
#  'TG5 SPECIALE ELEZIONI (TGCOM24)',
#  'IN DIRETTA DAL QUIRINALE: LE CONSULTAZIONI',
#  'TG1 E RAI QUIRINALE: IN RICORDO DI DON DIANA',
#  'CHE SUCC3DE? 2 (RETE)',
#  '#CARTABIANCA (TESTATA)',
#  'PREMIO LE MASCHERE DEL TEATRO ITALIANO (TESTATA)',
#  'PIAZZAPULITA - SENZA PACE (TESTATA)',
#  'STASERA ITALIA NEWS (VN)',
#  'AGORÀ ESTATE SPECIALE',
#  'MATTINO CINQUE - SPECIALE ELEZIONI I SALUTI',
#  'CLIP: TRAPANI - INTERVISTE AI CANDIDATI ALLE PROSSIME ELEZIONI COMUNALI',
#  'TG1: VERSO IL GOVERNO',
#  'CHE SUCC3DE? GAME',
#  'QUINTA COLONNA',
#  'PRES. ATLANTIDE - STORIE DI UOMINI E DI MONDI',
#  'SANREMO 2021 - 71 Festival della Canzone Italiana',
#  'CLIP: 25 APRILE 2022 - MANIFESTAZIONE ORGANIZZATA DALLA FIAP A ROMA',
#  'O ANCHE NO',
#  'RAI PARLAMENTO SPECIALE CONFRONTO',
#  'PATRIAE',
#  "L'ARIA CHE TIRA ESTATE - OGGI (TESTATA)",
#  'FRONTIERE',
#  'SANREMO 2021 - 71° FESTIVAL DELLA CANZONE ITALIANA',
#  "RADIO ANCH'IO",
#  'LA PUPA E IL SECCHIONE E VICEVERSA - STAGIONE 1',
#  'SEAT MUSIC AWARDS 2021',
#  'LA PARTITA',
#  'RAINEWS 24 - OGGI E DOMANI',
#  'PROPAGANDA LIKE (TESTATA)',
#  'ANTICIPAZIONI SKY TG24',
#  'ORE 14',
#  'OGNI MATTINA - DOPO IL TG (TESTATA)',
#  'ZONA BIANCA',
#  'CAMPIONATI DEL MONDO DI SCI ALPINO 2021: CERIMONIA DI APERTURA',
#  "AGORA' SPECIALE (TESTATA)",
#  'LA GRANDE STORIA - ANNIVERSARI',
#  'ABBATTIAMOLI',
#  'LINEA BLU',
#  'TG LA7 SPECIALE ELECTION DAY',
#  'SANREMO 2020 - 70° FESTIVAL DELLA CANZONE ITALIANA',
#  "RADICI - L'ALTRA FACCIA DELL'IMMIGRAZIONE",
#  "L'ITALIA CHE FA",
#  'TG2 - SPECIALE ELEZIONI AMMINISTRATIVE 2021',
#  'ANTEPRIMA SPECIALE #CARTABIANCA (RETE)',
#  "RAI NEWS 24 - NOI CI SIAMO L'ITALIA DELL'ACCOGLIENZA",
#  'ANTICIPAZIONI TG2',
#  "PRONTO CIRINNA'",
#  'CONTROCORRENTE SPECIALE',
#  'RAI NEWS SPECIALE - AMMINISTRATIVE 2022 SPECIALE BALLOTTAGGI',
#  'MATTINO CINQUE',
#  'SPORTELLO ITALIA',
#  'TG1 DIRETTA - PALERMO CHIAMA ITALIA',
#  'FILOROSSO (TESTATA)',
#  'MEDIASET TGCOM 24 - SPECIALE ELEZIONI 2019',
#  'RAI NEWS24 - IL TG DELLA SERA',
#  'TG2 - WEEKEND ESTATE',
#  'TG4 - DIARIO DEL GIORNO (TGCOM24)',
#  "RAI NEWS 24 - FOCUS 24 UN'ESTATE ITALIANA",
#  'STASERA ITALIA SPECIALE',
#  'RESTART (TESTATA)',
#  'CLIP: FEMMINICIDI IN ITALIA - DATI ANNO 2022',
#  'TG3',
#  'RAI 1 E TG1 - SPECIALE PORTA A PORTA - ELEZIONI 2018 (TESTATA)',
#  "NON É L'ARENA PRIMA PAGINA \\(TESTATA\\)",
#  'RAI NEWS24 SPECIALE - ELEZIONI 2018',
#  'SKY TG24 MONDO',
#  'TG4 - DIARIO DEL GIORNO SPECIALE',
#  "CERIMONIA DI CONSEGNA DEI COLLARI D'ORO 2019",
#  "ITALIA SI'! SPECIALE",
#  'NEL NOME DEL POPOLO ITALIANO',
#  'TG2 - SPECIALE BALLOTTAGGI',
#  'STUDIO APERTO LIVE',
#  'SONO LE VENTI',
#  'SKY TG24 SPECIALE: CORONAVIRUS - INTO THE RED ZONE',
#  'SKY TG24 - I FATTI DEL 2018',
#  "OGGI E' UN ALTRO GIORNO SHORT (TESTATA)",
#  "L'EUROPA CHE VORREI",
#  'TG8',
#  'LO SPORTELLO DI FORUM',
#  "CLIP: FORUM AMBROSETTI 2018 - RIFLESSIONI SUL FUTURO DELL'EUROPA",
#  'GRANDE FRATELLO 15',
#  'TG1 E RAI QUIRINALE: COMMERAZIONE DI ALESSANDRO MANZONI NEL 150ESIMO DELLA MORTE',
#  "SKY TG24 - RACCONTI D'ITALIA",
#  'SPECIALE TG5 - REGIONALI 2020 (TGCOM24)',
#  'MEDIASET TGCOM 24 - SERA',
#  'SPECIALE TG5 (TGCOM24)',
#  'SIAMO ANCORA FUORI DAL CORO (VN)',
#  'SKYTG24 - RASSEGNA STAMPA',
#  'SORGENTE DI VITA',
#  'RAI NEWS24 - TG SPECIALE',
#  'OGGI IN PRIMA - RASSEGNA STAMPA',
#  'TGR - 68° RADUNO NAZIONALE BERSAGLIERI',
#  'ATLANTIDE - STORIE DI UOMINI E DI MONDI (TESTATA)',
#  "PRES. AGORA' WEEKEND (RETE)",
#  'I SALUTI DI POMERIGGIO CINQUE',
#  'STASERA ITALIA WEEKEND SPECIALE - CORONA VIRUS',
#  "CHE GIORNO E'",
#  "VENTI20: I VENT'ANNI DEL 2000",
#  'SKY TG24 - NUMERI',
#  'TELEGRAM SPECIALE ELEZIONI',
#  'ANTEPRIMA LE PAROLE DELLA SETTIMANA (TESTATA)',
#  'SKY TG24 - ITALIA 18',
#  'TG3 SPECIALE ELEZIONI POLITICHE 2018',
#  'STATI GENERALI REMIX 2019-2020',
#  "ANTEPRIMA TG1 E PORTA A PORTA - SPECIALE CHI SARA' IL PRESIDENTE? (RETE)",
#  'TG4',
#  'ANTEPRIMA CONTROCORRENTE',
#  'LA CONFESSIONE (TESTATA)',
#  'SPECIALE TG2 - 100 ANNI DI STORIA',
#  'ANNI 20 ESTATE',
#  'AMICI DI MARIA DE FILIPPI - STAGIONE 20',
#  'STUDIO APERTO LA GIORNATA',
#  'UNO MATTINA SPECIALE ELEZIONI (TESTATA)',
#  'CLIP: ACCOGLIENZA E INTEGRAZIONE SOCIALE - PROGETTI AVVIATI DA AMMINISTRAZIONI COMUNALI E COOPERATIVE IN VAL CAMONICA (LOMBARDIA)',
#  'SKY TG24 - LIVE IN BARI',
#  "TG1 DIRETTA - RELAZIONE ANNUALE DEL PRESIDENTE DELL'AGCOM (RETE)",
#  'MATRIX PRIME',
#  'TG2 ITALIA - SPECIALE ELEZIONI USA',
#  "SPECIALE MEZZ'ORA IN PIU' - IL MONDO CHE VERRA' (RETE)",
#  "SPECIALE PORTA A PORTA - L'ITALIA UNITA CE LA FARA'",
#  "1/2H IN PIU' SPECIALE (TESTATA)",
#  "AGORA' STRENNE (RETE)",
#  "SPECIALE UNA MATTINA D'AGOSTO (TESTATA)",
#  '#ANNEFRANK LA STANZA ANTEPRIMA',
#  'ANTEPRIMA DRITTO E ROVESCIO',
#  'MATTINO CINQUE NEWS - I SALUTI (TGCOM 24)',
#  'SI O NO',
#  'FUORI DAL CORO',
#  "TG1 DIRETTA: GRAZIE GIGI - L'ULTIMO SALUTO A GIGI PROIETTI",
#  'SPECIALE PREMIO BIAGIO AGNES',
#  'KRONOS - IL TEMPO DELLA SCELTA (TESTATA)',
#  'RAZZA UMANA',
#  'MI MANDA RAITRE SPECIALE (TESTATA)',
#  'RAI CULTURA - TV TALK (RETE)',
#  'RAI NEWS24 - SABATO E DOMENICA 24: SPECIALE ELEZIONI',
#  "CLIP: DICHIARAZIONE DI SILVIO BERLUSCONI DOPO L'INCONTRO CON IL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA",
#  'SKY TG24 SPECIALE - VOTO 2020',
#  "FILO DIRETTO UCRAINA - L'ECONOMIA",
#  'SALUTI DA CORTINA E DAI MONDIALI DI SCI',
#  "RAI NEWS24 - POST COVID19: SI PUO' FARE!",
#  "SPECIALE MAFIA LA RICERCA DELLA VERITA'",
#  'LE CARTE IN REGOLA',
#  'RAI CULTURA - CONCERTO ANNIVERSARIO ROMA CAPITALE',
#  'RAI PARLAMENTO - TELEGIORNALE',
#  'SKY TG24 SPECIALE - BANCHI DI PROVA (I)',
#  'TRA POCO IN EDICOLA',
#  'TG1 - CRISI DI GOVERNO',
#  'DOMENICA IN - I SALUTI DI MARA (RETE)',
#  'TG5 MATTINA (TGCOM24)',
#  'SPECIALE PORTA A PORTA - ELEZIONI 2020 (TESTATA)',
#  'STASERA ITALIA NEWS (TGCOM24)',
#  'RAINEWS 24 - OGGI IN PRIMA',
#  "L'ARIA CHE TIRA IL DIARIO (TESTATA)",
#  'POMERIGGIO CINQUE SOCIAL',
#  'TG1 - I GIORNI DEL GOVERNO',
#  "UNO MATTINA - IL CAFFE' DI RAIUNO IDEE (RETE)",
#  'IL VIRUS - COSA NON HA FUNZIONATO?',
#  'DOMENICA REWIND',
#  'FILO DIRETTO - FESTA DELLA REPUBBLICA',
#  'MEDIASET TGCOM 24 - WEB TV',
#  'MEDIASET TGCOM 24 - PRIMA SERATA',
#  'CLIP: INTERVISTA A RENZO PIANO',
#  'RAI NEWS24 - SABATO24 SPECIALE QUIRINALE',
#  "L'ARIA CHE TIRA - OGGI (TESTATA)",
#  'LE PAROLE DELLA SETTIMANA (TESTATA)',
#  'MORNING NEWS (TGCOM24)',
#  'MEDIASET TGCOM 24 TOUR - IN MOVIMENTO TRA LE IMPRESE',
#  'PALIO DI SIENA',
#  'UNO MATTINA PER TELETHON (RETE)',
#  'FUORIROMA (TESTATA)',
#  'DIGITANGO - IL BALLO DELLE NOTIZIE IN RETE',
#  'TG LA7 EDIZIONE STRAORDINARIA',
#  'RAI NEWS24 - #2020ADDIO',
#  'VIENI DA ME',
#  'STUDIO APERTO 18:30',
#  'UNO MATTINA - SPECIALE (RETE)',
#  'RAI NEWS24 - FUTURO 24 VIAGGIO VERSO IL DOMANI',
#  'PRES. LE TENEBRE DI BIBBIANO',
#  'ANTEPRIMA LA VITA IN DIRETTA (RETE)',
#  "TG2 - SI' VIAGGIARE",
#  'SKY TG24 - SKYLINE',
#  "I DIRITTI AL TEMPO DELL'ALGORITMO",
#  "CLIP: DICHIARAZIONE DI NICOLA ZINGARETTI DOPO L'INCONTRO CON IL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA",
#  'CLIP: LA BONIFICA SOVRANISTA DI GIORGIO SANTELLI',
#  'STASERA ITALIA WEEKEND SPECIALE - CORONAVIRUS I SALUTI (VN)',
#  'XXXIII EDIZIONE PREMIO MARISA BELLISARIO',
#  'PRESADIRETTA (RETE)',
#  'DIRETTA DA ROMA: ASSEMBLEA NAZIONALE FORZA ITALIA',
#  'CARO MARZIANO (RETE)',
#  'LINEA BIANCA',
#  'POVERA PATRIA (TESTATA)',
#  'COSTA CONCORDIA - TRAPPOLA IN MARE',
#  'ANTEPRIMA PRESADIRETTA (RETE)',
#  'TG2 SPECIALE GOVERNO',
#  'CLIP: DISCORSO DI LILINA SEGRE AL QUIRINALE',
#  '1938 DIVERSI',
#  'UOMINI E PROFETI',
#  "C'E' SOLO UN PRESIDENTE L'ULTIMO SALUTO",
#  'RAI PARLAMENTO - PREMIER QUESTION TIME (L.I.S.)',
#  'DOMENICA LIVE - ELEZIONI POLITICHE',
#  'OTTO E MEZZO ANTEPRIMA (TESTATA)',
#  'RAI CULTURA - GRANDI DISCORSI DELLA STORIA (RAI EDU)',
#  'MATTINO CINQUE - SPECIALE ELEZIONI',
#  'FRATELLI DI CROZZA CLASSIC (TESTATA)',
#  'FRATELLI DI CROZZA (TESTATA)',
#  'TG2 SPECIALE - COMUNI AL VOTO',
#  "SKY TG24 ECONOMIA - L'INTERVISTA DI SARAH VARETTO",
#  'RTL 102.5 NEWS',
#  'TG5 NOTTE (TGCOM24)',
#  "FILO DIRETTO UCRAINA - I DUE VOLTI DELL'EUROPA",
#  "LIVE NON È LA D'URSO",
#  'I MIGLIORI FRATELLI DI CROZZA (TESTATA)',
#  'PIAZZAPULITA 00 (TESTATA)',
#  'FILO DIRETTO VERSO IL VOTO',
#  'TG1 DIRETTA - IL GIURAMENTO',
#  'MATTINO CINQUE NEWS (TGCOM 24)',
#  'PIAZZAPULITA - VINCERE',
#  'POMERIGGIO CINQUE - SPECIALE ELEZIONI EUROPEE',
#  'CLIP: OSTIA (ROMA) - VISITA ALLA STRUTTURA RICREATIVA PUNTO LUCE NATA DALLA COLLABORAZIONE TRA LA ONG SAVE THE CHILDREN E IL COMUNE DI ROMA',
#  "OGGI E' UN'ALTRO GIORNO + (RETE)",
#  'STASERA ITALIA SPECIALE - I SALUTI',
#  'FRATELLI DI CROZZA (RETE)',
#  "SKY TG24 - L'OSPITE",
#  'UNO MATTINA ESTATE - SPECIALE',
#  'FORREST',
#  'NEMO - NESSUNO ESCLUSO - ANTEPRIMA (RETE)',
#  'TGR - PIAZZA AFFARI',
#  'ACCORDI & DISACCORDI (TESTATA)',
#  'STUDIO APERTO - EDIZIONE STRAORDINARIA (TGCOM24)',
#  "CHE C'E' DI NUOVO",
#  'TG1 MATTINA - RASSEGNA STAMPA',
#  'TG LA7 DIARIO POLITICO',
#  'CLIP: TERNI TRA I COMUNI AL VOTO IL PROSSIMO 10 GIUGNO 2018',
#  'CAMMINA ITALIA',
#  'TG1 ELECTION DAY',
#  'PETROLIO FILES',
#  'GIOVANE EUROPA',
#  "PORTA A PORTA - ATTUALITA' DOPO IL CALCIO (RETE)",
#  'RAI EDUCATIONAL - TV TALK',
#  'SKY TG24 - VERSO IL GOVERNO',
#  'PIAZZAPULITA - PRIMA IO',
#  "L'ITALIA CRIMINALE QUANDO LA CRONACA FA LA STORIA",
#  'SKY TG24 SPECIALE: CORSIA DI EMERGENZA',
#  'PROPAGANDA LIVE SPECIALE (TESTATA)',
#  'PRESADIRETTA (TESTATA)',
#  'FILO DIRETTO - IL NUOVO GOVERNO',
#  "UNIVERSIADI ESTIVE NAPOLI 2019: CERIMONIA D'APERTURA",
#  'IL CANDIDATO VA ALLE ELEZIONI (TESTATA)',
#  "TG4 ULTIM'ORA (TGCOM24)",
#  'OGNI MATTINA - DOPO IL TG',
#  'SPECIALE TELEGRAM - IL VACCINO DELLA MEMORIA',
#  'STASERA ITALIA SPECIALE - CRISI DI GOVERNO',
#  'SKY TG24 - SALUTE TRADITA',
#  'RAI NEWS24 SPECIALE - ELEZIONI 2020 IL VERDETTO',
#  'TV7',
#  'TG5',
#  'IL GIORNALE DELLA MEZZANOTTE',
#  'RAI PARLAMENTO - SPECIALE CAMERA (L.I.S.)',
#  "BELLE COSI'",
#  'TG1 DIRETTA - 50° ANNIVERSARIO DELLA STRAGE DI PIAZZA FONTANA',
#  "TRIBU'",
#  "AGORA' SPECIALE EXTRA (RETE)",
#  'LA DOMENICA SPORTIVA',
#  'MI MANDA RAITRE ESTATE (TESTATA)',
#  'STORIE ITALIANE (RETE)',
#  'RAI SPORT: CICLISMO',
#  'RAI NEWS24 SPECIALE - ELEZIONI AMMINISTRATIVE',
#  'CLIP: INTERVISTA A MARCO MINNITI',
#  'ANTEPRIMA CONTROCORRENTE PRIMA SERATA',
#  'COFFEE BREAK',
#  'RAI NEWS24 SPECIALE - PIAZZA GRANDE',
#  'TG1 - INAUGURAZIONE DEL BOSCO DELLA MEMORIA',
#  "L'ARIA CHE TIRA SPECIALE #NOTTEPRIMADEGLIESAMI (TESTATA)",
#  'TG1, RAI 1 E RAI QUIRINALE: FESTA DELLA REPUBBLICA',
#  'STUDIO APERTO - EDIZIONE STRAORDINARIA',
#  'MATTINO CINQUE SPECIALE - LE STORIE',
#  "W L'ITALIA OGGI E DOMANI",
#  'ORE 14 LIVE',
#  'VIVA RAI 2!',
#  'ANTEPRIMA REPORT (TESTATA)',
#  'TITOLO QUINTO ANTEPRIMA',
#  "STASERA C'� CATTELAN SU RAIDUE",
#  "CLIP: L'AQUILA DIECI ANNI DOPO",
#  'TG2 - WEEKEND',
#  'ANTEPRIMA TG LA7 SPECIALE ELECTION DAY',
#  'PRIMO GIORNO DI SCUOLA - FORZA RAGAZZI',
#  'RAI PARLAMENTO - SPAZIOLIBERO',
#  'SKY TG24 - FUORICAMPO',
#  'BATTUTE?',
#  'MEDIASET TGCOM 24 - OGGI A TGCOM 24',
#  'PETROLIO FILES (TESTATA)',
#  'IL MEGLIO DEL PAESE DELLE MERAVIGLIE (TESTATA)',
#  'TECHE TELETHON',
#  "TAGADA' - #FOCUS (TESTATA)",
#  'TGR - 24° RADUNO: ASSOCIAZIONE NAZIONALE CARABINIERI',
#  'MATERA - INCHIESTA SULLA MATERIT: LA FABBRICA DELLA MORTE',
#  'TG1 MATTINA - ITALIA AL VOTO',
#  'RAI NEWS24 - SORSI E MORSI',
#  'ANTEPRIMA ATLANTIDE STORIE DI UOMINI E MONDI (TESTATA)',
#  'NEMO - NESSUNO ESCLUSO (RETE)',
#  'MEDIASET TGCOM 24 - BREAKING NEWS',
#  'LA7 20 UN RACCONTO ITALIANO',
#  'RAI 1 E TG1 - SPECIALE PORTA A PORTA - ELEZIONI 2018 (RETE)',
#  "DIMARTEDI' DIPIU' (TESTATA)",
#  'CLIP: INTERVISTA A PAOLO GENTILONI',
#  'TG1 - VERSO IL NUOVO GOVERNO',
#  'CRIMINI DEL CUORE',
#  'UN GIORNO DA PECORA',
#  'ANTEPRIMA FILOROSSO SPECIALE (RETE)',
#  'PORTA A PORTA (TESTATA)',
#  'PRES. SKY TG24 - BUONGIORNO TELEGIORNALE',
#  'TG4 - DIARIO DEL GIORNO SPECIALE (TGCOM24)',
#  'RAI PARLAMENTO - SPECIALE SENATO',
#  'ORE 14 (TESTATA)',
#  'TGR EDIZIONE STRAORDINARIA',
#  'RAI NEWS24 - SPOTLIGHT',
#  'TG PARLAMENTO',
#  'RAI NEWS - CHE FINE HA FATTO?',
#  'STUDIO APERTO LA GIORNATA (TGCOM24)',
#  'NEWS ROOM ITALIA',
#  "1948 L'ANNO CHE CAMBIO' L'ITALIA",
#  'DALLA VOSTRA PARTE VERSO IL VOTO',
#  "W L'ITALIA",
#  'CHE TEMPO CHE FA (RETE)',
#  'CR4 - LA REPUBBLICA DELLE DONNE',
#  'CLIP: INTERVISTA AL SINDACO DI VERONA FEDERICO SBOARINA',
#  'COFFEE BREAK SABATO',
#  "BERGAMO D'IMPROVVISO",
#  'CARO PRESIDENTE... (TGCOM 24)',
#  'ILLUMINATE',
#  "TUTTA LA CITTA' NE PARLA",
#  'TG ECONOMY',
#  "MATRIX E TG5: COSTANZO, L'UOMO CHE HA CAMBIATO LA TV",
#  'PRES. DOMENICA LIVE',
#  'ANTEPRIMA PORTA A PORTA (TESTATA)',
#  'DRITTO E ROVESCIO (TGCOM24)',
#  'LA STRADA DEL COLLE',
#  'QUARTA REPUBBLICA ANTEPRIMA',
#  'ANTEPRIMA IN ONDA (TESTATA)',
#  'SPECIALE TG4 - ADDIO ELISABETTA (TGCOM24)',
#  'CHE FUORI TEMPO CHE FA (RETE)',
#  'RAINEWS 24 - DOMANI IN PRIMA',
#  'TG5 - EDIZIONE STRAORDINARIA (TGCOM24)',
#  'TG1 - LE CONSULTAZIONI DI DRAGHI',
#  'RAI PARLAMENTO',
#  'RAI NEWS24 SPECIALE: PONTE SAN GIORGIO - LA RINASCITA',
#  'INDOVINA CHI VIENE A CENA',
#  'FILO DIRETTO - LE SFIDE DEL GOVERNO',
#  'CLIP: ELEZIONI REGIONALI UMBRIA',
#  'CONTROCORRENTE',
#  'RAI NEWS SPECIALE - PRIMO TRA GLI UMANI',
#  'A CENA DA MARIA LATELLA',
#  'M (RETE)',
#  'PREMIO CAMOMILLA - WOMEN FOR WOMEN AGAINST VIOLENCE',
#  'AL CONFINE DEI DIRITTI',
#  'STASERA ITALIA ANCORA',
#  "DOMENICA LIVE - ATTUALITA'",
#  'TG2 - SPECIALE ELEZIONI BASILICATA',
#  "ANTEPRIMA TAGADA' (TESTATA)",
#  '#CARTABIANCA ORE 18.30 (TESTATA)',
#  'PIACERE MAISANO AI TEMPI DEL CORONAVIRUS',
#  'ATLANTIDE SPECIALE (TESTATA)',
#  'PIACERE MAISANO',
#  'SKY TG24 - REGIONALI 2023: SPECIALE LAZIO E LOMBARDIA',
#  "LE PAROLE DELL'ANNO",
#  'TG3 - FUORI TG',
#  "ANTEPRIMA AGORA' SPECIALE (TESTATA)",
#  "CHE TEMPO CHE FARA' (TESTATA)",
#  "SKY TG24 SPECIALE - SANITA' MALATA",
#  'RAI NEWS 24 - FOCUS 24',
#  'POMERIGGIO CINQUE FESTIVO',
#  'QUELLI CHE.... DOPO IL TG',
#  "CLIP: TESTIMONIANZE SULLA CRISI GENERATA DALL'EMERGENZA CORONAVIRUS TRA LE PICCOLE E MEDIE IMPRESE",
#  "BLOB DI TUTTO DI PIU' (TESTATA)",
#  'LE TENEBRE DI BIBBIANO',
#  'TG3 SPECIALE - RAI PARLAMENTO',
#  'CHE TEMPO CHE FA - IL TAVOLO (RETE)',
#  '#CARTABIANCA (RETE)',
#  "L'APPRODO",
#  'TG1 - AMMINISTRATIVE 2021 BALLOTTAGGI',
#  'QUARTA REPUBBLICA AL VOTO',
#  'DEDICATO',
#  'RAI NEWS - ANTEPRIMA SPECIALE I GIORNI DEL QUIRINALE',
#  'RAI PARLAMENTO - SPECIALE SENATO (L.I.S.)',
#  'RAI NEWS24 - #2021ADDIO',
#  'SKY TG24 - SPECIALE: UN PIATTO DI SALUTE',
#  'QUINTA COLONNA - ANTEPRIMA',
#  "PIU' O MENO",
#  'RAI PARLAMENTO TG MAGAZINE',
#  'TG1 DIALOGO',
#  'DOMENICA LIVE - STORIE',
#  'MATRIX SPECIALE ELEZIONI',
#  'SPECIALE FATTI E MISFATTI',
#  'PROPAGANDA SOCIAL TOP TEN (TESTATA)',
#  'MEDIASET TGCOM 24',
#  'STASERA ITALIA NEWS SPECIALE (VN)',
#  'ANNI 20 NOTTE (TESTATA)',
#  'STASERA ITALIA - ANTEPRIMA',
#  'TG2 - SPECIALE',
#  'CLIP: VIDEO MESSAGGIO DI SILVIO BERLUSCONI',
#  'UNO MATTINA SPECIALE ELEZIONI ANTEPRIMA (TESTATA)',
#  'ANTEPRIMA PRESADIRETTA (TESTATA)',
#  'I MIGLIORI FRATELLI DI CROZZA',
#  'MATRIX SPECIALE',
#  'TG1 - AMMINISTRATIVE 2021',
#  "1/2H IN PIU' (TESTATA)",
#  'ANTEPRIMA LE PAROLE (RETE)',
#  'STASERA ITALIA QUIRINALE (VN)',
#  'SKY TG24 - LIVE IN FIRENZE',
#  'ORE 14 LIGHT (TESTATA)',
#  '5 MINUTI CON...',
#  'LA VITA IN DIRETTA SHORT (RETE)',
#  'MATTINO CINQUE - SPECIALE CORONAVIRUS',
#  'ANTEPRIMA LA VITA IN DIRETTA (TESTATA)',
#  'DENTRO LA ZONA BIANCA',
#  'SPECIALE CHE GIORNO È',
#  'CARO PRESIDENTE...',
#  'DA NOI...A RUOTA LIBERA (TESTATA)',
#  'TG1 MATTINA - ESTATE',
#  'RAI PARLAMENTO - TELEGIORNALE MAGAZINE',
#  'RAI NEWS 24 - FOCUS REFERENDUM',
#  'TG2 - LAVORI IN CORSO',
#  'TG1 E RAI PARLAMENTO IL NUOVO PARLAMENTO',
#  'SPECIALE LA BUSSOLA',
#  'QUARTA REPUBBLICA I SALUTI',
#  'STASERA ITALIA (VN)',
#  'FUORIROMA (RETE)',
#  'TG2 - IL CONFRONTO',
#  'BUONGIORNO ITALIA',
#  'MI MANDA RAITRE IN + (TESTATA)',
#  'TG2 - 64° REGATA DELLE ANTICHE REPUBBLICHE MARINARE',
#  'MATRIX CHIAMBRETTI',
#  'ESTATE IN DIRETTA (RETE)',
#  'ELEZIONI 2020 - VERSO IL VOTO',
#  'ANTEPRIMA PIAZZAPULITA (TESTATA)',
#  'SKY TG24 - LA SFIDA DEL COVID',
#  'CLIP: INTERVISTA A IGNAZIO MARINO',
#  "UNA MATTINA D'AGOSTO",
#  'ANTEPRIMA SALVINOLOGY - TUTTI I VOLTI DI MATTEO',
#  'SERGIO MARCHIONNE',
#  'TG5 SPECIALE (TGCOM24)',
#  "DI MARTEDIPIU' (TESTATA)",
#  'ANTEPRIMA STASERA ITALIA WEEKEND (VN)',
#  'MEDIASET TGCOM24 CLIP: DOMENICA LIVE INTERVISTA A GENTILONI',
#  'MATTINO CINQUE LIFE',
#  'SKY TG24 - AMERICA 2020',
#  "C'E' TEMPO PER...",
#  'FILOROSSO (RETE)',
#  'COFFEE BREAK ESTATE',
#  'RAI NEWS - ELEZIONI REGIONALI UMBRIA',
#  'TG2 - PROCIDA CAPITALE DELLA CULTURA 2022',
#  'ANTEPRIMA MAURIZIO COSTANZO SHOW',
#  'MEDIASET TGCOM 24 - RASSEGNA STAMPA',
#  'RAI NEWS24: 2019 - APPUNTI DI UN ANNO',
#  'RAI NEWS24 SPECIALE: 24 AGOSTO 2016 - LA SCOSSA INFINITA',
#  'REPORT (TESTATA)',
#  'IL CELESTE ROBERTO FORMIGONI',
#  'PRES. STASERA ITALIA ESTATE',
#  'TG1 - CERIMONIA DI INAUGURAZIONE ANNO GIUDIZIARIO',
#  'PALERMO CHIAMA ITALIA',
#  'CLIP: FATTI ED EVENTI INTERNAZIONALI CHE HANNO CARATTERIZZATO IL 2020',
#  'TG1 E RAI QUIRINALE - CELEBRAZIONE DEL 77° ANNIVERSARIO DELLA LIBERAZIONE',
#  'TG5 SERA (TGCOM24)',
#  'SKY TG24 SPECIALE (I)',
#  "ITALIA SI' (RETE)",
#  'SKY TG24 - IL CONFRONTO: PRIMARIE PD',
#  'TG5 EDIZIONE STRAORDINARIA',
#  'RAI NEWS 24 - IL NUOVO GOVERNO',
#  "TG1 DIRETTA - RELAZIONE ANNUALE DELL'AUTORITA' NAZIONALE ANTICORRUZIONE",
#  'FORMATO FAMIGLIA',
#  'SKY TG24 SPECIALE - VOTO 2020 (I)',
#  "OGGI E' UN ALTRO GIORNO (TESTATA)",
#  "ANTEPRIMA OGGI E' UN ALTRO GIORNO (RETE)",
#  "ANTEPRIMA LIVE NON E' LA D'URSO SPECIALE",
#  'TG2 POST ESTATE',
#  'TG1 - GENOVA RADURA DELLA MEMORIA RICORDO DELLE VITTIME DEL PONTE MORANDI',
#  'DOPPIA IPOCRISIA',
#  'SKY TG24 EDICOLA',
#  'PROPAGANDA LIVE BEST (TESTATA)',
#  'BALLATA PER GENOVA',
#  'MATRIX - SPECIALE ELEZIONI EUROPEE',
#  'ANDREOTTI DIARIO PRIVATO',
#  'SETTE GIORNI',
#  "TAGADA' (TESTATA)",
#  'RAI NEWS24: GENOVA ANNO UNO',
#  'REALITI SIAMO TUTTI PROTAGONISTI',
#  'CLIP: INTERVISTA AD ALBERTO BAGNAI',
#  'RAI NEWS24 - IL TG FLASH',
#  "TG1 - LE CITTÀ D'EUROPA PER LA PACE",
#  'RAI NEWS - SPECIALE ELEZIONI BASILICATA 2019',
#  'TG4 - DIARIO DEL GIORNO I SALUTI',
#  'TG3 EDIZIONE STRAORDINARIA',
#  'FILOROSSO',
#  "L'ARIA CHE TIRA SPECIALE - OGGI (TESTATA)",
#  'TGR - SPECIALE ANNIVERSARIO PONTE MORANDI',
#  'CR4 - LA REPUBBLICA DELLE DONNE REMIX',
#  'FESTIVAL DEL CINEMA ITALIANO',
#  'LE IENE PRESENTANO UN ANNO DI COVID',
#  'RAI NEWS24 SPECIALE: LE LEGGI INFAMI - 5 SETTEMBRE 1938',
#  'SPECIALE TG5 - REGIONALI 2020',
#  'TG1 - TRAGEDIA SULLA MARMOLADA',
#  'TG3 - NEL MONDO',
#  'QUELLI CHE',
#  'CORSA AL COLLE',
#  'MI MANDA RAITRE EXTRA (RETE)',
#  'ULTIMO - IL CAPITANO',
#  "L'ASSEDIO (TESTATA)",
#  'LA FERROVIA DELLA SETA',
#  'TG2 - PREMIO DE SANCTIS',
#  'RAI EDUCATIONAL - TV TALK ANTEPRIMA (TESTATA)',
#  'MAURIZIO COSTANZO SHOW ALLEGRIA',
#  'SKY TG24 - TIMELINE',
#  'GENOVA SAN GIORGIO - PONTE ITALIANO',
#  'CONFESSIONE REPORTER',
#  'COVID 19 - IL MONDO IN PERICOLO',
#  "AGORA' WEEKEND (TESTATA)",
#  'IL DIARIO DI ANNA',
#  "NON E' L'ARENA - IN PIAZZA A MEZZOJUSO (TESTATA)",
#  'DOMENICA LIVE - ULTIMA SORPRESA',
#  'ANTEPRIMA PORTA A PORTA 25 ANNI (RETE)',
#  'PIAZZAPULITA (TESTATA)',
#  'TG2 - CORTE DEI CONTI INAUGURAZIONE ANNO GIUDIZIARIO 2021',
#  'RAI NEWS24 - POMERIGGIO 24',
#  'TG4 - DIARIO DEL GIORNO',
#  'LA CADUTA - STORIA DI UNA MORTE, DI UNA BANCA, DI UNA CITTÀ',
#  'AL VOTO, AL VOTO...',
#  'SETTE STORIE SPECIALE TERREMOTO 5 ANNI DOPO (TESTATA)',
#  'OTTO E MEZZO SABATO (TESTATA)',
#  'PRES. RAI EDUCATIONAL - TV TALK (TESTATA)',
#  'TGR - 66° RADUNO NAZIONALE BERSAGLIERI',
#  'QUINTA COLONNA - ULTIMO ROUND',
#  'ANTEPRIMA MI MANDA RAITRE (RETE)',
#  'VERISSIMO',
#  'SPECIALE TG2',
#  'SKY TG24 - START',
#  'COFFEE BREAK REWIND',
#  'ZONA ROSSA',
#  'TG SPORT SPECIALE',
#  'TG2 FLASH (L.I.S.)',
#  'REGIONALI 2020 EMILIA ROMAGNA CALABRIA AL VOTO',
#  "TG5 SPECIALE-LILIANA SEGRE TESTIMONE CONTRO L'INDIFFERENZA",
#  "AGORA' SPECIALE (RETE)",
#  'RAI NEWS24 - REGIONALI 2023: LOMBARDIA E LAZIO',
#  'ZAPPING',
#  'NON STOP NEWS',
#  "RAI NEWS24 - CRONACHE DALL'ITALIA",
#  "C'E' SOLO UN PRESIDENTE",
#  'SKY TG24 SPECIALE - IL GIORNO DI CONTE',
#  'SKY TG24 - START: GENERAZIONE EUROPA',
#  "ANTEPRIMA VENTI20 I VENT'ANNI DEL 2000",
#  'REPORT (RETE)',
#  "ITALIA SI'! GIORNO PER GIORNO",
#  'TG1 SPECIALE - IL DISCORSO DI DRAGHI',
#  'MATTINO CINQUE NEWS - SPECIALE',
#  'SKY TG24 SPECIALE - 2020 UN ANNO CHE NON DIMENTICHEREMO ITALIA',
#  'MILLEEUNLIBRO - SCRITTORI IN TV',
#  "AGORA' ESTATE EXTRA (TESTATA)",
#  'SPECIALE ATLANTIDE - STORIE DI UOMINI E DI MONDI (TESTATA)',
#  'REPORT PLUS (RETE)',
#  'RAI NEWS REPORTAGE: LA DEPURAZIONE DELLA DISCORDIA',
#  'SPECIALE TG1 - UCRAINA',
#  "SKY TG24 SPECIALE: ITALIA '92 - TANGENTOPOLI, 30 ANNI DOPO",
#  'RAI NEWS - ECONOMIA 24',
#  "CLIP: LA SITUAZIONE DELL'OSPEDALE DI LOCRI",
#  'STASERA ITALIA SPECIALE (VN)',
#  "ZEFFIRELLI L'ULTIMO SOGNO",
#  'TUTTIFRUTTI',
#  'IN PRIMA FILA',
#  'FACCIA A FACCIA (MINOLI)',
#  'VISIONARI',
#  'TG2 SPECIALE ELEZIONI 2020',
#  'GENERAZIONE BELLEZZA',
#  "L'ARIA CHE TIRA SPECIALE (TESTATA)",
#  "FELICITA'",
#  'VOICE ANATOMY',
#  'LE GRANDI INTERVISTE DI PAOLO DEL DEBBIO',
#  'ORE 14 LIGHT (RETE)',
#  'SKY TG24 SPECIALE - LA SETE DEL PO',
#  'RAI NEWS 24 - MANOVRA DI NATALE: CAMERA APPROVA LA FIDUCIA',
#  "RICETTE ALL'ITALIANA ESTATE",
#  'TG1 ECONOMIA',
#  'GR1',
#  'LE MONTAGNE DELLA CULTURA',
#  'UOZZAP! CLASSIC',
#  'SKY TG24 - IL CONFRONTO: REGIONE LAZIO',
#  'UNO MATTINA ESTATE (RETE)',
#  'STASERA ITALIA SPECIALE (TGCOM24)',
#  'PETROLIO SPECIALE',
#  "L'ORA DI LEGALITA'",
#  'VERMICINO 40 ANNI DOPO',
#  "ANTEPRIMA PORTA A PORTA - ATTUALITA' DOPO IL CALCIO (RETE)",
#  'SKY TG24 - CONTE BIS',
#  'UOZZAP!',
#  'FILO DIRETTO UCRAINA - I GIORNI DEL CONFLITTO',
#  'RAI NEWS24 - REGIONALI 2023: FRIULI VENEZIA GIULIA',
#  'RAI NEWS24 SPECIALE: ELEZIONI POLITICHE 2022',
#  'CONTROCORRENTE SALUTI',
#  "ANTEPRIMA LIVE NON E' LA D'URSO SPECIALE NATALE",
#  "TG2 - COSTUME E SOCIETA'",
#  'ZEROVIRGOLA',
#  "POMERIGGIO CINQUE - L'ISOLA DEI FAMOSI",
#  'TG LA7 SPECIALE ELEZIONI 2018',
#  "PORTA A PORTA POLITICHE '22 (TESTATA)",
#  'STASERA ITALIA (TGCOM24)',
#  'PRES. REPORT (RETE)',
#  'SPECIALE GR1 - GIORNATA IN RICORDO DELLE VITTIME DELLE MAFIE E DEL DOVERE',
#  'RAI NEWS SPECIALE: 24 AGOSTO 2016 LA SCOSSA',
#  'SPECIALE TG1',
#  'PRES. COSTA CONCORDIA: CRONACA DI UN DISASTRO',
#  "CLIP: INTERVISTA A MARA CARFAGNA, PROMOTRICE DELLA CAMPAGNA NON E' NORMALE CHE SIA NORMALE",
#  'STASERA ITALIA SPECIALE ELEZIONI (TGCOM24)',
#  'CONTROCORRENTE - SPECIALE GUERRA',
#  'SKY TG24 - LIVE IN MILANO',
#  'CLIP: INTERVISTA A LAURA BOLDRINI',
#  "UNO MATTINA - IL CAFFE' DI RAIUNO (RETE)",
#  'TG1: LAZIO E LOMBARDIA AL VOTO',
#  'VERISSIMO - GIRI DI VALZER',
#  'ANTICIPAZIONI TG4',
#  "AGORA' WEEKEND (RETE)",
#  'PRES. STASERA ITALIA',
#  "REPORTAGE: LA LENTA RINASCITA, L'AQUILA 10 ANNI DOPO",
#  "HASHTAG 24 - L'ATTUALITA' CONDIVISA",
#  "L'ASSEDIO (RETE)",
#  'A RACCONTARE COMINCIA TU',
#  'TG1 - ADDIO SILVIO',
#  'TG3 LINEA NOTTE',
#  'MARY POP LIVE',
#  'QUARTA REPUBBLICA (TGCOM24)',
#  'ANTEPRIMA POMERIGGIO CINQUE',
#  'TG5 SPECIALE',
#  'MATRIX - SPECIALE ELEZIONI',
#  'QUARTA REPUBBLICA SPECIALE',
#  'FACE TO FACE - IL SALONE DELLA GIUSTIZIA',
#  'RAI NEWS - SPECIALE GIORNO DELLA MEMORIA',
#  'CLIP: INTERVISTA A MARIO MONTI',
#  'CINQUE MINUTI',
#  'CAPODANNO IN MUSICA',
#  'SKY TG24 SPECIALE - IL ROGO DI NOTRE DAME',
#  'OTTO E MEZZO SABATO - ANTEPRIMA (TESTATA)',
#  'UNO MATTINA IN FAMIGLIA (TESTATA)',
#  'OGNI MATTINA (TESTATA)',
#  'UNO MATTINA PRIMA PAGINA (RETE)',
#  'ZONA BIANCA (TGCOM24)',
#  'SECONDA LINEA (RETE)',
#  'SPECIALE TG2 - ELECTION DAY',
#  'MEDIASET TGCOM24 - INSIEME JUNTOS',
#  'SPECIALE TG1 - UN MARE DI FANGO: CRONACA DI UN DISASTRO ANNUNCIATO',
#  'SPECIALE TG5',
#  'POVERA PATRIA',
#  'OSSI DI SEPPIA IL RUMORE DELLA MEMORIA',
#  'TG1 MATTINA',
#  'CAFFÈ EUROPA',
#  'TG1 - CERIMONIA COMMEMORAZIONE VITTIME PONTE MORANDI',
#  'TG1 E PORTA A PORTA - SPECIALE ELEZIONI (TESTATA)',
#  'SKY TG24 - EUROPEE 2019 (I)',
#  'TG1 SPECIALE - LA DECISIONE DEL QUIRINALE',
#  'MATTINO CINQUE NEWS SPECIALE',
#  'STASERA ITALIA SPECIALE - CORONAVIRUS I SALUTI (VN)',
#  'PIAZZAPULITA - I FUORILEGGE',
#  "RAI NEWS24 - IN UN'ORA",
#  'PARLAMENTANDO',
#  'RAI CULTURA - BINARIO 21',
#  "DIMARTEDI' (TESTATA)",
#  'MEDIASET TGCOM 24 - DENTRO I FATTI',
#  'PIAZZAPULITA - LA RICADUTA (TESTATA)',
#  'OSSI DI SEPPIA QUELLO CHE RICORDIAMO',
#  'MESSAGGIO DEL PRES. REPUBBLICA SERGIO MATTARELLA ANNIVERSARIO FONDAZIONE VENEZIA',
#  'TG4 - EDIZIONE STRAORDINARIA (TGCOM24)',
#  'UNIVERSIADI ESTIVE NAPOLI 2019',
#  'CHE TEMPO CHE FA (TESTATA)',
#  'X-STYLE',
#  "AGORA' ESTATE EXTRA (RETE)",
#  'RAI NEWS24 - EFFETTO FARFALLA',
#  'SKY TG24 SPECIALE - CRISI DI GOVERNO',
#  'TG4 (TGCOM24)',
#  'PROPAGANDA LIVE DOC (TESTATA)',
#  'RAI NEWS SPECIALE L.I.S.',
#  'LA CORSA AL VOTO',
#  'SKY TG24 - SILVIO BERLUSCONI 1936-2023',
#  'CAMERA CON VISTA (TESTATA)',
#  'MEDIASET TGCOM 24 - SPECIALE CONSULTAZIONI',
#  "COME CI SI VEDRA' DOPO - TERRORISMO. LE STORIE DELLE VITTIME",
#  'MEDIASET TGCOM 24 - DIRETTISSIMA',
#  'TG5 GIORNO (TGCOM24)',
#  'RAI PARLAMENTO - SPECIALE CAMERA',
#  "BELLA MA'",
#  'MEDIASET TGCOM24 - NEWS LIVE',
#  "NON È l'ARENA \\(RETE\\)",
#  'MEDIASET TGCOM 24 - DENTRO I FATTI (CIVETTA)',
#  'ANTEPRIMA FILOROSSO (RETE)',
#  'MATRIX SPECIALE ELEZIONI EUROPEE',
#  'TG1 DIRETTA - MONICA, PER SEMPRE',
#  'SPECIALE TELEGRAM',
#  'RAI PARLAMENTO MAGAZINE',
#  'ANTEPRIMA ASPETTANDO LE PAROLE',
#  'BELVE CULT',
#  'ANTEPRIMA STASERA ITALIA WEEKEND SPECIALE CORONAVIRUS (VN)',
#  'ONOREVOLI CONFESSIONI',
#  'SETTE STORIE (RETE)',
#  "ASPETTANDO TAGADA' (TESTATA)",
#  "MEZZ'ORA IN PIU' - IL MONDO CHE VERRA' (TESTATA)",
#  'LE RAGAZZE',
#  'SKY TG24 - ITALIA 18 ON THE ROAD',
#  'RAI QUIRINALE E TG1: IL GIORNO DELLA MEMORIA (TESTATA)',
#  'SKY TG24 SPECIALE - VENEZIA SOMMERSA',
#  "PAOLO ROSSI UN CAMPIONE E' UN SOGNATORE CHE NON SI ARRENDE MAI",
#  'SKY TG24 - LA SFIDA DEL VOTO',
#  "FATTI E MISFATTI D'EUROPA",
#  'RAI PARLAMENTO - QUESTION TIME (L.I.S.)',
#  "VITE - L'ARTE DEL POSSIBILE",
#  'CHECKPOINT',
#  'RAI NEWS24 - IL TG DELLE 18.00',
#  'RAI NEWS24 - STUDIO 24 - SPECIALE',
#  'SPECIALE TG4 - LA CARICA DEI NUOVI SINDACI (TGCOM)',
#  'TG1 - IL PONTE DI GENOVA: CERIMONIA DI INAUGURAZIONE DEL VIADOTTO ALLA PRESENZA DEL PRES. DELLA REPUBBLICA',
#  "TG4 - L'ALMANACCO DI RETEQUATTRO",
#  'STUDIO APERTO - MAG',
#  'CHIAMATELA MAFIA',
#  'STASERA ITALIA SPECIALE - ANTEPRIMA (VN)',
#  'RAI NEWS - SPECIALE PRIMARIE PD',
#  'SOTTOVOCE',
#  'QUANTE STORIE (RAI 3)',
#  ...]

# %%
data.select('day').head(3)
# Out:
# shape: (3, 1)
# ┌─────────────────────┐
# │ day                 │
# │ ---                 │
# │ datetime[ns]        │
# ╞═════════════════════╡
# │ 2023-01-01 00:00:00 │
# │ 2023-01-01 00:00:00 │
# │ 2023-01-01 00:00:00 │
# └─────────────────────┘

# %%
name_unique = data.select('name').unique().to_series().to_list()
print(name_unique[:5])
# Out:
# ['Pompilio', 'Amos', 'Giuseppe (Giosi)', 'Nunzia Annunziata', 'Pinuccio']

# %%
data.select('lastname').unique().to_series().to_list()
# Out:
# ['Vigorelli',
#  'Meles',
#  'Crocetta',
#  'Efrem',
#  'Parroccini',
#  'Beruschi',
#  'Verì',
#  'Bergamotto',
#  'Frassoni',
#  'PPA Movimento Politico Pensiero Azione',
#  'Tusa',
#  'Prisco',
#  'Bonomelli',
#  'Rolfi',
#  'Polati',
#  'Del Re',
#  'Elia',
#  'Salmè',
#  'Sacchetti',
#  'Sabbadini',
#  'Sportiello',
#  'Battistoni',
#  'Ioannilli',
#  'Di Sciascio',
#  'Meritano',
#  'Durbano',
#  'De Rosa',
#  'Castellone',
#  'Mazzali',
#  'De Vincenzi',
#  'Santillo',
#  'Galli',
#  'Giambarba',
#  'Borra',
#  'Iarrera',
#  'Colia',
#  'Berni',
#  'Accardi',
#  'Maciucchi',
#  'Militello',
#  'Filippeschi',
#  'Ratti',
#  'Falvo',
#  'La Spina',
#  'Schillaci',
#  'Iaria',
#  'Fortunato',
#  'Aldegheri',
#  'Ascheri',
#  'Delfino',
#  'Buzzo',
#  'De Lucia',
#  'Partito Pensionati',
#  'Galizia',
#  'De Carolis',
#  'Manfredi',
#  'Pan',
#  'Popolo Viola',
#  'Palazzolo',
#  'Donnici',
#  'Biti',
#  'Rizzotto',
#  'Sernagiotto',
#  'Cristiani per la crescita felice',
#  'Angelosante',
#  'Tamburello',
#  'Scialpi',
#  'Ronconi',
#  'Majorino',
#  'Cervo',
#  'Fiocchi',
#  'Bartolo',
#  'Milanese',
#  'Mandanici',
#  'Vairani',
#  "D'Alessandro",
#  'Chiavaroli',
#  'Capponi',
#  'Stella',
#  'Gazzani',
#  'Accorsi',
#  'Borio',
#  'Siracusano',
#  'Luzzi',
#  'Ubaldi',
#  'Malavasi',
#  'Benvenuti Gostoli',
#  'Grilli',
#  'Frusone',
#  'Fossi',
#  'Semenzato',
#  'Petralia',
#  'Dika',
#  'Cassani',
#  'Caminiti',
#  'Pignalberi',
#  'Randazzo',
#  'Capezzone',
#  'Laghi',
#  'Boschini',
#  'Saccardi',
#  'Confalonieri',
#  'Serafia',
#  'Viva la Fisica',
#  'De Poli',
#  'Di Girolamo',
#  'Luciani',
#  'Socialisti e Democratici',
#  'Roccella',
#  'Emiliani',
#  'Cannatelli',
#  'Giglio',
#  'Pasqualon',
#  'Navanzino',
#  'Rao',
#  'Massimo Carmelo',
#  'Mucciardi',
#  'Scamard�',
#  'Orsini',
#  'Ioppolo',
#  'Fini',
#  'De Zanna',
#  'Batino',
#  'Chifaro',
#  'Mastella',
#  'Granello',
#  'Lasagna',
#  'Citino',
#  'Stramignoni',
#  'Pappalardo',
#  'Forlani',
#  'Thuegaz',
#  'Megha',
#  'Fotia',
#  'Soliani',
#  'Paladini Molgora',
#  'Bartolazzi',
#  'Venanzi',
#  'Onnis',
#  'Caruso',
#  'Giacone',
#  'Centro Democratico-Radicali Italiani-+Europa',
#  'Bongioanni',
#  'Legnaioli',
#  'Nicita',
#  'Benedikter',
#  'Italia dei Diritti',
#  'Morgante',
#  'Fasano',
#  'Irto',
#  'Donno',
#  'Schiano',
#  'Romanello',
#  'De Santis',
#  'Macario',
#  'Alba',
#  'Spataro',
#  'Floris',
#  'Russoniello',
#  'Iulian',
#  'Rossetti',
#  'Stefani',
#  'Latorre',
#  'Frate',
#  'Muggiani',
#  'Chessa',
#  'Dovetta',
#  'Pecorelli',
#  'Capozzi',
#  'Falconio',
#  'Campomenosi',
#  'Lodigiani',
#  'Meduri',
#  'Massimelli',
#  'Roberti',
#  'Beccaria',
#  'Mammolito',
#  'Brosio',
#  'Piffer',
#  'Vaninetti',
#  'Ceci',
#  'Fabbrizzi',
#  'Derisi',
#  'Epis',
#  'Zaffini',
#  'Del Bello',
#  'Zavalloni',
#  'Conia',
#  'De Martino',
#  'Soave Alemanno',
#  'Radiconcini',
#  'Rocchio',
#  'Ungaro',
#  'Liberati',
#  'Montibeller',
#  'Calvisi',
#  'Guerriero',
#  'Romani',
#  'Coffari',
#  'Lorenzi',
#  'Angelini',
#  'Artusi',
#  'Amoruso',
#  'Buonopane',
#  'Falbo',
#  'Riccardo',
#  'Morselli',
#  'Compagnone',
#  'Fucksia',
#  'Corsetto',
#  'Lo Russo',
#  'Gimelli',
#  'Addario',
#  'Mangani',
#  'Sciapichetti',
#  'Daccò',
#  'Isella',
#  'Beluzzi',
#  'Rollando',
#  'Losacco',
#  'Zappacosta',
#  'Bellifemine',
#  'Tiboni',
#  'Lupardini',
#  'Novali',
#  'Delbono',
#  'Titoni',
#  'Coltelli',
#  'SI-SEL-POS-Liberi e Uguali',
#  'Vezzini',
#  'Fermariello',
#  'Prestia',
#  'Tonnini',
#  'Della Valle',
#  'Pivetti',
#  'De Benedetti',
#  'Peluffo',
#  'Gallizzi',
#  'Ardizzone',
#  'Parolo',
#  'Memmo',
#  'Capuozzo',
#  'Lucente',
#  'Conte',
#  'Ruscigno',
#  'Persiani',
#  'Resta',
#  'Mastacchi',
#  'Partito Socialista',
#  'Movimento Politico Libertas',
#  'Ragusa',
#  'Bernabei',
#  'Barani',
#  'Tedesco',
#  'Pizzonia',
#  'Bernard',
#  'Bengala',
#  'Ferrari',
#  'Mazzini',
#  'Dalla Vecchia',
#  'Di Cola',
#  'Macilotti',
#  'Cenni',
#  'Lorusso',
#  'Mazzarella',
#  'Lolli',
#  'Beorchia',
#  'Schiavi',
#  'Verrecchia',
#  'Lobuono',
#  'Catalano',
#  'Siragusa',
#  'Tonoli',
#  'Laddaga',
#  'Moric',
#  'Angori',
#  "Lega per l'Italia",
#  'Damiani',
#  'Grippa',
#  'Castagnola',
#  'Addis',
#  'Gallera',
#  'Trombadore',
#  'Casciello',
#  'Neri',
#  'Missarelli',
#  'Berardinetti',
#  'Benevento',
#  'Pusceddu',
#  'Pirovano',
#  'Trapanese',
#  'Tondi',
#  'Guccione',
#  'Dori',
#  'Aliano',
#  'Laborante',
#  'Augliera',
#  'Battista Castagneri',
#  'Bontempi',
#  'Previtali',
#  'Airoldi',
#  'Foppa',
#  'Sylos Labini',
#  'Tesei',
#  'Medri',
#  'Sgambato',
#  'Bizzoni',
#  'Calzia',
#  'Lollobrigida',
#  'Abate',
#  'La Porta',
#  'Piastra',
#  'Manzo',
#  'Manfrin',
#  'Alberizzi',
#  'Stirati',
#  'Liberi e Uguali',
#  'Cantelli',
#  'Braga',
#  'Nigro',
#  'Mazzarotto',
#  'Zorzo',
#  'Sacc�',
#  'Gelone',
#  'Patuelli',
#  'Lai',
#  'Magorno',
#  'Civita',
#  'Comencini',
#  'Ciocca',
#  'Franceschelli',
#  'Casaleggio',
#  'Alli',
#  'Trenta',
#  'Schifone',
#  'Basilico',
#  'Alberoni',
#  'Toccafondi',
#  'Bozzano',
#  'Incarnato',
#  'Caliendo',
#  'Fenaroli',
#  'Azione Civile',
#  'Coletto',
#  'Mar�',
#  'Antonioli',
#  'Garofoli',
#  'Gennari',
#  'Cavallari',
#  'Speroni',
#  'Foscari',
#  'Delli Noci',
#  'Nanni',
#  'Guerini',
#  'Cascella',
#  'Roberto',
#  'Cirroni',
#  'Rondinelli',
#  'Grant',
#  'Arboit',
#  'Bavaro',
#  'Mazzoli',
#  'Davi',
#  'Gualmini',
#  'Benassi',
#  'Palazzetti',
#  'Anzaldi',
#  'Marchetto Aliprandi',
#  'Purpora',
#  'Marzullo',
#  'Montebello',
#  'Bosatelli',
#  'Mascarin',
#  'Costi',
#  'Trotta',
#  'Di Stasio',
#  'Ginetti',
#  'Fioroni',
#  'Lazzeri',
#  'Bettini',
#  'Degli Angeli',
#  'Motta',
#  'Bargilli',
#  'Spicola',
#  'Moles',
#  'Gentili',
#  'Veith',
#  'Pelonzi',
#  'Acchiardi',
#  'Bottoni',
#  'Cuccu',
#  'Poli',
#  'De Luca',
#  'Pavia',
#  'Sparavigna',
#  'Spizzirri',
#  'Bessi',
#  'Pilosio',
#  'Piccolotti',
#  'Bozza',
#  'Zampa',
#  'Marganelli',
#  'Guidolin',
#  'Tripiedi',
#  'Dosio',
#  'Gaggero',
#  'Bonriposi',
#  'Papale',
#  'Giampà',
#  'Garito',
#  'Di Bari',
#  'Sileri',
#  'Lattuca',
#  'Colonna',
#  'Del Monaco',
#  'Versace',
#  'Basile',
#  'Vespa',
#  'Tassara',
#  'Olocco',
#  'Caragliano',
#  'Arru',
#  'Patriciello',
#  'Barabotti',
#  'Altavilla',
#  'Mazzolani',
#  'Veronesi',
#  'Pizzul',
#  'Puglia',
#  'Saija',
#  'Piani',
#  'Colantoni',
#  'Funaro',
#  'Franchellucci',
#  'Andò',
#  'Pedicini',
#  'Gullì',
#  'Tripoli',
#  'Crema',
#  'Ticchi',
#  'Bazzoli',
#  'Deo',
#  'Flocchini',
#  'Becchetti',
#  'Rapinese',
#  'Bettin',
#  'Bellardo Gioili',
#  'Unione Tricolore America Latina',
#  'Loizzo',
#  'Gaudino',
#  'Libertà',
#  'Tombolini',
#  'Cris�',
#  'Canobbio',
#  'Manes',
#  'Orengo',
#  'Francilia',
#  'Zingoni',
#  'Fantetti',
#  'Parrini',
#  'Zunato',
#  'Ceccanti',
#  'Bacci',
#  'Amen',
#  'Pressi',
#  'Marinone',
#  'Usula',
#  'Benvenuto',
#  'Pellizzari',
#  'Figuccia',
#  'Gufler',
#  'Vergaglia',
#  'Lisi',
#  'Puggioni',
#  'Delpriori',
#  'Sarlo',
#  'Chisso',
#  'Faraone',
#  'Strada',
#  'Comitato per il No al taglio del Parlamento',
#  'Barberini Colonna',
#  'Pillon',
#  'Gambini',
#  'De Ranieri',
#  'Calabretta',
#  "D'Ettore",
#  'Di San Martino Lorenzato',
#  'Boschi',
#  'Cairo',
#  'Galliani',
#  "D'Elia",
#  'Conci',
#  'Iacobelli',
#  'Verlicchi',
#  'Losurdo',
#  'Bassano',
#  'Lazzarini',
#  'Spinelli',
#  'Sciannimanica',
#  'Visini',
#  'Bellone',
#  'Testolin',
#  'Brognoli',
#  'Cuillo',
#  'Vincenti',
#  'Di Liberto',
#  'Montioni',
#  'Di Sabatino',
#  'Bergamo',
#  'Ranuccio',
#  'Canturi',
#  'Manzoni',
#  'Rollo',
#  'Marello',
#  'Caterino',
#  'Cossu',
#  "D'angelo",
#  'Bolandrini',
#  'Pedica',
#  'Causin',
#  'Stefio',
#  'Diomedi',
#  'Amendola',
#  'Popolo della famiglia-Alternativa Popolare',
#  'Silvestro',
#  'Catalfo',
#  'Manuele',
#  'Cittadini per Bolzonello',
#  'Partito Valore Umano',
#  'Magalotti',
#  'Lipera',
#  'Muscarà',
#  'Friggeri',
#  'Notazio',
#  'Monguzzi',
#  'Moffa',
#  "D'Incà",
#  'Sensini',
#  'La Loggia',
#  'Nazzaro',
#  'Marasca',
#  'Preacco',
#  'Ginoble',
#  'Ugolini',
#  'Frulio',
#  'Giacoletto',
#  'Scamolla',
#  'Venzon',
#  'Agostinelli',
#  'Liardo',
#  'Nelli',
#  'Maiorano',
#  'Scavello',
#  'Petracca',
#  'Petralia Camassa',
#  'Mattiotti',
#  'Giusiano',
#  'Ifarajimi',
#  'Pichetto Fratin',
#  'Baudino',
#  'De Angelis',
#  'Calamari',
#  'Sperto',
#  'Orgoglio Molise',
#  'Lucianaz',
#  'Lega Nord',
#  'Migliorino',
#  'Licopodio',
#  'Bettarini',
#  'Balzi',
#  'Carano',
#  'Solombrino',
#  'Rasero',
#  'Caperdoni',
#  'Piana',
#  'Calenda',
#  'Passerini',
#  'Sicchiero',
#  'Stelliferi',
#  'Cuttica di Revigliasco',
#  'Wheeler',
#  'Di Pasquale',
#  'Morando',
#  'Monorchio',
#  'De Lorenzo',
#  'Polese',
#  'Crestini',
#  'Campione',
#  'Puglisi',
#  'Melio',
#  'Avanguardia nazionale',
#  'Borghini',
#  'Perla',
#  'Sau',
#  'Cristaldi',
#  'Cetrone',
#  'Pasquini',
#  'Mai',
#  'Villone',
#  'Masini',
#  'Colla',
#  'Lenzi',
#  'Giampredone',
#  'Abete',
#  'Madama',
#  'Tondo',
#  'Scordella',
#  'Capellino',
#  'Boccuzzi',
#  'Agus',
#  'Asproso',
#  'Andruccioli',
#  'Trentanovi',
#  'Bray',
#  'Giuliani',
#  'Barros',
#  'Biscardini',
#  'Bilotti',
#  'Innocenti',
#  'Labella',
#  'Fontana',
#  'Balleari',
#  'Dal Borgo',
#  'Quintavalla',
#  'Sabatini',
#  'Plescia',
#  'Burocchi',
#  'Sica',
#  'Zullo',
#  'Citterio',
#  'Bakkali',
#  'C�',
#  'Vignaroli',
#  'Schiuma',
#  'Messana',
#  'De Nardo',
#  'Scriva',
#  'De Gasperi',
#  'Movimento Animalista',
#  'Marcon',
#  'Bocher',
#  'Di Cillo',
#  'Deiana',
#  'Pasquali',
#  'Linguanti',
#  'Caccavale',
#  'Pisapia',
#  'Zanetti',
#  'Brugger',
#  'Rizzi',
#  'Della Dora',
#  'Maffoni',
#  'Nadal',
#  'Turati',
#  'Ledda',
#  'Comitato Democratici per il Sì',
#  'Bellaria',
#  'Simonelli',
#  'Biglio',
#  'Iadicicco',
#  'Bernardini De Pace',
#  'De Faveri',
#  'Fabris',
#  'Delvecchio',
#  'Fascina',
#  'Zulli',
#  'Barile',
#  'Augussori',
#  'Fabi',
#  'Valente',
#  'Degiovanni',
#  'Passariello',
#  'Callegaro',
#  'Partito Internettiano',
#  'Puddu',
#  'Lacchetta',
#  'Vitri',
#  'Savoi',
#  'Castelluccio',
#  'Cinti',
#  'Fracassi',
#  'Passoni',
#  'Magrini',
#  'Zani',
#  'Sartini',
#  'Argentin',
#  'Barbaliscia',
#  'Harth',
#  'Pedrelli',
#  'Sigismondi',
#  'Silvestri',
#  'Tornusciolo',
#  'Popolo per la Costituzione',
#  'Vannucci',
#  'Moretti',
#  'Gonzo',
#  'Caffaratto',
#  'Alliance Valdotaine',
#  'Seletti',
#  'Poli Bortone',
#  'Foglio',
#  'Centioni',
#  'Policaro',
#  'Calvani',
#  'Loiacono',
#  'Fantini',
#  'Vignali',
#  'Cavagna',
#  'Ciancio',
#  'Lama',
#  'Amato',
#  'Ronchi',
#  'Rossini',
#  'Potere al Popolo',
#  'Granà',
#  'Cesa',
#  'Astarita',
#  'Binetti',
#  'Tursi',
#  'Cucchiara',
#  'Mazzucchelli',
#  'Crescimanno',
#  'Mazzorato',
#  'Maccari',
#  'Casisi',
#  'Vaccarin',
#  'Gazzolo',
#  'Canale Clapetto',
#  'Ruggia',
#  'Lipparini',
#  'Pedrali',
#  'De Rebotti',
#  'Pavone',
#  'Nava',
#  'Frizzi',
#  'Giacomuzzi',
#  'Sartore',
#  'Martire',
#  'Giuliante',
#  'Anzalone',
#  'Pettinari',
#  'Pigoni',
#  'Pelicioli',
#  'Lo Monte',
#  'Szumski',
#  'Licheri',
#  'Antonelli',
#  'Barbafieri',
#  'Calderoli',
#  'C.A.L. (Costituzione, Ambiente, Lavoro)-Alternativa-P.C.-I.d.V',
#  'Piano',
#  'Dalla Nora',
#  'Sotgia',
#  'Superbi',
#  'Pecorini',
#  'Farello',
#  'Tucci',
#  'Di Lieto',
#  'Piccitto',
#  'Iasevoli',
#  'Di Paolo',
#  'Taurino',
#  'Adduce',
#  'Ruini',
#  'Angotti',
#  'Proserpio',
#  'Marinacci',
#  'Oggiano',
#  'Chiancone',
#  'Guardamagna',
#  'Robustelli',
#  'Caucino',
#  'Papatheu',
#  'Lengua',
#  'Falciano',
#  'Montagner',
#  'Mondello',
#  'Pavoncello',
#  'Toma',
#  'Balestrieri',
#  'Cofferati',
#  'Alonge',
#  'Lovecchio',
#  'Garillo',
#  'Lamboglia',
#  'Iannitti',
#  'Tomatis',
#  'Occhi',
#  'Genovese',
#  'Bertagna',
#  'Pascucci',
#  'Razza',
#  'Bertucco',
#  'Marsetti',
#  'Gubellini',
#  "D'Adamo",
#  'Pinotti',
#  'Carretto',
#  'Mastrangeli',
#  'Bosa',
#  'Ciriani',
#  'Volt Italia',
#  'Mercalli',
#  'Ghedini',
#  'Lo Faro',
#  'Donati',
#  'Cersosimo',
#  'Liburdi',
#  'Sanvitto',
#  'Toniaccini',
#  'Baseggio',
#  'Cuperlo',
#  'Govi',
#  "D'Oria",
#  'De Conciliis',
#  'Buonincontro',
#  'Sadegholvaad',
#  'Severini',
#  'Digioia',
#  'Ziberna',
#  'Coppolino',
#  'Rinascimento',
#  'Bisconti',
#  'Cozzi',
#  'Chianella',
#  'Capocchi',
#  "D'Ugo",
#  'Filini',
#  'Rianna',
#  'Benveduti',
#  'Comotto',
#  'Raffaele',
#  'Nicolao',
#  'Taglioli',
#  'Fantinati',
#  'Vendola',
#  'Zaia Presidente',
#  'Berti',
#  'Della Porta',
#  'Alvisi',
#  'Sarnataro',
#  'Marchesich',
#  'Marchesic',
#  'Tremonti',
#  'Borletti Buitoni',
#  'Lantieri',
#  'Turini',
#  'Simoni',
#  'Casalini',
#  'Caci',
#  'Paladini',
#  'Galmozzi',
#  'Zanda',
#  'Valluzzi',
#  'Pollicino',
#  'Tallini',
#  'Scarpitta',
#  'Dambruoso',
#  'Tinti',
#  'Di Cerbo',
#  'Mongatti',
#  'Antonetti',
#  'Ortolani',
#  'Rota',
#  'Barberis',
#  'Ciambetti',
#  'Auddino',
#  'Stramezzi',
#  'Farioli',
#  'Cillo',
#  'Sturla',
#  'Sardine',
#  "D'ettorre",
#  'Bianciardi',
#  'Nervi',
#  'Ricaro',
#  'Priori',
#  'Moschioni',
#  'Steger',
#  'Perifano',
#  'Deledda',
#  'Gasbarra',
#  'Basciano',
#  'Ausserdorfer',
#  'Rostirolla',
#  'Berardinangelo',
#  'Lacopeta',
#  'Cicconofri',
#  'Ichino',
#  'Gasparini',
#  'Bonanno Conti',
#  'Lambiase',
#  'Campagnolo',
#  'Cangelosi',
#  'Risso',
#  'Schifani',
#  'Mammi',
#  'Mittermair',
#  'Scavuzzo',
#  'Ceretti',
#  'Turla',
#  'Di Lello',
#  'Canu',
#  'Delunas',
#  'Finardi',
#  'Iardino',
#  'Salsotto',
#  'Corvi',
#  'Indipendenza Veneta',
#  'Tidei',
#  'Lipari',
#  'Damonte',
#  'Di Marzo',
#  'Di Silvestre',
#  'Boniardi',
#  'Matera',
#  'De Meo',
#  'Morganti',
#  'De Marinis',
#  'Bellomo',
#  'Meini',
#  'Partito Liberale Italiano',
#  'Dei',
#  'Capriotti',
#  'Gobbi',
#  'Alinovi',
#  'Fiandaca',
#  'Calore',
#  'Carinelli',
#  'Di Caro',
#  'Gagnarli',
#  'Garufo',
#  'Massardo',
#  'Boato',
#  'Sarracino',
#  'Bori',
#  'Palestra',
#  'Pignataro',
#  'Europa Verde',
#  'Massa',
#  'Tontaccini',
#  'Sabatinelli',
#  'Del Basso De Caro',
#  'Merra',
#  'Bordilli',
#  'Mortandello',
#  'Gavusi',
#  'Curatella',
#  'Bragagni',
#  'Gelli',
#  'Bonaldi',
#  'Gargano',
#  'Geminiani',
#  'Sapienza',
#  'Talloru',
#  'Caso',
#  'Varasano',
#  'Maira',
#  'Procopio',
#  'Cotugno',
#  'Dal Monte',
#  'Cardinali',
#  'Tozzi',
#  'Spaggiari',
#  'Lopreiato',
#  "Patto Per l'Autonomia",
#  'Cipolla',
#  'Barberi',
#  'Porta',
#  'Per una Sinistra Rivoluzionaria',
#  'Bechis',
#  'Aurea (De La Cruz)',
#  'Gemma',
#  'Bucari',
#  'Vanzi',
#  'Daviddi',
#  'Vuilleumier',
#  'Bancheri',
#  'Camarda',
#  'Riotta',
#  'Sdoga',
#  'Rivoluzione Sanitaria',
#  'Sambrici',
#  "Italia Viva - Italia C'�",
#  'Andrioli',
#  'Locher',
#  'Pastorella',
#  'Allegretti',
#  'Casa',
#  'Ingenito',
#  'Bentivogli',
#  'Nasso',
#  'Mottola',
#  'Benasso',
#  'Urso',
#  'Legnini',
#  'Camuzzi',
#  'Callegari',
#  'Di Fiore',
#  'Mirabello',
#  ...]

# %%
data.filter(pl.col("name") == "political movement").select("lastname").head(3)
# Out:
# shape: (3, 1)
# ┌─────────────────────────────────┐
# │ lastname                        │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ Azione-Italia Viva-Renew Europ… │
# │ Azione-Italia Viva-Renew Europ… │
# │ Azione-Italia Viva-Renew Europ… │
# └─────────────────────────────────┘

# %%
data.filter(pl.col("name") != "political movement").select("lastname").head(3)
# Out:
# shape: (3, 1)
# ┌────────────┐
# │ lastname   │
# │ ---        │
# │ str        │
# ╞════════════╡
# │ Berlusconi │
# │ Conte      │
# │ Letta      │
# └────────────┘

# %%
data.select('topic').unique().to_series().to_list()
# Out:
# ['Informazioni di servizio',
#  'Religione e questioni religiose',
#  'Fine',
#  'Ambiente',
#  'Cultura e istruzione',
#  'Sport',
#  'Medicina, salute e scienza',
#  'Pubblicità',
#  'Cronaca',
#  'Economia, finanza e lavoro',
#  'Programma',
#  'Società',
#  'Politica e attività istituzionali',
#  'Altro',
#  'Costume e società',
#  'Esteri',
#  'Mass media e spettacolo',
#  'Giustizia']

# %%
unique_affiliations = data.select('affiliation').unique().to_series().to_list()
print(unique_affiliations[:5])
# Out:
# ['Partito Comunista', 'Centro Democratico-Italiani In Europa-Europeisti-MAIE', 'Unione Popolare con De Magistris', 'Coraggio Italia-Idea e Cambiamo-Europeisti', 'SVP']

# %%
data.select('kind').unique().to_series().to_list()
# Out:
# ['Notizia', 'Parola']

# %%
data.select('duration').head(5).to_series().to_list()
# Out:
# [7, 42, 24, 25, 17]

# %%
data = data.with_columns((pl.col("name") + " " + pl.col("lastname")).alias("fullname"))
data
# Out:
# shape: (1_293_757, 11)
# ┌──────────┬─────────┬─────────────┬────────────┬───┬──────────┬─────────┬────────────┬────────────┐
# │ channel  ┆ program ┆ day         ┆ lastname   ┆ … ┆ duration ┆ kind    ┆ __index_le ┆ fullname   │
# │ ---      ┆ ---     ┆ ---         ┆ ---        ┆   ┆ ---      ┆ ---     ┆ vel_0__    ┆ ---        │
# │ str      ┆ str     ┆ datetime[ns ┆ str        ┆   ┆ i64      ┆ str     ┆ ---        ┆ str        │
# │          ┆         ┆ ]           ┆            ┆   ┆          ┆         ┆ i64        ┆            │
# ╞══════════╪═════════╪═════════════╪════════════╪═══╪══════════╪═════════╪════════════╪════════════╡
# │ CANALE 5 ┆ TG5     ┆ 2023-01-01  ┆ Azione-Ita ┆ … ┆ 7        ┆ Notizia ┆ 2          ┆ political  │
# │          ┆         ┆ 00:00:00    ┆ lia        ┆   ┆          ┆         ┆            ┆ movement   │
# │          ┆         ┆             ┆ Viva-Renew ┆   ┆          ┆         ┆            ┆ Azione-Ita │
# │          ┆         ┆             ┆ Europ…     ┆   ┆          ┆         ┆            ┆ l…         │
# │ CANALE 5 ┆ TG5     ┆ 2023-01-01  ┆ Berlusconi ┆ … ┆ 42       ┆ Notizia ┆ 3          ┆ Silvio     │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Berlusconi │
# │ CANALE 5 ┆ TG5     ┆ 2023-01-01  ┆ Conte      ┆ … ┆ 24       ┆ Notizia ┆ 4          ┆ Giuseppe   │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Conte      │
# │ CANALE 5 ┆ TG5     ┆ 2023-01-01  ┆ Letta      ┆ … ┆ 25       ┆ Notizia ┆ 5          ┆ Enrico     │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Letta      │
# │ CANALE 5 ┆ TG5     ┆ 2023-01-01  ┆ Renzi      ┆ … ┆ 17       ┆ Notizia ┆ 6          ┆ Matteo     │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Renzi      │
# │ …        ┆ …       ┆ …           ┆ …          ┆ … ┆ …        ┆ …       ┆ …          ┆ …          │
# │ TV8      ┆ TG8     ┆ 2021-01-30  ┆ Fontana    ┆ … ┆ 11       ┆ Parola  ┆ 30508      ┆ Attilio    │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Fontana    │
# │ TV8      ┆ TG8     ┆ 2021-01-30  ┆ Mattarella ┆ … ┆ 41       ┆ Parola  ┆ 30509      ┆ Sergio     │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Mattarella │
# │ TV8      ┆ TG8     ┆ 2021-01-31  ┆ Movimento  ┆ … ┆ 3        ┆ Notizia ┆ 30510      ┆ political  │
# │          ┆         ┆ 00:00:00    ┆ 5 Stelle   ┆   ┆          ┆         ┆            ┆ movement   │
# │          ┆         ┆             ┆            ┆   ┆          ┆         ┆            ┆ Movimento  │
# │          ┆         ┆             ┆            ┆   ┆          ┆         ┆            ┆ 5…         │
# │ TV8      ┆ TG8     ┆ 2021-01-31  ┆ Partito    ┆ … ┆ 4        ┆ Notizia ┆ 30511      ┆ political  │
# │          ┆         ┆ 00:00:00    ┆ Democratic ┆   ┆          ┆         ┆            ┆ movement   │
# │          ┆         ┆             ┆ o          ┆   ┆          ┆         ┆            ┆ Partito    │
# │          ┆         ┆             ┆            ┆   ┆          ┆         ┆            ┆ Dem…       │
# │ TV8      ┆ TG8     ┆ 2021-01-31  ┆ Renzi      ┆ … ┆ 27       ┆ Parola  ┆ 30512      ┆ Matteo     │
# │          ┆         ┆ 00:00:00    ┆            ┆   ┆          ┆         ┆            ┆ Renzi      │
# └──────────┴─────────┴─────────────┴────────────┴───┴──────────┴─────────┴────────────┴────────────┘

# %%
#divide political groups (var-->political_groups) and politicians (var-->politicians) in an array with names

political_groups = data.filter(pl.col("name") == "political movement").select("lastname").unique().to_series().to_list()

politicians = data.filter(pl.col("name") != "political movement").select("fullname").unique().to_series().to_list()

# %%
#find all values of all columns (var: channel, program, affiliation, topic) all arrays

channels = data.select('channel').unique().to_series().to_list()
programs = data.select('program').unique().to_series().to_list()
affiliations = data.select('affiliation').unique().to_series().to_list()
topics = data.select('topic').unique().to_series().to_list()

# %%
#how much a politician talked about all the possible topics (politicianTopics --> json variable {"topic", "minutes", "interventions"})

n = "Silvio Berlusconi"

x = data.filter(pl.col("fullname") == n)
politicianTopics = []

for t in topics:
  y = x.filter(pl.col("topic") == t)
  sum = y.select("duration").sum().to_series().to_list()
  politicianTopics.append({"topic": t, "minutes" : sum, "interventions" : y.shape[0]})


#how much a political group talked about all the possible topics (polGroupTopics --> json variable {"topic", "minutes", "interventions"})

m = "Azione-Italia Viva-Renew Europe"

w = data.filter(pl.col("lastname") == m)
polGroupTopics = []

for t in topics:
  z = w.filter(pl.col("topic") == t)
  sum = z.select("duration").sum().to_series().to_list()
  polGroupTopics.append({"topic": t, "minutes" : sum, "interventions" : z.shape[0]})

# %%
#how much a politician talked in a specific channel (politicianChannels --> json variable {"channel", "minutes", "interventions"})

n = "Silvio Berlusconi"

x = data.filter(pl.col("fullname") == n)
politicianChannels = []

for c in channels:
  y = x.filter(pl.col("channel") == c)
  sum = y.select("duration").sum().to_series().to_list()
  politicianChannels.append({"channel": c, "minutes" : sum, "interventions" : y.shape[0]})


#how much a political group talked about all the possible topics (polGroupTopics --> json variable {"topic", "minutes", "interventions"})

m = "Azione-Italia Viva-Renew Europe"

w = data.filter(pl.col("lastname") == m)
polGroupChannels = []

for c in channels:
  z = w.filter(pl.col("channel") == c)
  sum = z.select("duration").sum().to_series().to_list()
  polGroupChannels.append({"channel": c, "minutes" : sum, "interventions" : z.shape[0]})

# %%
#how many politicians participate (have participated) in every political group (politiciansAffiliation --> json variable {"affiliation", "politicians"[] })

politiciansAffiliation = []
y = data.filter(pl.col("name") != "political movement")

for a in affiliations:
  x = y.filter(pl.col("affiliation") == a)
  politiciansAffiliation.append({"affiliation": a, "politicians": x.select('fullname').unique().to_series().to_list()})

# %%
#how much a political group has intervened in tv (interventionsPoliticalGroup --> json variable {"affiliation", "interventions", "minutes"})

interventionsPoliticalGroup = []

for a in affiliations:
  x = data.filter(pl.col("affiliation") == a)
  sum = x.select("duration").sum().to_series().to_list()
  interventionsPoliticalGroup.append({"affiliation": a, "interventions": x.shape[0], "minutes": sum})

# %%
#how many political groups a politician have participated in (politicianPoliticalGroups[])

n = "Matteo Renzi"

x = data.filter(pl.col("fullname") == n)

politicianPoliticalGroups = x.select('affiliation').unique().to_series().to_list()

# %%
name = "Silvio Berlusconi"
politicians = data.filter(pl.col("name") != "political movement")

politician_channels = politicians.filter(pl.col('fullname') == name)
x = []

for c in channels:
    singleChannel = politician_channels.filter(pl.col('channel') == c)
    programsChannel = singleChannel.select('program').unique().to_series().to_list()
    arr = []
    for p in programsChannel:
        temp2 = singleChannel.filter(pl.col('program') == p)
        p1 = temp2.select('program').unique().to_series().to_list()
        total = temp2.select('duration').sum().to_series().to_list()
        arr.append({'program': p1[0], 'minutes': total[0]})
    x.append({'channel': singleChannel.select('channel').unique().to_series().to_list()[0], 'programs': arr})

final_list = {'politician': name, 'channels': x}
# Out:
# {'politician': 'Silvio Berlusconi',
#  'channels': [{'channel': 'NOVE',
#    'programs': [{'program': 'DEEJAY TG', 'minutes': 2965},
#     {'program': 'IL CELESTE ROBERTO FORMIGONI', 'minutes': 72},
#     {'program': 'UMBERTO B. IL SENATUR', 'minutes': 60},
#     {'program': 'SONO LE VENTI', 'minutes': 14},
#     {'program': 'I MIGLIORI FRATELLI DI CROZZA (TESTATA)', 'minutes': 5239},
#     {'program': 'ACCORDI & DISACCORDI (TESTATA)', 'minutes': 291},
#     {'program': 'FRATELLI DI CROZZA (RETE)', 'minutes': 6627},
#     {'program': 'FRATELLI DI CROZZA (TESTATA)', 'minutes': 6329},
#     {'program': 'I MIGLIORI FRATELLI DI CROZZA', 'minutes': 2001},
#     {'program': 'FRATELLI DI CROZZA CLASSIC (TESTATA)', 'minutes': 451},
#     {'program': 'I MIGLIORI FRATELLI DI CROZZA (RETE)', 'minutes': 3131}]},
#   {'channel': 'RTL102.5',
#    'programs': [{'program': 'RTL 102.5 GIORNALE ORARIO', 'minutes': 1220},
#     {'program': 'RTL 102.5 NEWS', 'minutes': 33}]},
#   {'channel': 'ITALIA 1',
#    'programs': [{'program': 'STUDIO APERTO LIVE', 'minutes': 282},
#     {'program': 'STUDIO APERTO - MAG', 'minutes': 113},
#     {'program': 'STUDIO APERTO LA GIORNATA', 'minutes': 24983},
#     {'program': 'STUDIO APERTO - EDIZIONE STRAORDINARIA', 'minutes': 242},
#     {'program': 'SPORT MEDIASET', 'minutes': 16},
#     {'program': 'STUDIO APERTO', 'minutes': 79709},
#     {'program': "C'E' SOLO UN PRESIDENTE", 'minutes': 1154},
#     {'program': 'MEDIASET TGCOM 24', 'minutes': 83},
#     {'program': 'STUDIO APERTO LA DOMENICA 18:30', 'minutes': 2088},
#     {'program': 'STUDIO APERTO LA DOMENICA 12:25', 'minutes': 2552},
#     {'program': "C'E' SOLO UN PRESIDENTE L'ULTIMO SALUTO", 'minutes': 35},
#     {'program': 'CARO PRESIDENTE...', 'minutes': 328}]},
#   {'channel': 'SKY TG 24 CAN. 50',
#    'programs': [{'program': 'SKY TG24 SPECIALE - VENEZIA SOMMERSA',
#      'minutes': 36},
#     {'program': 'SKY TG24 - CRISI APERTA', 'minutes': 1116},
#     {'program': 'SKY TG24 - BUONGIORNO', 'minutes': 1754},
#     {'program': 'SKY TG24 - DENTRO I FATTI, CON LE TUE DOMANDE',
#      'minutes': 1641},
#     {'program': 'SKY TG24 SPECIALE', 'minutes': 762},
#     {'program': 'SKY TG24 POMERIGGIO', 'minutes': 1212},
#     {'program': 'SKY TG24 - CASA ITALIA', 'minutes': 1732},
#     {'program': 'SKY TG24 - DIRETTA', 'minutes': 2535},
#     {'program': 'SKY TG24 - SILVIO BERLUSCONI 1936-2023', 'minutes': 67},
#     {'program': 'SEVEN - SPECIALE', 'minutes': 83},
#     {'program': 'SKY TG24 - SKYLINE', 'minutes': 1591},
#     {'program': 'CORSA AL COLLE', 'minutes': 14},
#     {'program': 'SKY TG24 - LA SFIDA DEL VOTO', 'minutes': 467},
#     {'program': 'SKY TG24 - SPECIALE REGIONI AL VOTO', 'minutes': 203},
#     {'program': 'SKY TG24 - VERSO IL GOVERNO', 'minutes': 274},
#     {'program': 'LO STATO SOCIAL', 'minutes': 35},
#     {'program': "TRIBU' - EUROPA 19", 'minutes': 3156},
#     {'program': "TRIBU'", 'minutes': 68},
#     {'program': 'SKY TG24 - GOVERNO MELONI', 'minutes': 810},
#     {'program': 'SKY TG24 SPECIALE - 2020 UN ANNO CHE NON DIMENTICHEREMO ITALIA',
#      'minutes': 32},
#     {'program': 'SKY TG24 - BUONGIORNO TELEGIORNALE', 'minutes': 6449},
#     {'program': 'SKY TG24 - TIMELINE', 'minutes': 580},
#     {'program': 'SKY TG24 - MATTINA', 'minutes': 2607},
#     {'program': 'ANTICIPAZIONI SKY TG24', 'minutes': 246},
#     {'program': 'SKY TG24 - AGENDA', 'minutes': 462},
#     {'program': 'SKY TG24', 'minutes': 161205},
#     {'program': 'SKY TG24 - I GIORNI DI CONTE', 'minutes': 814},
#     {'program': 'SKY TG24 - ITALIA 18', 'minutes': 4558},
#     {'program': 'SEVEN', 'minutes': 606},
#     {'program': 'SKY TG24 - START', 'minutes': 1528},
#     {'program': 'SKY TG24 EDICOLA', 'minutes': 14818},
#     {'program': 'SKY TG24 MONDO', 'minutes': 249},
#     {'program': 'SKY TG24 - RASSEGNA STAMPA', 'minutes': 49}]},
#   {'channel': 'RAI 2',
#    'programs': [{'program': 'QUELLI CHE ASPETTANO', 'minutes': 4},
#     {'program': 'TG2 FLASH', 'minutes': 1088},
#     {'program': 'RESTART (TESTATA)', 'minutes': 60},
#     {'program': 'NEMO - NESSUNO ESCLUSO - ANTEPRIMA (RETE)', 'minutes': 11},
#     {'program': "ANTEPRIMA CHE C'E' DI NUOVO", 'minutes': 28},
#     {'program': 'ANTICIPAZIONI TG2', 'minutes': 401},
#     {'program': 'SPECIALE TG2', 'minutes': 313},
#     {'program': 'TG2 - SPECIALE', 'minutes': 158},
#     {'program': 'TG2 - FRANKENSTEIN ALLE 10 IL MOSTRO IN PRIMA PAGINA',
#      'minutes': 74},
#     {'program': "MISTERI D'ITALIA", 'minutes': 27},
#     {'program': 'QUELLI CHE.... DOPO IL TG', 'minutes': 134},
#     {'program': 'IL CONFRONTO', 'minutes': 183},
#     {'program': 'BATTUTE?', 'minutes': 227},
#     {'program': 'RESTART (RETE)', 'minutes': 81},
#     {'program': 'TG2 POST', 'minutes': 4134},
#     {'program': 'NIGHT TABLOID (RETE)', 'minutes': 389},
#     {'program': 'RAI PARLAMENTO - TELEGIORNALE', 'minutes': 231},
#     {'program': 'TG2 ITALIA', 'minutes': 158},
#     {'program': 'RAI PARLAMENTO - SPECIALE', 'minutes': 774},
#     {'program': 'KRONOS - IL TEMPO DELLA SCELTA (TESTATA)', 'minutes': 1503},
#     {'program': 'TG2 PUNTO DI VISTA', 'minutes': 311},
#     {'program': 'NEMO - NESSUNO ESCLUSO (RETE)', 'minutes': 129},
#     {'program': 'POVERA PATRIA', 'minutes': 1689},
#     {'program': 'CHE TEMPO CHE FA', 'minutes': 21},
#     {'program': 'TG2', 'minutes': 50778},
#     {'program': 'TG2 (L.I.S.)', 'minutes': 560},
#     {'program': 'TG2 - DOSSIER', 'minutes': 953},
#     {'program': 'RAI PARLAMENTO - PUNTO EUROPA', 'minutes': 178},
#     {'program': 'QUELLI CHE IL CALCIO', 'minutes': 71},
#     {'program': 'POVERA PATRIA (TESTATA)', 'minutes': 1146},
#     {'program': 'POPOLO SOVRANO', 'minutes': 54}]},
#   {'channel': 'RETE 4',
#    'programs': [{'program': 'QUARTA REPUBBLICA ANTEPRIMA', 'minutes': 296},
#     {'program': 'DALLA VOSTRA PARTE VERSO IL VOTO', 'minutes': 6876},
#     {'program': 'TG4 SPECIALE ELEZIONI (TGCOM24)', 'minutes': 205},
#     {'program': 'STASERA ITALIA SPECIALE', 'minutes': 125},
#     {'program': 'CARO PRESIDENTE...', 'minutes': 328},
#     {'program': 'SPECIALE TG4', 'minutes': 1243},
#     {'program': 'MEDIASET TGCOM 24', 'minutes': 120},
#     {'program': 'STASERA ITALIA NEWS SPECIALE (VN)', 'minutes': 9},
#     {'program': 'TG4 - DIARIO DELLA DOMENICA', 'minutes': 56},
#     {'program': 'CR4 - LA REPUBBLICA DELLE DONNE REMIX', 'minutes': 33},
#     {'program': 'QUINTA COLONNA - ANTEPRIMA', 'minutes': 12},
#     {'program': 'STASERA ITALIA ESTATE (VN)', 'minutes': 499},
#     {'program': 'CONTROCORRENTE PRIMA SERATA', 'minutes': 1215},
#     {'program': 'FUORI DAL CORO (VN)', 'minutes': 1754},
#     {'program': 'ZONA BIANCA', 'minutes': 8160},
#     {'program': 'TG4 NIGHT NEWS', 'minutes': 32034},
#     {'program': 'ANTEPRIMA DRITTO E ROVESCIO', 'minutes': 1175},
#     {'program': 'CR4 - LA REPUBBLICA DELLE DONNE', 'minutes': 60},
#     {'program': 'STASERA ITALIA WEEKEND (VN)', 'minutes': 1821},
#     {'program': 'TG4 - DIARIO DEL GIORNO SPECIALE', 'minutes': 1202},
#     {'program': 'SPECIALE TG4 (NEWS MEDIASET)', 'minutes': 5230},
#     {'program': "ANTEPRIMA W L'ITALIA OGGI E DOMANI", 'minutes': 80},
#     {'program': 'STASERA ITALIA WEEKEND', 'minutes': 1021},
#     {'program': 'TG4 - DIARIO DEL GIORNO IL VERDETTO', 'minutes': 257},
#     {'program': "W L'ITALIA OGGI E DOMANI", 'minutes': 310},
#     {'program': 'TG4', 'minutes': 114035},
#     {'program': 'TG4 - EDIZIONE STRAORDINARIA', 'minutes': 236},
#     {'program': 'TG5', 'minutes': 2616},
#     {'program': 'STASERA ITALIA WEEKEND SPECIALE - CORONAVIRUS (VN)',
#      'minutes': 11},
#     {'program': 'CONTROCORRENTE', 'minutes': 7130},
#     {'program': 'QUINTA COLONNA', 'minutes': 5186},
#     {'program': 'TG4 - DIARIO DEL GIORNO', 'minutes': 931},
#     {'program': 'SPECIALE TG5', 'minutes': 5562},
#     {'program': 'SETTE GIORNI', 'minutes': 1309},
#     {'program': 'STASERA ITALIA SPECIALE (VN)', 'minutes': 303},
#     {'program': 'ANTICIPAZIONI TG4', 'minutes': 1758},
#     {'program': 'DRITTO E ROVESCIO', 'minutes': 8462},
#     {'program': 'STASERA ITALIA NEWS (VN)', 'minutes': 1565},
#     {'program': 'MATTINO CINQUE NEWS SPECIALE', 'minutes': 1176},
#     {'program': 'DALLA VOSTRA PARTE', 'minutes': 21},
#     {'program': 'QUARTA REPUBBLICA', 'minutes': 10130},
#     {'program': 'STASERA ITALIA', 'minutes': 2157},
#     {'program': 'DALLA VOSTRA PARTE ANCHE DI SABATO', 'minutes': 12},
#     {'program': "TG4 ULTIM'ORA", 'minutes': 20144},
#     {'program': 'STASERA ITALIA (VN)', 'minutes': 20844}]},
#   {'channel': 'RAI 1',
#    'programs': [{'program': 'TG1 60 SECONDI', 'minutes': 1406},
#     {'program': 'UNO MATTINA (RETE)', 'minutes': 36},
#     {'program': 'RAI PARLAMENTO - TELEGIORNALE', 'minutes': 26},
#     {'program': 'TG1 - ADDIO SILVIO', 'minutes': 224},
#     {'program': "OGGI E' UN ALTRO GIORNO (RETE)", 'minutes': 399},
#     {'program': 'LA VITA IN DIRETTA ESTATE (TESTATA)', 'minutes': 6},
#     {'program': 'RAI PARLAMENTO - PUNTO EUROPA', 'minutes': 145},
#     {'program': 'TG1 - I GIORNI DELLA CRISI', 'minutes': 602},
#     {'program': 'ANTEPRIMA PORTA A PORTA (RETE)', 'minutes': 692},
#     {'program': 'PRES. PORTA A PORTA (TESTATA)', 'minutes': 75},
#     {'program': 'ANTEPRIMA PORTA A PORTA (TESTATA)', 'minutes': 1170},
#     {'program': 'UNO MATTINA (TESTATA)', 'minutes': 3060},
#     {'program': 'TG1 - ESEQUIE DI STATO DI SILVIO BERLUSCONI', 'minutes': 27},
#     {'program': 'PORTA A PORTA (TESTATA)', 'minutes': 9097},
#     {'program': 'SPECIALE PORTA A PORTA (TESTATA)', 'minutes': 2184},
#     {'program': "PORTA A PORTA POLITICHE '22 (TESTATA)", 'minutes': 858},
#     {'program': 'SPECIALE TG1', 'minutes': 55},
#     {'program': 'TG1 (L.I.S.)', 'minutes': 2085},
#     {'program': 'SPECIALE PORTA A PORTA (RETE)', 'minutes': 540},
#     {'program': 'PORTA A PORTA 25 ANNI (RETE)', 'minutes': 483},
#     {'program': 'TG1 EDIZIONE STRAORDINARIA', 'minutes': 1990},
#     {'program': 'ANTEPRIMA LA VITA IN DIRETTA (RETE)', 'minutes': 22},
#     {'program': 'PORTA A PORTA (RETE)', 'minutes': 5809},
#     {'program': 'TG1', 'minutes': 88599},
#     {'program': "ITALIA SI'", 'minutes': 9},
#     {'program': 'TG1 MATTINA', 'minutes': 578},
#     {'program': 'CHE TEMPO CHE FA (TESTATA)', 'minutes': 1292},
#     {'program': 'CINQUE MINUTI', 'minutes': 129},
#     {'program': "OGGI E' UN ALTRO GIORNO (TESTATA)", 'minutes': 9},
#     {'program': 'ANTICIPAZIONI TG1', 'minutes': 244},
#     {'program': 'PETROLIO (RETE)', 'minutes': 5},
#     {'program': 'CHE TEMPO CHE FA (RETE)', 'minutes': 13},
#     {'program': 'ANTEPRIMA PORTA A PORTA 25 ANNI (RETE)', 'minutes': 12},
#     {'program': 'RAI PARLAMENTO - SETTEGIORNI', 'minutes': 9},
#     {'program': 'RAI CULTURA - GRANDI DISCORSI DELLA STORIA (RAI EDU)',
#      'minutes': 268},
#     {'program': 'LA VITA IN DIRETTA (RETE)', 'minutes': 263},
#     {'program': 'SPECIALE PORTA A PORTA ELEZIONI EUROPEE 2019 (TESTATA)',
#      'minutes': 757}]},
#   {'channel': 'CANALE 5',
#    'programs': [{'program': 'POMERIGGIO CINQUE', 'minutes': 1673},
#     {'program': 'DOMENICA LIVE - POLITICA', 'minutes': 17},
#     {'program': 'MATTINO CINQUE', 'minutes': 13623},
#     {'program': 'TG5', 'minutes': 194679},
#     {'program': "MATRIX E TG5: COSTANZO, L'UOMO CHE HA CAMBIATO LA TV",
#      'minutes': 245},
#     {'program': 'X-STYLE', 'minutes': 74},
#     {'program': 'ANTICIPAZIONI TG5', 'minutes': 983},
#     {'program': 'TG5 PRIMA PAGINA', 'minutes': 104280},
#     {'program': 'POMERIGGIO CINQUE - POLITICA', 'minutes': 1240},
#     {'program': "ANTEPRIMA LIVE NON E' LA D'URSO SPECIALE", 'minutes': 518},
#     {'program': 'MATTINO CINQUE - NEWS', 'minutes': 5110},
#     {'program': 'MAURIZIO COSTANZO SHOW', 'minutes': 2516},
#     {'program': 'POMERIGGIO CINQUE - ELEZIONI POLITICHE', 'minutes': 1283},
#     {'program': "POMERIGGIO CINQUE - L'ISOLA DEI FAMOSI", 'minutes': 13},
#     {'program': 'MORNING NEWS', 'minutes': 424},
#     {'program': 'MATRIX', 'minutes': 6378},
#     {'program': 'SPECIALE MAURIZIO COSTANZO SHOW 40', 'minutes': 25},
#     {'program': 'MATRIX PRIME - LA SFIDA DEI LEADER', 'minutes': 3503},
#     {'program': 'MATTINO CINQUE - SPECIALE CORONAVIRUS', 'minutes': 1429},
#     {'program': 'POMERIGGIO CINQUE SOCIAL', 'minutes': 977},
#     {'program': "LIVE NON E' LA D'URSO SPECIALE", 'minutes': 82},
#     {'program': 'TG5 EDIZIONE STRAORDINARIA', 'minutes': 69},
#     {'program': 'CARO PRESIDENTE...', 'minutes': 328},
#     {'program': 'DOMENICA LIVE', 'minutes': 3636},
#     {'program': 'MATTINO CINQUE NEWS - SPECIALE', 'minutes': 1176},
#     {'program': 'MATTINO CINQUE - SPECIALE ELEZIONI', 'minutes': 91},
#     {'program': 'POMERIGGIO CINQUE - SPECIALE ELEZIONI EUROPEE',
#      'minutes': 1458},
#     {'program': 'DOMENICA LIVE - ELEZIONI POLITICHE', 'minutes': 1996},
#     {'program': "L'INTERVISTA", 'minutes': 7},
#     {'program': 'SPECIALE TG5', 'minutes': 7223},
#     {'program': 'VUOI SCOMMETTERE?', 'minutes': 120},
#     {'program': 'MAURIZIO COSTANZO SHOW ALLEGRIA', 'minutes': 272}]},
#   {'channel': 'Rai Radio3',
#    'programs': [{'program': 'LA NOTTE DI RADIO3', 'minutes': 6},
#     {'program': 'GR 3', 'minutes': 90}]},
#   {'channel': 'Rai Radio2', 'programs': [{'program': 'GR 2', 'minutes': 42}]},
#   {'channel': 'Mediaset TgCom 24',
#    'programs': [{'program': 'TG5 (TGCOM24)', 'minutes': 177424},
#     {'program': 'MEDIASET TGCOM 24', 'minutes': 773479},
#     {'program': 'MEDIASET TGCOM 24 - ORE 12', 'minutes': 19810},
#     {'program': 'STASERA ITALIA NEWS (TGCOM24)', 'minutes': 84},
#     {'program': 'STASERA ITALIA WEEKEND (TGCOM24)', 'minutes': 9},
#     {'program': 'TG4 - DIARIO DEL GIORNO (TGCOM24)', 'minutes': 1188},
#     {'program': 'MATTINO CINQUE NEWS SPECIALE (TGCOM24)', 'minutes': 1111},
#     {'program': 'SPECIALE FATTI E MISFATTI', 'minutes': 13207},
#     {'program': 'MEDIASET TGCOM 24 - SPECIALE CONSULTAZIONI', 'minutes': 572},
#     {'program': 'TG5 NOTTE (TGCOM24)', 'minutes': 1312},
#     {'program': 'MORNING NEWS (TGCOM24)', 'minutes': 424},
#     {'program': 'TG4 - DIARIO DELLA DOMENICA (TGCOM24)', 'minutes': 56},
#     {'program': 'CONTROCORRENTE (TGCOM24)', 'minutes': 2406},
#     {'program': 'TG ECONOMY FLASH', 'minutes': 6},
#     {'program': 'TG ECONOMY', 'minutes': 180},
#     {'program': 'MEDIASET TGCOM 24 - ORE 18', 'minutes': 25383},
#     {'program': "C'E' SOLO UN PRESIDENTE", 'minutes': 1154},
#     {'program': 'TG4 - DIARIO DEL GIORNO SPECIALE (TGCOM24)', 'minutes': 1202},
#     {'program': 'MEDIASET TGCOM24 - NEWS LIVE', 'minutes': 1479},
#     {'program': 'QUARTA REPUBBLICA (TGCOM24)', 'minutes': 11},
#     {'program': 'MEDIASET TGCOM 24 - DENTRO I FATTI', 'minutes': 8367},
#     {'program': 'TG5 - EDIZIONE STRAORDINARIA (TGCOM24)', 'minutes': 25},
#     {'program': 'MEDIASET TGCOM 24 DIRETTA', 'minutes': 5965},
#     {'program': 'MATTINO CINQUE NEWS (TGCOM24)', 'minutes': 4072},
#     {'program': 'MATTINO CINQUE NEWS (TGCOM 24)', 'minutes': 273},
#     {'program': 'FATTI E MISFATTI', 'minutes': 6711},
#     {'program': "TG4 ULTIM'ORA (TGCOM24)", 'minutes': 33},
#     {'program': 'CHECK POINT', 'minutes': 86},
#     {'program': 'MEDIASET TGCOM 24 EDIZIONE SPECIALE', 'minutes': 14},
#     {'program': 'MEDIASET TGCOM 24 - DIRETTISSIMA', 'minutes': 19716},
#     {'program': 'TG4 - EDIZIONE STRAORDINARIA (TGCOM24)', 'minutes': 62},
#     {'program': 'STUDIO APERTO LA DOMENICA (TGCOM24)', 'minutes': 1489},
#     {'program': 'SPECIALE TG4 (TGCOM24)', 'minutes': 6678},
#     {'program': "C'E' SOLO UN PRESIDENTE L'ULTIMO SALUTO", 'minutes': 35},
#     {'program': 'TG5 PRIMA PAGINA (TGCOM24)', 'minutes': 109090},
#     {'program': 'MEDIASET TGCOM 24 - PRIMA SERATA', 'minutes': 869},
#     {'program': 'TG4 (TGCOM24)', 'minutes': 94370},
#     {'program': 'LE GRANDI INTERVISTE DI PAOLO DEL DEBBIO', 'minutes': 15},
#     {'program': 'STUDIO APERTO (TGCOM24)', 'minutes': 38239},
#     {'program': 'MEDIASET TGCOM 24 - OLTRE I FATTI', 'minutes': 276},
#     {'program': 'STASERA ITALIA (TGCOM24)', 'minutes': 2138},
#     {'program': 'MEDIASET TGCOM 24 - CARTE SCOPERTE', 'minutes': 81},
#     {'program': 'MEDIASET TGCOM 24 - RASSEGNA STAMPA', 'minutes': 1174},
#     {'program': 'STASERA ITALIA SPECIALE ELEZIONI (TGCOM24)', 'minutes': 116},
#     {'program': 'CAVOLETTI DA BRUXELLES', 'minutes': 448},
#     {'program': 'MEDIASET TGCOM 24 - WEB TV', 'minutes': 259},
#     {'program': "MATRIX E TG5: COSTANZO, L'UOMO CHE HA CAMBIATO LA TV",
#      'minutes': 245},
#     {'program': 'SPECIALE TG5 (TGCOM24)', 'minutes': 8985},
#     {'program': 'CARO PRESIDENTE... (TGCOM 24)', 'minutes': 1312},
#     {'program': 'MEDIASET TGCOM 24 - BREAKING NEWS', 'minutes': 4020},
#     {'program': 'TG5 MATTINA (TGCOM24)', 'minutes': 1427},
#     {'program': 'POMERIGGIO CINQUE - ELEZIONI POLITICHE (TGCOM24)',
#      'minutes': 1283},
#     {'program': 'STUDIO APERTO LIVE (TGCOM24)', 'minutes': 65},
#     {'program': 'MEDIASET TGCOM 24 SPECIALE', 'minutes': 16176},
#     {'program': 'DIRETTA DA STRASBURGO: PARLA SILVIO BERLUSCONI',
#      'minutes': 1091},
#     {'program': 'MEDIASET TGCOM 24 - OGGI A TGCOM 24', 'minutes': 5058},
#     {'program': 'TG5 GIORNO (TGCOM24)', 'minutes': 585},
#     {'program': 'DIRETTA DA ROMA: ASSEMBLEA NAZIONALE FORZA ITALIA',
#      'minutes': 3409},
#     {'program': 'SPORT MEDIASET - LA GIORNATA', 'minutes': 81},
#     {'program': 'STASERA ITALIA (TGCOM 24)', 'minutes': 28}]},
#   {'channel': 'LA7D',
#    'programs': [{'program': "NON È L'ARENA - IL MEGLIO DI \\(TESTATA\\)",
#      'minutes': 26},
#     {'program': 'TG LA7', 'minutes': 7567}]},
#   {'channel': 'TV8',
#    'programs': [{'program': 'SKY TG24', 'minutes': 12935},
#     {'program': 'IL CANDIDATO VA ALLE ELEZIONI (TESTATA)', 'minutes': 20},
#     {'program': 'SKY TG24 - BUONGIORNO', 'minutes': 1055},
#     {'program': 'SKY TG24 - BUONGIORNO TELEGIORNALE', 'minutes': 2950},
#     {'program': 'SKY TG24 - LA SFIDA DEL VOTO', 'minutes': 25},
#     {'program': 'ANTICIPAZIONI SKY TG24', 'minutes': 36},
#     {'program': "VENTI20: I VENT'ANNI DEL 2000", 'minutes': 245},
#     {'program': 'SKYTG24 - RASSEGNA STAMPA', 'minutes': 25},
#     {'program': 'OGNI MATTINA', 'minutes': 32},
#     {'program': 'SKY TG 24 EDICOLA (I)', 'minutes': 19},
#     {'program': 'SKY TG24 - MATTINA (I)', 'minutes': 1784},
#     {'program': "ANTEPRIMA VENTI20 I VENT'ANNI DEL 2000", 'minutes': 4},
#     {'program': 'OGNI MATTINA (TESTATA)', 'minutes': 67},
#     {'program': 'TG8', 'minutes': 738},
#     {'program': 'SKY TG24 - I GIORNI DI CONTE', 'minutes': 76},
#     {'program': 'ANTEPRIMA TG8', 'minutes': 19},
#     {'program': 'SKY TG24 - SILVIO BERLUSCONI 1936-2023', 'minutes': 4}]},
#   {'channel': 'CIELO',
#    'programs': [{'program': 'SKY TG24 - MATTINA (I)', 'minutes': 454},
#     {'program': 'SKY TG24 - BUONGIORNO', 'minutes': 588},
#     {'program': 'SKY TG24 - LA SFIDA DEL VOTO', 'minutes': 25},
#     {'program': 'SKY TG24', 'minutes': 8761},
#     {'program': 'SKY TG24 EDICOLA', 'minutes': 19},
#     {'program': 'SKY TG24 (I)', 'minutes': 22}]},
#   {'channel': 'RAINEWS',
#    'programs': [{'program': 'REGIONALI 2020 EMILIA ROMAGNA CALABRIA AL VOTO',
#      'minutes': 250},
#     {'program': 'RAI NEWS24 - STUDIO 24', 'minutes': 2309},
#     {'program': 'FILO DIRETTO - VERSO IL VOTO', 'minutes': 1469},
#     {'program': 'RAI NEWS24 - SABATO E DOMENICA 24', 'minutes': 938},
#     {'program': 'CLIP: VIDEO MESSAGGIO DI SILVIO BERLUSCONI', 'minutes': 1229},
#     {'program': 'RAI NEWS24 - STUDIO 24 - SPECIALE', 'minutes': 91},
#     {'program': 'RAI NEWS24 - IL TG DELLE 12.00', 'minutes': 2965},
#     {'program': 'FILO DIRETTO - IL VOTO DI FIDUCIA', 'minutes': 817},
#     {'program': 'RAINEWS 24 - OGGI E DOMANI', 'minutes': 1517},
#     {'program': 'FILO DIRETTO - VERSO IL GOVERNO', 'minutes': 118},
#     {'program': 'DIGITANGO - IL BALLO DELLE NOTIZIE IN RETE', 'minutes': 355},
#     {'program': 'RAI NEWS24 - SERA 24 OGGI E DOMANI', 'minutes': 141},
#     {'program': 'RAI NEWS24 - POMERIGGIO 24', 'minutes': 113},
#     {'program': 'RAI NEWS24 SPECIALE: ELEZIONI POLITICHE 2022',
#      'minutes': 310},
#     {'program': 'RAINEWS 24 - DOMANI IN PRIMA', 'minutes': 4656},
#     {'program': 'SPECIALE LA BUSSOLA', 'minutes': 21},
#     {'program': 'RAI NEWS24 - IL TG DELLE 8', 'minutes': 2826},
#     {'program': 'RAI NEWS24 - SABATO24', 'minutes': 165},
#     {'program': 'TELEGRAM', 'minutes': 939},
#     {'program': "RAI NEWS24 - IN UN'ORA", 'minutes': 194},
#     {'program': 'RAI NEWS24 - IL TG FLASH', 'minutes': 850},
#     {'program': 'ANTICIPAZIONI RAI NEWS', 'minutes': 50},
#     {'program': 'RAI NEWS - RASSEGNA STAMPA', 'minutes': 952},
#     {'program': 'RAI NEWS 24 (L.I.S.)', 'minutes': 3596},
#     {'program': 'RAI NEWS SPECIALE', 'minutes': 416},
#     {'program': 'RAI NEWS IN DIRETTA', 'minutes': 3693},
#     {'program': 'RAI NEWS24 - MATTINA 24', 'minutes': 159},
#     {'program': "FILO DIRETTO - L'ADDIO A SILVIO BERLUSCONI", 'minutes': 1707},
#     {'program': "RAI NEWS24 - E' GIA' DOMANI", 'minutes': 186},
#     {'program': 'RAI NEWS24 - #2020ADDIO', 'minutes': 73},
#     {'program': 'LA BUSSOLA', 'minutes': 1324},
#     {'program': 'RAI NEWS24 - QUEL CHE RESTA DEL GIORNO', 'minutes': 133},
#     {'program': 'PRIMO GIORNO DI SCUOLA - FORZA RAGAZZI', 'minutes': 39},
#     {'program': "RAI NEWS24 - E' GIA' DOMANI - ANTEPRIMA", 'minutes': 76},
#     {'program': 'RAI NEWS24 - SABATO E DOMENICA 24: SPECIALE ELEZIONI',
#      'minutes': 15},
#     {'program': 'SPECIALE TELEGRAM', 'minutes': 947},
#     {'program': 'RAI NEWS24 - IL TG DI MEZZANOTTE', 'minutes': 2805},
#     {'program': 'RAI NEWS24 - IL TG DELLE 18.00', 'minutes': 2550},
#     {'program': "CLIP: DICHIARAZIONE DI SILVIO BERLUSCONI DOPO L'INCONTRO CON IL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA",
#      'minutes': 346},
#     {'program': 'NEWS ROOM ITALIA', 'minutes': 934},
#     {'program': 'RAI NEWS24 - IL TG DELLA SERA', 'minutes': 5001},
#     {'program': 'RAI NEWS - ELEZIONI REGIONALI UMBRIA', 'minutes': 16},
#     {'program': 'RAI NEWS', 'minutes': 245541},
#     {'program': 'RAINEWS 24 - OGGI IN PRIMA', 'minutes': 2088},
#     {'program': 'FILO DIRETTO - IL NUOVO PARLAMENTO', 'minutes': 46},
#     {'program': 'FILO DIRETTO', 'minutes': 37}]},
#   {'channel': 'LA7',
#    'programs': [{'program': 'PROPAGANDA LIVE SPECIALE (TESTATA)',
#      'minutes': 31},
#     {'program': 'COFFEE BREAK ESTATE', 'minutes': 185},
#     {'program': 'PIAZZAPULITA - SENZA PACE (TESTATA)', 'minutes': 46},
#     {'program': 'TG LA7 SPECIALE', 'minutes': 4302},
#     {'program': "L'ARIA CHE TIRA IL DIARIO (TESTATA)", 'minutes': 14488},
#     {'program': 'TG LA7 - CRONACHE', 'minutes': 7},
#     {'program': 'COFFEE BREAK', 'minutes': 6096},
#     {'program': 'IN ONDA (TESTATA)', 'minutes': 1181},
#     {'program': 'LA CORSA AL VOTO', 'minutes': 133},
#     {'program': 'BERSAGLIO MOBILE (TESTATA)', 'minutes': 4554},
#     {'program': 'TAGADOC (TESTATA)', 'minutes': 203},
#     {'program': 'PIAZZAPULITA - VINCERE', 'minutes': 19},
#     {'program': "TAGADA' (TESTATA)", 'minutes': 13606},
#     {'program': "NON È L'ARENA - IL MEGLIO DI \\(TESTATA\\)", 'minutes': 46},
#     {'program': 'COFFEE BREAK SABATO', 'minutes': 191},
#     {'program': "L'ARIA CHE TIRA (TESTATA)", 'minutes': 17576},
#     {'program': 'ANTICIPAZIONI TG LA7', 'minutes': 21},
#     {'program': 'UOZZAP!', 'minutes': 2826},
#     {'program': 'ATLANTIDE - STORIE DI UOMINI E DI MONDI (TESTATA)',
#      'minutes': 88},
#     {'program': 'TG LA7 SPECIALE ELEZIONI 2019', 'minutes': 4},
#     {'program': 'VAR CONDICIO (TESTATA)', 'minutes': 675},
#     {'program': 'LA7 20 UN RACCONTO ITALIANO', 'minutes': 570},
#     {'program': "L'ARIA CHE TIRA ESTATE (TESTATA)", 'minutes': 1729},
#     {'program': 'PROPAGANDA THE MOVIE #UNESTATEFA (TESTATA)', 'minutes': 52},
#     {'program': 'ANTICAMERA CON VISTA (TESTATA)', 'minutes': 652},
#     {'program': "TAGADA' PRIMA PAGINA (TESTATA)", 'minutes': 8},
#     {'program': 'PIAZZAPULITA (TESTATA)', 'minutes': 944},
#     {'program': "L'ARIA CHE TIRA - OGGI (TESTATA)", 'minutes': 17234},
#     {'program': 'OMNIBUS LA7 (TESTATA)', 'minutes': 12256},
#     {'program': "TG LA7 L'ULTIMA PAROLA", 'minutes': 98},
#     {'program': 'ANTEPRIMA TG LA7', 'minutes': 3444},
#     {'program': 'PIAZZAPULITA 00 (TESTATA)', 'minutes': 33},
#     {'program': "ASPETTANDO TAGADA' (TESTATA)", 'minutes': 60},
#     {'program': 'LA7 RICORDA', 'minutes': 74},
#     {'program': "L'ARIA CHE TIRA ESTATE - OGGI (TESTATA)", 'minutes': 2567},
#     {'program': "NON È L'ARENA \\(TESTATA\\)", 'minutes': 2643},
#     {'program': "L'ARIA CHE TIRA SPECIALE - OGGI (TESTATA)", 'minutes': 70},
#     {'program': 'IN ONDA PRIMA SERATA (TESTATA)', 'minutes': 316},
#     {'program': "DIMARTEDI' (TESTATA)", 'minutes': 1926},
#     {'program': 'TG LA7 SPECIALE ELEZIONI 2018', 'minutes': 9},
#     {'program': 'TG LA7 DIARIO POLITICO', 'minutes': 2662},
#     {'program': 'PROPAGANDA LIVE - CORSI DI RECUPERO (TESTATA)',
#      'minutes': 150},
#     {'program': 'PROPAGANDA LIVE BEST (TESTATA)', 'minutes': 289},
#     {'program': "L'ARIA CHE TIRA ESTATE IL DIARIO (TESTATA)", 'minutes': 944},
#     {'program': 'PROPAGANDA LIKE (TESTATA)', 'minutes': 34},
#     {'program': 'PROPAGANDA LIVE SPECIAL (TESTATA)', 'minutes': 178},
#     {'program': "DI MARTEDIPIU' (TESTATA)", 'minutes': 72},
#     {'program': 'OTTO E MEZZO (TESTATA)', 'minutes': 5636},
#     {'program': 'UOZZAP! COLLEZIONE AUTUNNO INVERNO', 'minutes': 768},
#     {'program': 'TG LA7', 'minutes': 63364},
#     {'program': "NON È L'ARENA SPECIALE \\(TESTATA\\)", 'minutes': 47},
#     {'program': "L'ARIA CHE TIRA SPECIALE (TESTATA)", 'minutes': 85},
#     {'program': 'FACCIA A FACCIA (MINOLI)', 'minutes': 2262},
#     {'program': "L'ARIA CHE TIRA - ORE 13 (TESTATA)", 'minutes': 71},
#     {'program': "ANTEPRIMA TAGADA' (TESTATA)", 'minutes': 328},
#     {'program': 'TG LA7 EDIZIONE STRAORDINARIA', 'minutes': 15},
#     {'program': 'PROPAGANDA LIVE (TESTATA)', 'minutes': 2636},
#     {'program': "TAGADA' - #FOCUS (TESTATA)", 'minutes': 307},
#     {'program': 'CAMERA CON VISTA (TESTATA)', 'minutes': 3122}]},
#   {'channel': 'SKY TG24',
#    'programs': [{'program': 'SKY TG24 - BUONGIORNO', 'minutes': 1754},
#     {'program': 'SKY TG24 - CASA ITALIA', 'minutes': 1732},
#     {'program': 'SKY TG24 - CRISI APERTA', 'minutes': 1116},
#     {'program': 'SKY TG24 - DIRETTA', 'minutes': 2535},
#     {'program': 'SKY TG24 - ITALIA 18', 'minutes': 4558},
#     {'program': 'SKY TG24 - MATTINA', 'minutes': 2607},
#     {'program': 'SKY TG24 - RASSEGNA STAMPA', 'minutes': 49},
#     {'program': 'SKY TG24 SPECIALE - VENEZIA SOMMERSA', 'minutes': 36},
#     {'program': 'SKY TG24 SPECIALE', 'minutes': 762},
#     {'program': 'SKY TG24 - AGENDA', 'minutes': 462},
#     {'program': 'SKY TG24 POMERIGGIO', 'minutes': 1212},
#     {'program': 'SKY TG24 - BUONGIORNO TELEGIORNALE', 'minutes': 6449},
#     {'program': 'SKY TG24 - TIMELINE', 'minutes': 580},
#     {'program': 'ANTICIPAZIONI SKY TG24', 'minutes': 246},
#     {'program': 'SEVEN', 'minutes': 606},
#     {'program': 'SKY TG24 - START', 'minutes': 1528},
#     {'program': 'SKY TG24 - GOVERNO MELONI', 'minutes': 810},
#     {'program': 'SKY TG24 - I GIORNI DI CONTE', 'minutes': 814},
#     {'program': 'SKY TG24 EDICOLA', 'minutes': 14818},
#     {'program': 'LO STATO SOCIAL', 'minutes': 35},
#     {'program': 'SKY TG24 MONDO', 'minutes': 249},
#     {'program': "TRIBU' - EUROPA 19", 'minutes': 3156},
#     {'program': 'SKY TG24 - VERSO IL GOVERNO', 'minutes': 274},
#     {'program': "TRIBU'", 'minutes': 68},
#     {'program': 'SKY TG24', 'minutes': 161205},
#     {'program': 'SKY TG24 - SKYLINE', 'minutes': 1591},
#     {'program': 'SKY TG24 - DENTRO I FATTI, CON LE TUE DOMANDE',
#      'minutes': 1641},
#     {'program': 'SKY TG24 - LA SFIDA DEL VOTO', 'minutes': 467},
#     {'program': 'CORSA AL COLLE', 'minutes': 14},
#     {'program': 'SKY TG24 - SPECIALE REGIONI AL VOTO', 'minutes': 203},
#     {'program': 'SEVEN - SPECIALE', 'minutes': 83},
#     {'program': 'SKY TG24 SPECIALE - 2020 UN ANNO CHE NON DIMENTICHEREMO ITALIA',
#      'minutes': 32},
#     {'program': 'SKY TG24 - SILVIO BERLUSCONI 1936-2023', 'minutes': 67}]},
#   {'channel': 'Rai Radio1',
#    'programs': [{'program': 'GR 1', 'minutes': 355},
#     {'program': 'IL GIORNALE DELLA MEZZANOTTE', 'minutes': 6},
#     {'program': 'UN GIORNO DA PECORA', 'minutes': 8}]},
#   {'channel': 'RAI 3',
#    'programs': [{'program': 'ANTEPRIMA REPORT (RETE)', 'minutes': 51},
#     {'program': "ANTEPRIMA AGORA' (RETE)", 'minutes': 582},
#     {'program': 'REPORT (RETE)', 'minutes': 806},
#     {'program': "AGORA' EXTRA (TESTATA)", 'minutes': 67},
#     {'program': 'ANTEPRIMA AGORÀ ESTATE \\(TESTATA\\)', 'minutes': 195},
#     {'program': 'REPORT (TESTATA)', 'minutes': 196},
#     {'program': "ANTEPRIMA AGORA' SPECIALE (RETE)", 'minutes': 35},
#     {'program': 'LE PAROLE DELLA SETTIMANA (RETE)', 'minutes': 9},
#     {'program': 'TG3', 'minutes': 41571},
#     {'program': 'FRONTIERE (RETE)', 'minutes': 23},
#     {'program': '#CARTABIANCA ORE 18.30 (TESTATA)', 'minutes': 179},
#     {'program': 'QUANTE STORIE (TESTATA)', 'minutes': 105},
#     {'program': 'OSSI DI SEPPIA QUELLO CHE RICORDIAMO', 'minutes': 8},
#     {'program': '#CARTABIANCA ORE 18.30 (RETE)', 'minutes': 164},
#     {'program': 'RAI EDUCATIONAL - TV TALK', 'minutes': 259},
#     {'program': '#CARTABIANCA (RETE)', 'minutes': 1263},
#     {'program': 'TG3 EDIZIONE STRAORDINARIA', 'minutes': 1651},
#     {'program': '#CARTABIANCA (TESTATA)', 'minutes': 3810},
#     {'program': "AGORA' SPECIALE (RETE)", 'minutes': 44},
#     {'program': "AGORA' WEEKEND (TESTATA)", 'minutes': 28},
#     {'program': "1/2H IN PIU' (RETE)", 'minutes': 496},
#     {'program': 'CHE SUCC3DE?', 'minutes': 51},
#     {'program': "BLOB DI TUTTO DI PIU' (TESTATA)", 'minutes': 545},
#     {'program': 'SPECIALE TG PARLAMENTO', 'minutes': 25},
#     {'program': 'PRESADIRETTA (TESTATA)', 'minutes': 6},
#     {'program': "AGORA' ESTATE (RETE)", 'minutes': 426},
#     {'program': "AGORA' SPECIALE (TESTATA)", 'minutes': 15},
#     {'program': "AGORA' EXTRA (RETE)", 'minutes': 248},
#     {'program': 'BLOB 30', 'minutes': 2761},
#     {'program': 'LE PAROLE (RETE)', 'minutes': 29},
#     {'program': 'FRONTIERE', 'minutes': 22},
#     {'program': 'IL CAVALLO E LA TORRE (RETE)', 'minutes': 610},
#     {'program': 'CHE SUCC3DE? 2 (RETE)', 'minutes': 2},
#     {'program': "AGORA' WEEKEND (RETE)", 'minutes': 50},
#     {'program': "AGORA' (TESTATA)", 'minutes': 6126},
#     {'program': "AGORA' ESTATE (TESTATA)", 'minutes': 293},
#     {'program': "L'APPRODO", 'minutes': 9},
#     {'program': 'RAI EDUCATIONAL - TV TALK (TESTATA)', 'minutes': 48},
#     {'program': 'AGORÀ ESTATE \\(TESTATA\\)', 'minutes': 377},
#     {'program': "BLOB DI TUTTO DI PIU' (RETE)", 'minutes': 8121},
#     {'program': 'TG3 (L.I.S.)', 'minutes': 1527},
#     {'program': 'CHE TEMPO CHE FA (RETE)', 'minutes': 601},
#     {'program': 'RAI PARLAMENTO - TELEGIORNALE', 'minutes': 96},
#     {'program': 'QUANTE STORIE (RETE)', 'minutes': 95},
#     {'program': 'LE RAGAZZE', 'minutes': 30},
#     {'program': 'LE PAROLE PER DIRLO', 'minutes': 35},
#     {'program': "AGORA' ESTATE EXTRA (TESTATA)", 'minutes': 5},
#     {'program': 'TG3 LINEA NOTTE', 'minutes': 584},
#     {'program': "AGORA' (RETE)", 'minutes': 4822},
#     {'program': 'PRESADIRETTA (RETE)', 'minutes': 35},
#     {'program': 'LA SCELTA', 'minutes': 65},
#     {'program': "ANTEPRIMA AGORA' ESTATE (RETE)", 'minutes': 75},
#     {'program': 'MI MANDA RAITRE (RETE)', 'minutes': 9},
#     {'program': "1/2H IN PIU' (TESTATA)", 'minutes': 2895},
#     {'program': 'TG3 SPECIALE', 'minutes': 1871},
#     {'program': 'LA MIA PASSIONE', 'minutes': 59}]}]}
