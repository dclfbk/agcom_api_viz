# %%
import polars as pl
import os
import warnings
import json
warnings.filterwarnings('ignore')
from datetime import datetime
import datetime as dt

# %%
data = pl.read_parquet(".." + os.sep + ".." + os.sep + "docs"  + os.sep +  "data" + os.sep + "agcomdata.parquet")

# %%
data.columns
# Out:
# ['channel',
#  'program',
#  'day',
#  'lastname',
#  'name',
#  'affiliation',
#  'topic',
#  'duration',
#  'kind',
#  '__index_level_0__']

# %%
data.select('channel').unique().to_series().to_list()
# Out:
# ['RTL102.5',
#  'RAINEWS',
#  'LA7',
#  'Rai Radio2',
#  'Mediaset TgCom 24',
#  'CIELO',
#  'LA7D',
#  'Rai Radio1',
#  'RAI 2',
#  'TV8',
#  'RAI 3',
#  'NOVE',
#  'SKY TG 24 CAN. 50',
#  'Rai Radio3',
#  'RAI 1',
#  'RETE 4',
#  'ITALIA 1',
#  'SKY TG24',
#  'CANALE 5']

# %%
data.select('program').unique().to_series().to_list()
# Out:
# ["FILO DIRETTO UCRAINA - I DUE VOLTI DELL'EUROPA",
#  'RAI 1 E TG1 - SPECIALE PORTA A PORTA - ELEZIONI 2018 (RETE)',
#  'TIKI TAKA SPECIALE',
#  'POPOLO SOVRANO',
#  'STASERA ITALIA SPECIALE (VN)',
#  'TUTTI A SCUOLA (TESTATA)',
#  'TG5 GIORNO (TGCOM24)',
#  'ANTEPRIMA DOMENICA LIVE',
#  'SKY TG24 - E-VENTI',
#  'SPECIALE MAFIA LA RICERCA DELLA VERITÀ',
#  'RAI NEWS24 SPECIALE: 24 AGOSTO 2016 - LA SCOSSA INFINITA',
#  'SPECIALE TG1 - UCRAINA',
#  'TG4 SPECIALE ELEZIONI (TGCOM24)',
#  "TG2 - RELAZIONE ANNUALE AL PARLAMENTO DELL'AUTORITÀ DI REGOLAZIONE PER ENERGIA, RETI E AMBIENTE",
#  'UN GIORNO DA PECORA',
#  'POVERA PATRIA (TESTATA)',
#  "TG5 - L'ARCA DI NOÈ",
#  'ELEZIONI 2020 - VERSO IL VOTO',
#  'ANNI 20 - ANTEPRIMA',
#  'GENOVA SAN GIORGIO - PONTE ITALIANO',
#  'AGORÀ WEEKEND (RETE)',
#  'FILO DIRETTO UCRAINA - I GIORNI DEL CONFLITTO',
#  'TGR - SPECIALE ANNIVERSARIO PONTE MORANDI',
#  'SKY TG24 SPECIALE: CORONAVIRUS - INTO THE RED ZONE',
#  'TRA POCO LIVE',
#  'UNO MATTINA - IL CAFFÈ DI RAIUNO (TESTATA)',
#  'TG1: LE CONSULTAZIONI',
#  'FACCIA A FACCIA (MINOLI)',
#  'SKY TG24 - REGIONALI 2023: SPECIALE LAZIO E LOMBARDIA',
#  'VOX POPULI',
#  'SKY TG24 - LA SFIDA DEL COVID',
#  'UNO MATTINA PER TELETHON (RETE)',
#  'SPECIALE TG4 - ADDIO ELISABETTA (TGCOM24)',
#  'MATTINO CINQUE NEWS - I SALUTI (TGCOM 24)',
#  'SPECIALE TG4 (TGCOM24)',
#  'UOZZAP! CLASSIC',
#  'RAI NEWS24 SPECIALE - PIAZZA GRANDE',
#  'OTTO E MEZZO SABATO - ANTEPRIMA (TESTATA)',
#  'ANTEPRIMA AGORÀ SPECIALE (RETE)',
#  'A SUA IMMAGINE',
#  'TG LA7 SPECIALE ELECTION DAY',
#  'TG1 ECONOMIA',
#  'SKY TG24 - START: GENERAZIONE EUROPA',
#  "NON � L'ARENA (TESTATA)",
#  'LE PAROLE PER DIRLO',
#  'FORMATO FAMIGLIA',
#  'CHE TEMPO CHE FA RICORDA MAURIZIO COSTANZO',
#  'TG1 DIRETTA - MONICA, PER SEMPRE',
#  'GRANDE FRATELLO 15',
#  "TG4 - L'ALMANACCO DI RETEQUATTRO",
#  'ESTATE IN DIRETTA',
#  'SKY TG24 SPECIALE - IL ROGO DI NOTRE DAME',
#  'CLIP: MESSAGGIO DI FINE ANNO DEL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA',
#  'TG1 SPECIALE - LA DECISIONE DEL QUIRINALE',
#  'CLIP: LE ELEZIONI IN FRIULI VENEZIA GIULIA',
#  "MATRIX E TG5: COSTANZO, L'UOMO CHE HA CAMBIATO LA TV",
#  'CLIP: ORVIETO TERRITORIO DI CONFINE',
#  'SKYTG24 - RASSEGNA STAMPA',
#  'VOLO ITAVIA 870',
#  'TG1 EDIZIONE SPECIALE',
#  "CLIP: DICHIARAZIONE DI LUIGI DI MAIO DOPO L'INCONTRO CON IL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA",
#  'MEDIASET TGCOM 24 - DENTRO I FATTI SPECIALE ELEZIONI 2018',
#  'MAURIZIO COSTANZO SHOW - BUONANOTTE',
#  'STUDIO APERTO LIVE',
#  'RAI EDUCATIONAL - TV TALK EXTRA',
#  'CASA ITALIA',
#  'DOMENICA IN (RETE)',
#  'DOMENICA REWIND',
#  'TG1 - LE CONSULTAZIONI DI DRAGHI',
#  'ANTEPRIMA PRESADIRETTA (RETE)',
#  'REPORT (RETE)',
#  'RAI NEWS24 SPECIALE: LE CARTE IN REGOLA - PIERSANTI MATTARELLA',
#  'FILOROSSO (TESTATA)',
#  "PRESENTAZIONE 104° EDIZIONE GIRO D'ITALIA",
#  'SKY TG24 - ITALIA 18 ON THE ROAD',
#  'LA BUSSOLA CORONAVIRUS',
#  'RAI NEWS24 - IL TG DI MEZZANOTTE',
#  'CLIP: ELEZIONI REGIONALI EMILIA ROMAGNA 2020 - TESTIMONIANZE E PROSPETTIVE DI VOTO',
#  'SKY TG24 SPECIALE',
#  'OGNI MATTINA',
#  'AGORÀ (TESTATA)',
#  'MI MANDA RAITRE IN + (TESTATA)',
#  'TGR - LA GIOSTRA DELLA QUINTANA',
#  'DIMARTEDÌ (TESTATA)',
#  '1/2H IN PIÙ (TESTATA)',
#  'I MIGLIORI FRATELLI DI CROZZA (RETE)',
#  'OSSI DI SEPPIA QUELLO CHE RICORDIAMO',
#  'IL CAVALLO E LA TORRE (TESTATA)',
#  "CLIP: FASE 2 DELL'EMERGENZA CORONAVIRUS E POSSIBILI CAMBIAMENTI NEL TRASPORTO PUBBLICO LOCALE",
#  'ANTEPRIMA POMERIGGIO CINQUE',
#  'LA GRANDE STORIA',
#  'STUDIO APERTO - EDIZIONE STRAORDINARIA',
#  'RAI NEWS24 DIRETTA',
#  'CAMPIONATI DEL MONDO DI SCI ALPINO 2021: CERIMONIA DI APERTURA',
#  'SPECIALE ELEZIONI POLITICHE 2018 (TESTATA)',
#  'RAI NEWS24 - POST COVID19: SI PUÒ FARE!',
#  'LE PAROLE (TESTATA)',
#  'TG2 FLASH',
#  'IL CONFRONTO',
#  'TELEGRAM SPECIALE ELEZIONI',
#  'CONTROCORRENTE SPECIALE SALUTI',
#  'TG1 ELECTION DAY',
#  'CHE TEMPO CHE FA',
#  'STASERA ITALIA SPECIALE - ANTEPRIMA (TGCOM24)',
#  'LA CONFESSIONE (TESTATA)',
#  'IL TERREMOTO - IRPINIA 1980',
#  'POMERIGGIO CINQUE',
#  'PRESADIRETTA (RETE)',
#  "CHE C'È DI NUOVO",
#  'SPECIALE TG5',
#  'CLIP: CATANIA TRA I COMUNI AL VOTO IL PROSSIMO 10 GIUGNO 2018',
#  'RAI PARLAMENTO - SPECIALE CAMERA',
#  'TG2 SPECIALE - COMUNI AL VOTO',
#  'RAI PIPOL LO SPETTACOLO SIETE NOI (TESTATA)',
#  'SPECIALE PREMIO BIAGIO AGNES',
#  'CHIAMATELA MAFIA',
#  'SKY TG24 - SKYLINE',
#  "PRESENTAZIONE 103° EDIZIONE GIRO D'ITALIA",
#  'ITALIA SÌ',
#  "TG1: DAVID SASSOLI - L'OMAGGIO DEL PARLAMENTO EUROPEO",
#  'COME CI SI VEDRÀ DOPO - TERRORISMO. LE STORIE DELLE VITTIME',
#  'TG1 - IL GIORNO DEL PRESIDENTE',
#  'I FATTI VOSTRI',
#  'I MIGLIORI FRATELLI DI CROZZA (TESTATA)',
#  'SKY TG24 - LEZIONI DI VOTO',
#  'SPECIALE TG2 - 100 ANNI DI STORIA',
#  'ANTEPRIMA LA VITA IN DIRETTA ESTATE (TESTATA)',
#  'FESTIVAL DEL CINEMA ITALIANO',
#  "L'ASSEDIO (RETE)",
#  'VIVAVOCE',
#  'SKY TG24 - CRISI APERTA',
#  'AGORÀ SPECIALE (TESTATA)',
#  "SKY TG24 - RACCONTI D'ITALIA",
#  'TECHE TELETHON',
#  'I DIECI COMANDAMENTI',
#  'NON STOP NEWS',
#  'TG LA7 EDIZIONE STRAORDINARIA',
#  'PROTESTANTESIMO',
#  'SPECIALE TG4 - PONTE SAN GIORGIO LA RINASCITA DI GENOVA',
#  'ANTEPRIMA amore ESTATE (TESTATA)',
#  'RAI PARLAMENTO - SETTEGIORNI',
#  'TG2 (L.I.S.)',
#  'SKY TG24 - ITALIA 18',
#  'STASERA ITALIA SPECIALE CORONAVIRUS (VN)',
#  'ANNI 20 NOTTE (RETE)',
#  'RAI PARLAMENTO E TG2 - SPECIALE IL COLLE PIÙ ALTO',
#  'RAI NEWS - ANTEPRIMA SPECIALE I GIORNI DEL QUIRINALE',
#  'MATRIX',
#  '#CARTABIANCA ORE 18.30 (TESTATA)',
#  'UOZZAP!',
#  "RAI NEWS24 SPECIALE: QUEL GIORNO A CODOGNO - L'ANNO DEL VIRUS",
#  'CLIP: EMERGENZA VALLE DEL SACCO',
#  'REALITI SIAMO TUTTI PROTAGONISTI',
#  'PREMIO LE MASCHERE DEL TEATRO ITALIANO',
#  'REGIONALI 2020 EMILIA ROMAGNA CALABRIA AL VOTO',
#  'RAI NEWS24 - IL TG DELLE 18.00',
#  'TG4 SPECIALE ELEZIONI',
#  'QUINTA COLONNA',
#  'ORE 14 LIGHT (RETE)',
#  'STUDIO APERTO - EDIZIONE STRAORDINARIA (TGCOM24)',
#  'STASERA ITALIA SPECIALE OGGI (VN)',
#  'TG2 - SPECIALE',
#  'SPECIALE TG2 POST',
#  'MORNING NEWS (TGCOM24)',
#  'PRES. DOMENICA LIVE',
#  'DIGITANGO - IL BALLO DELLE NOTIZIE IN RETE',
#  "NON � L'ARENA (RETE)",
#  'CHE TEMPO CHE FA (TESTATA)',
#  'SOTTOVOCE',
#  'ANTEPRIMA RESTART (RETE)',
#  'ANTEPRIMA FILOROSSO SPECIALE (RETE)',
#  'SEVEN - SPECIALE',
#  'CHE SUCC3DE? 2 (TESTATA)',
#  'MEDIASET TGCOM 24 - WEB TV',
#  'FILOROSSO SPECIALE (RETE)',
#  'M (RETE)',
#  'TG1 E RAI 1 - UNO MATTINA SPECIALE ELEZIONI 2018 (RETE)',
#  'MI MANDA RAITRE EXTRA (RETE)',
#  'MATTINO CINQUE NEWS SPECIALE',
#  'RAI NEWS24 - IL TG DELLE 12.00',
#  'CLIP: INTERVISTA AL SINDACO DI VERONA FEDERICO SBOARINA',
#  'CLIP: CONFERENZE STAMPA DEI VARI LEADER POLITICI',
#  "CHI L'HA VISTO? 11:30 (TESTATA)",
#  'RAI CULTURA - CONCERTO ANNIVERSARIO ROMA CAPITALE',
#  'REPORT (TESTATA)',
#  'FUORI DAL CORO (VN)',
#  'PRESADIRETTA SABATO (RETE)',
#  'MEDIASET TGCOM 24 - PRIMA SERATA',
#  'TG1 E PORTA A PORTA - SPECIALE SERGIO MATTARELLA LA CONFERMA (RETE)',
#  'FILO DIRETTO - I GIORNI DELLA CRISI',
#  'QUELLI CHE IL CALCIO',
#  'STASERA ITALIA SPECIALE - I SALUTI',
#  "CHI L'HA VISTO? (RETE)",
#  'SKY TG24 - VERSO IL GOVERNO',
#  'MESSAGGIO DEL PRES. REPUBBLICA SERGIO MATTARELLA ANNIVERSARIO FONDAZIONE VENEZIA',
#  'VENTI20... QUASI 21',
#  'TG2 DOSSIER',
#  'PIAZZAPULITA - SENZA PACE (TESTATA)',
#  'ASPETTANDO GEO',
#  'DIRETTA DA ROMA: ASSEMBLEA NAZIONALE FORZA ITALIA',
#  'TG3 - NEL MONDO',
#  'IL NUOVO PONTE DI GENOVA - ORGOGLIO ITALIANO',
#  'PRES. COSTA CONCORDIA: CRONACA DI UN DISASTRO',
#  'ABBATTIAMOLI',
#  'SKY TG24 SPECIALE: GENOVA PER NOI - UN ANNO DOPO',
#  'MORNING NEWS',
#  '5 MINUTI CON...',
#  "HASHTAG 24 - L'ATTUALITÀ CONDIVISA",
#  'POMERIGGIO CINQUE - ELEZIONI POLITICHE (TGCOM24)',
#  'TG1 - CERIMONIA DI INAUGURAZIONE ANNO GIUDIZIARIO',
#  'GENERAZIONE BELLEZZA',
#  "L'ITALIA CHE FA",
#  'TG1 E PORTA A PORTA - SPECIALE CHI SARÀ IL PRESIDENTE? (RETE)',
#  'ORE 14 LIGHT (TESTATA)',
#  'RAI NEWS24 - FUTURO 24 VIAGGIO VERSO IL DOMANI',
#  'LA MIA PASSIONE',
#  'MATTINO CINQUE I SALUTI',
#  'VOXPOPULI',
#  'TG5 PRIMA PAGINA (TGCOM24)',
#  "LIVE NON � LA D'URSO",
#  'MAURIZIO COSTANZO SHOW ALLEGRIA',
#  'TG3 EDIZIONE STRAORDINARIA',
#  'LA PUPA E IL SECCHIONE E VICEVERSA - STAGIONE 1',
#  'PRONTO CIRINNÀ',
#  'STATI GENERALI REMIX 2019-2020',
#  'CLIP: VIDEO MESSAGGIO DI SILVIO BERLUSCONI',
#  'FATTI E MISFATTI',
#  'TG LA7 DIARIO POLITICO',
#  'O ANCHE NO',
#  'CAMERA CON VISTA (TESTATA)',
#  'AGORÀ ESTATE EXTRA (TESTATA)',
#  'MATTINO CINQUE NEWS (TGCOM24)',
#  'ATLANTIDE FILES (TESTATA)',
#  'SANREMO 2021 - 71 Festival della Canzone Italiana',
#  'TG3 SPECIALE - RAI PARLAMENTO',
#  'SKY TG24 - I GIORNI DI CONTE',
#  'ANTEPRIMA AGORÀ (TESTATA)',
#  "NON � L'ARENA - IL MEGLIO DI (TESTATA)",
#  'TGR - PIAZZA AFFARI',
#  "SPECIALE PORTA A PORTA - L'ITALIA UNITA CE LA FARÀ",
#  'FELICITÀ',
#  'CAMMINA ITALIA',
#  'MILLEEUNLIBRO - SCRITTORI IN TV',
#  'SKY TG24 - LIVE IN BARI',
#  'CHE SUCC3DE? GAME',
#  'RAZZA UMANA',
#  'PRES. ACCORDI & DISACCORDI (TESTATA)',
#  'BELVE AFTER',
#  'CHE TEMPO CHE FA - IL TAVOLO',
#  "NON È L'ARENA - IN PIAZZA A MEZZOJUSO (TESTATA)",
#  'TG5 EDIZIONE STRAORDINARIA',
#  'FRATELLI DI CROZZA (RETE)',
#  'RAI PARLAMENTO - SPECIALE SENATO',
#  'SPECIALE TG4 - DIARIO DELLA CRISI',
#  'FILO DIRETTO - IL VOTO DI FIDUCIA',
#  'MEDIASET TGCOM24 CLIP: DOMENICA LIVE INTERVISTA A GENTILONI',
#  "W L'ITALIA OGGI E DOMANI",
#  'SKY TG24 - GOVERNO MELONI',
#  'SKYTG24 SPECIALE: SCACCO AL BOSS',
#  'PORTA A PORTA 25 ANNI (RETE)',
#  'ZEROVIRGOLA',
#  'DRITTO E ROVESCIO...E OLTRE ANTEPRIMA',
#  "PIAZZAPULITA - L'INGANNO",
#  'QUARTA REPUBBLICA ANTEPRIMA',
#  'GR 1 - FOCUS ECONOMIA',
#  'STASERA ITALIA - ANTEPRIMA',
#  'SKY TG24 SPECIALE - città AL VOTO (I)',
#  'FRONTIERE',
#  'RAI NEWS 24 - FOCUS 24',
#  'DOMENICA LIVE - POLITICA',
#  'STASERA ITALIA WEEKEND SPECIALE - CORONA VIRUS',
#  'CORSA AL COLLE',
#  'MI MANDA RAITRE (TESTATA)',
#  "ANTEPRIMA W L'ITALIA OGGI E DOMANI",
#  'TGR: PALIO DE LA MARCILIANA',
#  'PRES. PORTA A PORTA (RETE)',
#  'MATTINO CINQUE - NEWS I SALUTI',
#  'UOZZAP! COLLEZIONE AUTUNNO INVERNO',
#  'DRITTO E ROVESCIO OFF',
#  'PROPAGANDA LIKE (TESTATA)',
#  'FILO DIRETTO - IL NUOVO GOVERNO',
#  'QUARTA REPUBBLICA - SPECIALE (TGCOM24)',
#  'QUARTA REPUBBLICA AL VOTO (TGCOM24)',
#  "SKY TG24 - L'OSPITE",
#  'CONVENTION REPUBBLICANA - LE NOTTI DI TRUMP',
#  'TG2 SPECIALE GOVERNO',
#  'MATTINO CINQUE - NEWS 2021',
#  'CHE TEMPO CHE FA (RETE)',
#  'IN VACANZA CON VIVA RAI 2!',
#  "W L'ITALIA",
#  'SPECIALE TG1',
#  'NEMO - NESSUNO ESCLUSO (RETE)',
#  'VUOI SCOMMETTERE-',
#  'RTL 102.5 GIORNALE ORARIO',
#  'ANTEPRIMA LE PAROLE DELLA SETTIMANA (TESTATA)',
#  'GUSTIBUS',
#  'STASERA ITALIA WEEKEND SPECIALE (VN)',
#  'MATTINO CINQUE NEWS - ELEZIONI',
#  'RAI NEWS24 SPECIALE: COVID 19 - DOMANDE E RISPOSTE',
#  'ANTEPRIMA CONTROCORRENTE PRIMA SERATA',
#  'DALLA VOSTRA PARTE',
#  'PREMIO LE MASCHERE DEL TEATRO ITALIANO (TESTATA)',
#  'CHE TEMPO CHE FARÀ',
#  'COSTA CONCORDIA: CRONACA DI UN DISASTRO',
#  'amore ESTATE (TESTATA)',
#  'SPECIALE TG4 - LA CARICA DEI NUOVI SINDACI (TGCOM)',
#  'PIACERE MAISANO',
#  'DOMENICA LIVE - ULTIMA SORPRESA',
#  'TGR SPECIALE',
#  'TG1 DIRETTA - 50° ANNIVERSARIO DELLA STRAGE DI PIAZZA FONTANA',
#  'CINQUE MINUTI',
#  'TG4 - DIARIO DEL GIORNO SPECIALE (TGCOM24)',
#  'LA NOTTE DEL GIGLIO',
#  "VENTI20: I VENT'ANNI DEL 2000",
#  'ANTEPRIMA LE PAROLE (RETE)',
#  'RAI NEWS24: GENOVA ANNO UNO',
#  'SKY TG24 - LIVE IN FIRENZE',
#  'OGNI MATTINA (TESTATA)',
#  'SKY TG24 SPECIALE: CORSIA DI EMERGENZA',
#  'RAI CULTURA - BINARIO 21',
#  'ANTEPRIMA STASERA ITALIA WEEKEND (VN)',
#  'TG1 E RAI QUIRINALE: FESTA DELLA LIBERAZIONE',
#  "24MM L'APPROFONDIMENTO",
#  'LA TV DELLE RAGAZZE - GLI STATI GENERALI',
#  'COFFEE BREAK REWIND',
#  'TG1 - FUNERALI RAFFAELLA CARRÀ',
#  'POMERIGGIO CINQUE - SPECIALE CORONAVIRUS',
#  "RAI CULTURA - GIOVANNI FALCONE C'ERA UNA VOLTA A PALERMO",
#  'QUARTA REPUBBLICA SPECIALE',
#  'TG4 - EDIZIONE STRAORDINARIA',
#  'RAI PARLAMENTO - SPAZIOLIBERO',
#  'SKY TG24 - LIVE IN TERNI',
#  'HIT THE ROAD MAN',
#  'ANTEPRIMA LE IENE PRESENTANO UN ANNO DI COVID',
#  'PIAZZAPULITA 00 (TESTATA)',
#  'STASERA ITALIA SPECIALE (TGCOM24)',
#  'PIAZZAPULITA - I FUORILEGGE',
#  "L'ARIA CHE TIRA SPECIALE (TESTATA)",
#  "I DIRITTI AL TEMPO DELL'ALGORITMO",
#  'RAI NEWS24 - REGIONALI 2023: FRIULI VENEZIA GIULIA',
#  'IN ONDA PRIMA SERATA (TESTATA)',
#  'TG4 SPECIALE ELEZIONI (NEWS MEDIASET)',
#  'RAI NEWS24 - PRIMA DI DOMANI',
#  'LE CARTE IN REGOLA',
#  'TG1 - I GIORNI DEL GOVERNO',
#  'SPECIALE TG2',
#  'TG3 - SPECIALE ELEZIONI EUROPEE 2019',
#  'GIOVANE EUROPA',
#  'RAI NEWS REPORTAGE: LA DEPURAZIONE DELLA DISCORDIA',
#  "TG1 - L'INCARICO",
#  'SPECIALE CHE GIORNO �',
#  'ANTEPRIMA FILOROSSO (RETE)',
#  'RAI NEWS24 SPECIALE: ELEZIONI POLITICHE 2022',
#  'TG1 - INAUGURAZIONE DEL BOSCO DELLA MEMORIA',
#  'QUARTA REPUBBLICA I SALUTI',
#  'ANTEPRIMA amore ESTATE SPECIALE',
#  'RAI NEWS24 - REGIONALI 2023: LOMBARDIA E LAZIO',
#  'TGR - ESTOVEST',
#  'PRES. RAI EDUCATIONAL - TV TALK (TESTATA)',
#  'SPORTELLO ITALIA',
#  'LA VITA IN DIRETTA (TESTATA)',
#  'SKY TG 24 EDICOLA (I)',
#  'UMBERTO B. IL SENATUR',
#  'MEDIASET TGCOM24 - INSIEME JUNTOS',
#  'UNO MATTINA ESTATE - SPECIALE',
#  'RAI EDUCATIONAL - TV TALK ANTEPRIMA (TESTATA)',
#  "L'ARIA CHE TIRA ESTATE - OGGI (TESTATA)",
#  'MATRIX SPECIALE',
#  "UNA MATTINA D'AGOSTO",
#  'GR1',
#  "SPECIALE UNA MATTINA D'AGOSTO (TESTATA)",
#  'OGGI È UN ALTRO GIORNO (RETE)',
#  'RAI NEWS24 - TG SPECIALE',
#  'SPECIALE TG2 - ELEZIONI 2018',
#  'RAI NEWS24 - SABATO24',
#  'TRIBÙ',
#  'ORE 14 (TESTATA)',
#  'RAINEWS 24 - OGGI IN PRIMA',
#  'MEDIASET TGCOM 24 - SERA',
#  'SPECIALE ATLANTIDE - STORIE DI UOMINI E DI MONDI (TESTATA)',
#  '#ANNEFRANK LA STANZA ANTEPRIMA',
#  'STASERA ITALIA SPECIALE - ANTEPRIMA (VN)',
#  'CR4 - LA REPUBBLICA DELLE DONNE REMIX',
#  'IL DIARIO DI ANNA ',
#  "CLIP: L'AQUILA DIECI ANNI DOPO",
#  'TGR - PALIO DELLA MARCILIANA',
#  'SKY TG24 - AMERICA 2020',
#  'ACCORDI & DISACCORDI (RETE)',
#  'SPECIALE TG5 - REGIONALI 2020 (TGCOM24)',
#  "L'ARIA CHE TIRA SPECIALE #NOTTEPRIMADEGLIESAMI (TESTATA)",
#  "CLIP: DICHIARAZIONE DI MATTEO SALVINI DOPO L'INCONTRO CON IL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA",
#  "LIVE NON È LA D'URSO SPECIALE NATALE",
#  'CRIMINI DEL CUORE',
#  'QUANTE STORIE (RAI 3)',
#  'TG1 - CERIMONIA COMMEMORAZIONE VITTIME PONTE MORANDI',
#  'REPORT PLUS (RETE)',
#  'TG2 - MOTORI',
#  'STASERA ITALIA WEEKEND',
#  '100 OPERE TORNANO A CASA',
#  'SKY TG24 - FUORICAMPO',
#  'TG2 - REGATA STORICA DI VENEZIA',
#  'RAI PARLAMENTO',
#  'MATRIX CHIAMBRETTI',
#  'BLOB 30',
#  'RAI CULTURA - PROVINCIA CAPITALE',
#  "SKY TG24 - IL PAESE CHE NON C'È",
#  'MEDIASET TGCOM 24 - ORE 18',
#  'CLIP: FEMMINICIDI IN ITALIA - DATI ANNO 2022',
#  'TG1 (L.I.S.)',
#  'QUARTA REPUBBLICA AL VOTO',
#  'PRES. STASERA ITALIA (VN)',
#  'GENERAZIONE GIOVANI',
#  "RADICI - L'ALTRA FACCIA DELL'IMMIGRAZIONE",
#  'TG1 - FUNERALI DELLE VITTIME DELLA STRAGE DI RAVENUSA',
#  'RAI NEWS24 SPECIALE: A UN PASSO DALLA CRISI',
#  'TG LA7',
#  "RAI NEWS 24 - FOCUS 24 UN'ESTATE ITALIANA",
#  'AGORÀ SPECIALE EXTRA (RETE)',
#  'MEDIASET TGCOM 24 - CARTE SCOPERTE',
#  "1948 L'ANNO CHE CAMBIÒ L'ITALIA",
#  'QUANTE STORIE (RETE)',
#  'RAI NEWS SPECIALE',
#  'MORNING NEWS SALUTI FINALI (TGCOM24)',
#  'RAI NEWS24 - #2021ADDIO',
#  'ANTEPRIMA REPORT (RETE)',
#  'SPECIALE #CARTABIANCA (RETE)',
#  'CHECK POINT',
#  'TG5 (TGCOM24)',
#  'ORE 14',
#  'SKY TG24 - SILVIO BERLUSCONI 1936-2023',
#  'IL CANDIDATO VA ALLE ELEZIONI (TESTATA)',
#  'TG5 SPECIALE ELEZIONI',
#  'VIAGGIO NELLA CHIESA DI FRANCESCO',
#  'RAI NEWS SPECIALE L.I.S.',
#  'LE IENE PRESENTANO UN ANNO DI COVID',
#  'CIAO MASCHIO',
#  'MATTINO CINQUE SPECIALE - LE STORIE',
#  'MI MANDA RAITRE IN + (RETE)',
#  'TG1: VERSO IL GOVERNO',
#  'SALUTI DA CORTINA E DAI MONDIALI DI SCI',
#  'POMERIGGIO CINQUE NEWS (TGCOM24)',
#  'ANTEPRIMA TG LA7',
#  'PRES. STASERA ITALIA ESTATE',
#  "SPECIALE FRONTIERE - L'ANGELA SOPRA BERLINO (TESTATA)",
#  "BERGAMO D'IMPROVVISO",
#  'FUORI DAL CORO - ASPETTANDO FUORI DAL CORO (VN)',
#  'RAI NEWS - SPECIALE ELEZIONI EUROPEE 2019',
#  'PETROLIO SPECIALE',
#  'ANTEPRIMA #CARTABIANCA (RETE)',
#  'SKY TG24 - CASA ITALIA',
#  'TG3 - MONDO',
#  "FATTI E MISFATTI D'EUROPA",
#  'RAI NEWS24 - QUEL CHE RESTA DEL GIORNO',
#  'SKY TG24 - BUSINESS',
#  'RAI PARLAMENTO - SPECIALE',
#  'STOP AND GO',
#  'SKY TG24 (I)',
#  'TG4 - EDIZIONE STRAORDINARIA (TGCOM24)',
#  'ANTICAMERA CON VISTA (TESTATA)',
#  'PIAZZAPULITA (TESTATA)',
#  'TG1: LAZIO E LOMBARDIA AL VOTO',
#  'PIAZZAPULITA - PRIMA IO',
#  'RAI PARLAMENTO - TELEGIORNALE MAGAZINE',
#  'CLIP: PRINCIPALI EVENTI POLITICI ITALIANI DEL 2021',
#  'FUORIROMA (TESTATA)',
#  'TG2 - PREMIO DE SANCTIS',
#  'TG2 - REGATA STORICA DI VENEZIA 2021 (TESTATA)',
#  'IN PRIMA FILA',
#  'RAI NEWS 24 - IL NUOVO GOVERNO',
#  "ANTEPRIMA LIVE NON È LA D'URSO",
#  'ANTICIPAZIONI TG LA7',
#  'SPECIALE PORTA A PORTA (TESTATA)',
#  'MATTINO CINQUE NEWS LIFE',
#  'SPECIALE PORTA A PORTA - ELEZIONI 2020 (TESTATA)',
#  'MEDIASET TGCOM 24 - OGGI A TGCOM 24',
#  "L'ARIA DI DOMENICA (TESTATA)",
#  'ANTEPRIMA TG8',
#  'MESSAGGIO DI FINE ANNO DEL PRESIDENTE DELLA REPUBBLICA SERGIO MATTARELLA',
#  'TG2',
#  'FACE TO FACE - IL SALONE DELLA GIUSTIZIA',
#  'TG3 - SPECIALE ELEZIONI',
#  'ANTEPRIMA PRESADIRETTA (TESTATA)',
#  'RAI NEWS24 SPECIALE - ELEZIONI AMMINISTRATIVE',
#  'PREMIO CAMOMILLA - WOMEN FOR WOMEN AGAINST VIOLENCE',
#  'TG SPORT',
#  'TG5 SPECIALE',
#  'ANTEPRIMA TG1 E PORTA A PORTA - SPECIALE CHI SARÀ IL PRESIDENTE? (RETE)',
#  'ANTEPRIMA RAI EDUCATIONAL - TV TALK',
#  'SPECIALE SONO LE VENTI',
#  'MEDIASET TGCOM 24 - RASSEGNA STAMPA',
#  'SKY TG24 SPECIALE - LA SETE DEL PO',
#  "RAI NEWS24 SPECIALE: GIORNATA DELLA MEMORIA E DELL'IMPEGNO - VITTIME INNOCENTI",
#  'RAI NEWS 24 - FOCUS 24 SPECIALE',
#  'CROZZA NEL PAESE DELLE MERAVIGLIE (TESTATA)',
#  'ITALIA SÌ! SPECIALE',
#  'LA VITA IN DIRETTA ESTATE (TESTATA)',
#  'STASERA ITALIA SPECIALE ELEZIONI (TGCOM24)',
#  'AMICI DI MARIA DE FILIPPI - STAGIONE 20',
#  'QUARTA REPUBBLICA - VINCITORI E VINTI',
#  'COFFEE BREAK ESTATE',
#  'SEMBRA IERI - CRONACA E STORIA',
#  'POMERIGGIO CINQUE SPECIALE ELEZIONI 2018',
#  "MEZZ'ORA IN PIÙ - IL MONDO CHE VERRÀ (TESTATA)",
#  'ITALIA SÌ! PODIO E POI',
#  'PETROLIO FILES (TESTATA)',
#  'CLIP: INTERVISTA A LAURA BOLDRINI',
#  'MEDIASET TGCOM 24 - BREAKING NEWS',
#  'COSE NOSTRE',
#  'SKY TG24 - BUONGIORNO',
#  'CONTROCORRENTE PRIMA SERATA SALUTI',
#  "TG4 ULTIM'ORA (TGCOM24)",
#  'MEDIASET TGCOM 24 TOUR',
#  'SKY TG24 POMERIGGIO',
#  'ANTEPRIMA LA VITA IN DIRETTA ESTATE (RETE)',
#  'GR 3',
#  'ROAD TO CORTINA 2021',
#  'STASERA ITALIA NEWS (VN)',
#  'UOZZAP! COLLEZIONE PRIMAVERA ESTATE',
#  'RAI NEWS: VOTO DEL 4 MARZO - I COLLEGI',
#  'PREMIO CIMITILE - XXV EDIZIONE',
#  'OGGI È UN ALTRO GIORNO SHORT (TESTATA)',
#  'SECONDA LINEA (RETE)',
#  'LO STATO SOCIAL',
#  'QUARTA REPUBBLICA (TGCOM24)',
#  'PROPAGANDA LIVE BEST (TESTATA)',
#  'SKY TG24 - BUONGIORNO TELEGIORNALE',
#  'SKY TG24 MONDO',
#  'ITALIA SOTTO INCHIESTA',
#  'TG SPORT SPECIALE',
#  "SKY TG24 - LA NOTTE DELL'EUROPA 2019",
#  'MATRIX - SPECIALE ELEZIONI EUROPEE',
#  'CONTROCORRENTE (TGCOM24)',
#  'SIAMO ANCORA FUORI DAL CORO (VN)',
#  'TG4 - DIARIO DI GUERRA',
#  'SKY TG24 - SALUTE TRADITA',
#  'STASERA ITALIA SPECIALE ELEZIONI (VN)',
#  'FILOROSSO',
#  'UNIVERSIADI ESTIVE NAPOLI 2019',
#  'TG2 - FRANKENSTEIN ALLE 10 IL MOSTRO IN PRIMA PAGINA',
#  'PETROLIO (RETE)',
#  'MATTINO CINQUE NEWS - SPECIALE',
#  'MISS ITALIA 2018',
#  'SPECIALE PORTA A PORTA ELEZIONI EUROPEE 2019 (TESTATA)',
#  'SONO LE VENTI',
#  'PORTA A PORTA SPECIALE ELEZIONI (TESTATA)',
#  'UNO MATTINA - SPECIALE (RETE)',
#  'TGR EDIZIONE STRAORDINARIA',
#  'POMERIGGIO CINQUE - ASPETTANDO LA PASQUA',
#  'SPORT MEDIASET',
#  'FILO DIRETTO - IL NUOVO PARLAMENTO',
#  'PRES. ATLANTIDE - STORIE DI UOMINI E DI MONDI',
#  'ORE 14 (RETE)',
#  'CHE TEMPO CHE FA - IL TAVOLO (RETE)',
#  'TG1: GIORNATA DELLA LEGALITÀ',
#  'TRIBÙ - EUROPA 19',
#  'VERISSIMO - GIRI DI VALZER',
#  'IN BARBA A TUTTO',
#  "RAI NEWS24 - LO STATO DELL'UNIONE",
#  'TG1',
#  'TG2 - DOSSIER',
#  'TG2 - SPECIALE BALLOTTAGGI',
#  'TG3 SPECIALE ELEZIONI POLITICHE 2018',
#  "UNIVERSIADI ESTIVE NAPOLI 2019: CERIMONIA D'APERTURA",
#  'TG1 E RAI QUIRINALE: IN RICORDO DI DON DIANA',
#  'TGR - IL SETTIMANALE ESTATE',
#  'STASERA ITALIA NEWS SPECIALE I SALUTI (VN)',
#  'INDOVINA CHI VIENE A CENA',
#  'ANTEPRIMA SALVINOLOGY - TUTTI I VOLTI DI MATTEO',
#  'ANTEPRIMA LA VITA IN DIRETTA (TESTATA)',
#  'BLOB DI TUTTO DI PIÙ (RETE)',
#  'STASERA ITALIA SPECIALE',
#  'SKY TG24 - TIMELINE',
#  'ANTEPRIMA DRITTO E ROVESCIO',
#  'TG ECONOMY',
#  'MATRIX SPECIALE ELEZIONI',
#  'CLIP: INTERVISTA A MARCO MINNITI',
#  'CLIP: TRAPANI TRA I COMUNI AL VOTO IL PROSSIMO 10 GIUGNO 2018',
#  'TG2 - COSTUME E SOCIETÀ',
#  'SKY TG24 - CONTE BIS',
#  'TG LA7 SPECIALE: NOTTE AMERICANA - TRUMP O BIDEN',
#  'ANTICIPAZIONI TG5',
#  'AGORÀ ESTATE EXTRA (RETE)',
#  'AGORÀ STRENNE (RETE)',
#  'PORTA A PORTA (RETE)',
#  'ANTICIPAZIONI TG2',
#  'CLIP: TRAPANI - INTERVISTE AI CANDIDATI ALLE PROSSIME ELEZIONI COMUNALI',
#  "L'APPRODO",
#  'DALLA VOSTRA PARTE VERSO IL VOTO',
#  'FUORIROMA (RETE)',
#  'VERMICINO 40 ANNI DOPO',
#  'MATRIX PRIME',
#  'TG4 - DIARIO DEL GIORNO IL VERDETTO',
#  "RAI PARLAMENTO - CERIMONIA CELEBRATIVA DEL CENTENARIO DELL'AULA DI MONTECITORIO",
#  "VITE - L'ARTE DEL POSSIBILE",
#  "RADIO ANCH'IO",
#  'CARO PRESIDENTE... (TGCOM 24)',
#  'CLIP: MONTE SOLE (BOLOGNA) - CELEBRAZIONI DEL 25 APRILE 2022',
#  "TG2 - TUTTO IL BELLO CHE C'È",
#  'TG3 - FUORI TG',
#  "PRES. SPECIALE MEZZ'ORA IN PIÙ - IL MONDO CHE VERRÀ (RETE)",
#  'VIVA RAI 2!',
#  'RAI NEWS24 - POMERIGGIO 24',
#  'LA SCELTA',
#  'LA MALAEDUCAXXXION',
#  'INFERNO SULLA TERRA',
#  'ATLANTIDE - STORIE DI UOMINI E DI MONDI (TESTATA)',
#  'STASERA ITALIA ESTATE',
#  'RAI NEWS SPECIALE - ELEZIONI 2021 I BALLOTTAGGI',
#  'TG2 - PROCIDA CAPITALE DELLA CULTURA 2022',
#  'TG2 - SPECIALE ELEZIONI 2022',
#  'STORIE ITALIANE (RETE)',
#  "PRIMA DELL'ALBA",
#  "RICETTE ALL'ITALIANA ESTATE",
#  'TG PARLAMENTO - VERSO IL REFERENDUM',
#  'LA VITA IN DIRETTA SHORT (RETE)',
#  'KRONOS - IL TEMPO DELLA SCELTA (TESTATA)',
#  'TG1 DIALOGO',
#  'STASERA ITALIA NEWS SPECIALE (VN)',
#  'ASPETTANDO LE PAROLE',
#  'PARLAMENTANDO',
#  'SKY TG24 - IL CONFRONTO',
#  'A RACCONTARE COMINCIA TU',
#  'TG1 SPECIALE - È CRISI',
#  'SKY TG24 SPECIALE - città AL VOTO',
#  'CHECKPOINT',
#  'SKY TG24 SPECIALE - SANITÀ MALATA',
#  'IL CASO CUCCHI (2009-2019, UNA RICOSTRUZIONE TELEVISIVA)',
#  'ANTEPRIMA PORTA A PORTA (RETE)',
#  "IL VELENO NELL'ACQUA",
#  'MATTINO CINQUE - SPECIALE CORONAVIRUS',
#  'ANTEPRIMA PIAZZAPULITA (TESTATA)',
#  'ANNI 20 ESTATE',
#  'DOMENICA IN - I SALUTI DI MARA (RETE)',
#  'SKY TG24 - I FATTI DEL 2018',
#  'SKY TG24 SPECIALE - BERLINO 89',
#  'REPORT CULT (RETE)',
#  'RAI NEWS24 SPECIALE - ELEZIONI 2018',
#  'QUELLI CHE',
#  'TG1 E RAI VATICANO: PREGHIERA PER LA PACE',
#  'TG1 DIRETTA: GIORNATA INTERNAZIONALE DELLA DONNA',
#  'RAI NEWS IN DIRETTA',
#  'A SUA IMMAGINE - SPECIALE',
#  'PALIO DI SIENA 2019',
#  'CHE GIORNO È',
#  'AGORÀ ESTATE (RETE)',
#  'SPECIALE MAURIZIO COSTANZO SHOW 40',
#  'RAI NEWS24 - STUDIO 24 - ANTEPRIMA',
#  'LE RAGAZZE',
#  'I MIGLIORI FRATELLI DI CROZZA',
#  'RAZZISTI, PERCHÈ-',
#  'SKY TG24 - ELECTION DAY',
#  'LA7 RICORDA',
#  "SKY TG24 ECONOMIA - L'INTERVISTA DI SARAH VARETTO",
#  'SPECIALE STORIE ITALIANE (RETE)',
#  'ZONA BIANCA (TGCOM24)',
#  'RAI NEWS',
#  'LA NOTTE AMERICANA (VN)',
#  'INVIATO SPECIALE',
#  'IL MEGLIO DEL PAESE DELLE MERAVIGLIE (TESTATA)',
#  'STUDIO APERTO - MAG',
#  'CARO MARZIANO (RETE)',
#  'TG1 E RAI PARLAMENTO EDIZIONE SPECIALE',
#  'SETTE STORIE (RETE)',
#  'SKY TG24 - SPECIALE REGIONI AL VOTO',
#  'RAI 1 E TG1 - SPECIALE PORTA A PORTA - ELEZIONI 2018 (TESTATA)',
#  'STASERA ITALIA (TGCOM 24)',
#  'QUARTA REPUBBLICA - SPECIALE QUIRINALE',
#  'ANTEPRIMA POMERIGGIO CINQUE NEWS (TGCOM24)',
#  'SKY TG24 - DENTRO I FATTI, CON LE TUE DOMANDE',
#  'ASPETTANDO LA VITA IN DIRETTA ESTATE (TESTATA)',
#  'RAI NEWS - SPECIALE PRIMARIE PD',
#  'RAI NEWS 24 (L.I.S.)',
#  'X-STYLE',
#  'SPECIALE TG5 (TGCOM24)',
#  'ANTEPRIMA CHE TEMPO CHE FA (TESTATA)',
#  "SPECIALE MEZZ'ORA IN PIÙ - IL MONDO CHE VERRÀ (RETE)",
#  'RAI NEWS24 - SABATO E DOMENICA 24',
#  'STASERA ITALIA WEEKEND (TGCOM24)',
#  'SKY TG24 - EUROPEE 2019',
#  'MEDIASET TGCOM 24 - SPECIALE ELEZIONI',
#  'UNO MATTINA IN FAMIGLIA (RETE)',
#  'MAREMMA FELIX',
#  'TECHETECHETÈ - IL MEGLIO DELLA TV',
#  'RAI NEWS - SPECIALE I GIORNI DEL QUIRINALE',
#  'PRESADIRETTA (TESTATA)',
#  'ORE 14 LIVE',
#  'MATRIX SPECIALE ELEZIONI EUROPEE',
#  'MAURIZIO COSTANZO SHOW 40',
#  'PROPAGANDA LIVE SPECIAL (TESTATA)',
#  'REPORT CULT (TESTATA)',
#  'BATTUTE-',
#  'RAI CULTURA - SENATO & CULTURA',
#  'CLANDESTINO',
#  'RAI NEWS24 - SABATO24 SPECIALE QUIRINALE',
#  "ZEFFIRELLI L'ULTIMO SOGNO",
#  'TG1 E RAI QUIRINALE - CELEBRAZIONE DEL 77° ANNIVERSARIO DELLA LIBERAZIONE',
#  'CLIP: LA BONIFICA SOVRANISTA DI GIORGIO SANTELLI',
#  'TG1 - COMUNICAZIONI ALLA CAMERA DEL PRESIDENTE DEL CONSIGLIO DEI MINISTRI',
#  "ANTEPRIMA LIVE NON È LA D'URSO SPECIALE",
#  'ULTIMO - IL CAPITANO',
#  'SKY TG24 - RASSEGNA STAMPA',
#  'TG1 - IL GIURAMENTO DEL GOVERNO DRAGHI',
#  'MATRIX - SPECIALE ELEZIONI',
#  'STUDIO APERTO LIVE (TGCOM24)',
#  'TG4 - DIARIO DEL GIORNO SPECIALE',
#  'MATTINO CINQUE',
#  'TITOLO QUINTO ANTEPRIMA',
#  'STATI GENERALI',
#  'TGR: PALIO DI ASTI',
#  'ONOREVOLI CONFESSIONI',
#  'TG1 - I GIORNI DELLA CRISI',
#  'RAI NEWS24 - SABATO E DOMENICA 24: SPECIALE ELEZIONI',
#  'ALLA LAVAGNA',
#  "L'ARIA CHE TIRA ESTATE IL DIARIO (TESTATA)",
#  'RAI NEWS SPECIALE: 24 AGOSTO 2016 LA SCOSSA',
#  'UNO MATTINA (RETE)',
#  'RAI QUIRINALE E TG1: IL GIORNO DELLA MEMORIA',
#  'SPECIALE TG1: ITALIA AL VOTO',
#  'RAI NEWS - SPECIALE GIORNO DELLA MEMORIA',
#  'NOVE RACCONTA: CASAMONICA LE MANI SU ROMA',
#  'TG5',
#  'MATRIX PRIME - LA SFIDA DEI LEADER',
#  'TG8',
#  'TG ECONOMY FLASH',
#  'MI MANDA RAITRE IN FESTA',
#  'MEDIASET TGCOM 24 - SPECIALE ELEZIONI 2019',
#  'MEDIASET TGCOM24 - SPECIALE PIAZZA FONTANA, STRAGE DI STATO',
#  'MI MANDA RAITRE SPECIALE (TESTATA)',
#  'POMERIGGIO CINQUE - SPECIALE PRIMO MAGGIO',
#  'LA CADUTA � STORIA DI UNA MORTE, DI UNA BANCA, DI UNA città',
#  'PRES. POVERA PATRIA (TESTATA)',
#  'ANTEPRIMA STASERA ITALIA WEEKEND SPECIALE CORONAVIRUS (VN)',
#  'CONTROCORRENTE SALUTI',
#  "RAI NEWS 24 - NOI CI SIAMO L'ITALIA DELL'ACCOGLIENZA",
#  'TELETHON',
#  'POMERIGGIO CINQUE - SPECIALE ELEZIONI EUROPEE',
#  'I SALUTI DI POMERIGGIO CINQUE',
#  'ELISIR',
#  'RAI NEWS24 - È GIÀ DOMANI',
#  '#FAKE - LA FABBRICA DELLE NOTIZIE',
#  'OTTO E MEZZO ANTEPRIMA (TESTATA)',
#  'SKY TG24 - PROGRESS',
#  'STUDIO APERTO SPECIALE',
#  "TG5 SPECIALE-LILIANA SEGRE TESTIMONE CONTRO L'INDIFFERENZA",
#  "L'ORA DI LEGALITÀ",
#  "STASERA C'È IL MEGLIO DI CATTELAN",
#  'UNA PEZZA DI LUNDINI',
#  'PROPAGANDA LIVE - CORSI DI RECUPERO (TESTATA)',
#  'MORNING NEWS SALUTI FINALI',
#  'TG1 - GENOVA RADURA DELLA MEMORIA RICORDO DELLE VITTIME DEL PONTE MORANDI',
#  'ANTEPRIMA PORTA A PORTA (TESTATA)',
#  'IN ONDA FOCUS (TESTATA)',
#  'TAGAD� LE STORIE (TESTATA)',
#  'LINEA BIANCA',
#  'STASERA ITALIA - ANTEPRIMA (VN)',
#  'LA GRANDE STORIA - ANNIVERSARI',
#  'SALVINOLOGY - TUTTI I VOLTI DI MATTEO',
#  'NEWS ROOM ITALIA - SPECIALE ELEZIONI',
#  'TG1 MATTINA - RASSEGNA STAMPA',
#  "C'È SOLO UN PRESIDENTE",
#  'TG PARLAMENTO',
#  'RAI NEWS ',
#  'LIKE TUTTO CIÒ CHE PIACE',
#  'SI O NO',
#  'TG2 ITALIA',
#  'STUDIO APERTO LA DOMENICA 12:25',
#  'VISIONARI',
#  'TG2 - WEEKEND',
#  "TG LA7 L'ULTIMA PAROLA",
#  'MI MANDA RAITRE ESTATE (TESTATA)',
#  'UN GIORNO IN PRETURA',
#  "L'ASSEDIO (TESTATA)",
#  "CLIP: LA SITUAZIONE DELL'OSPEDALE DI LOCRI",
#  'ITALIA SÌ (RETE)',
#  'SPECIALE STUDIO APERTO',
#  'FILO DIRETTO VERSO IL VOTO',
#  'ATLANTIDE SPECIALE (TESTATA)',
#  'COSTA CONCORDIA:CRONACA DI UN NAUFRAGIO',
#  'LA VITA IN DIRETTA ESTATE (RETE)',
#  'PRES. PORTA A PORTA (TESTATA)',
#  'RAI PARLAMENTO - PREMIER QUESTION TIME (L.I.S.)',
#  'DOMENICA LIVE',
#  'TG1 DIRETTA - IL GIURAMENTO',
#  'SKY TG24 - SULLE TRACCE DEL CONTAGIO',
#  'DEDICATO',
#  'TG LA7 SPECIALE ELEZIONI 2021',
#  'BELVE CULT',
#  'CHE TEMPO CHE FARÀ (TESTATA)',
#  'ANTEPRIMA OGGI È UN ALTRO GIORNO (RETE)',
#  'MEDIASET TGCOM 24 - ELEZIONI 2018',
#  'RAINEWS 24 - OGGI E DOMANI',
#  'RAI PARLAMENTO TG MAGAZINE',
#  'TG2 - MIZAR',
#  "RAI NEWS24 - CRONACHE DALL'ITALIA",
#  'PATRIAE',
#  'RAI NEWS - DIARIO DELLA CRISI',
#  'ANTICIPAZIONI RAI NEWS',
#  'SANREMO 2021 - 71° FESTIVAL DELLA CANZONE ITALIANA',
#  'LINEA BLU',
#  'PRES. AGORÀ WEEKEND (RETE)',
#  'AGORÀ ESTATE (TESTATA)',
#  'SANREMO 2020 - 70° FESTIVAL DELLA CANZONE ITALIANA',
#  'DOMENICA LIVE - ELEZIONI POLITICHE',
#  'SKY TG24 SPECIALE: PANDEMIA - LA NOTTE PIÙ LUNGA',
#  'amore ESTATE SPECIALE',
#  'LA NOSTRA STORIA',
#  'MEDIASET TGCOM24 - SPECIALE EUROPA',
#  'ACCORDI & DISACCORDI (TESTATA)',
#  'COSTA CONCORDIA - TRAPPOLA IN MARE',
#  'SKY TG24 SPECIALE - BANCHI DI PROVA',
#  'CLIP: ELEZIONI REGIONALI UMBRIA',
#  'ANTEPRIMA LA VITA IN DIRETTA (RETE)',
#  'QUELLI CHE ASPETTANO',
#  'SPECIALE FRONTIERE',
#  "TG1 DIRETTA: GRAZIE GIGI - L'ULTIMO SALUTO A GIGI PROIETTI",
#  'SKY TG24 - IL CONFRONTO: REGIONE LAZIO',
#  'SKY TG24 - EUROPEE 2019 (I)',
#  'SEVEN',
#  'TG2 POST - SPECIALE BALLOTTAGGI',
#  'POMERIGGIO CINQUE - ELEZIONI POLITICHE',
#  'NEWS ROOM ITALIA - SPECIALE LA SFIDA DI CONTE',
#  'FILO DIRETTO - VERSO IL GOVERNO',
#  'RAI NEWS24 - È GIÀ DOMANI - ANTEPRIMA',
#  'SPECIALE TG4',
#  'ANTEPRIMA SPECIALE PORTA A PORTA (RETE)',
#  'LA NOTTE DI RADIO3',
#  'IL CELESTE ROBERTO FORMIGONI',
#  'RAI PARLAMENTO SPECIALE CONFRONTO',
#  'ANTEPRIMA FUORIROMA (RETE)',
#  'SKY TG24 IL CONFINE',
#  "RAI NEWS24 SPECIALE: LA MEMORIA E LA RINASCITA - L'AQUILA A 14 ANNI DAL TERREMOTO",
#  'PROPAGANDA SOCIAL TOP TEN (TESTATA)',
#  'SKY TG24 SPECIALE - VOTO 2020 (I)',
#  'ANTEPRIMA PETROLIO ',
#  'LE IENE (RETE)',
#  'RAI NEWS - SPECIALE ELEZIONI BASILICATA 2019',
#  'TG5 MATTINA (TGCOM24)',
#  'TGR SPECIALE TERREMOTO',
#  'BLOB DI TUTTO DI PIÙ (TESTATA)',
#  '#CARTABIANCA (RETE)',
#  '#CARTABIANCA (TESTATA)',
#  'STUDIO APERTO LA GIORNATA',
#  'SPORT MEDIASET LA GIORNATA',
#  'LA CONFESSIONE IL MEGLIO DEL 2018',
#  'TG2 - SPECIALE ELEZIONI',
#  'ANTEPRIMA PORTA A PORTA - ATTUALITÀ DOPO IL CALCIO (RETE)',
#  'TG4 - DIARIO DELLA CRISI',
#  'SPORT MEDIASET - LA GIORNATA',
#  'ANTEPRIMA CHE TEMPO CHE FA (RETE)',
#  'I SALUTI DI ZONA BIANCA',
#  'ANTEPRIMA RAI 1 E TG1 - SPECIALE PORTA A PORTA (RETE)',
#  'NEL NOME DEL POPOLO ITALIANO',
#  'ANTEPRIMA POMERIGGIO CINQUE - NEWS',
#  'MI MANDA RAITRE ESTATE (RETE)',
#  'SKY TG24 - VOTO COMUNE',
#  'TG1 - IL PONTE DI GENOVA: CERIMONIA DI INAUGURAZIONE DEL VIADOTTO ALLA PRESENZA DEL PRES. DELLA REPUBBLICA',
#  'STASERA ITALIA SPECIALE - CORONAVIRUS I SALUTI (VN)',
#  'PROPAGANDA LIVE DOC (TESTATA)',
#  'MOKA',
#  'TG2 - WEEKEND ESTATE',
#  'OGGI È UN ALTRO GIORNO EXTRA (RETE)',
#  "FILO DIRETTO UCRAINA - L'ECONOMIA",
#  '#CARTABIANCA ORE 18.30 (RETE)',
#  'PRES. STASERA ITALIA NEWS (VN)',
#  "NON È L'ARENA PRIMA PAGINA (TESTATA)",
#  'ANTEPRIMA REPORT (TESTATA)',
#  'TG LA7 SPECIALE',
#  'STUDIO APERTO',
#  'RAI NEWS24 SPECIALE: PONTE SAN GIORGIO - LA RINASCITA',
#  'caffè EUROPA',
#  'RAI 1 E TG1 - ANTEPRIMA SPECIALE PORTA A PORTA - ELEZIONI 2018 (RETE)',
#  'FILO DIRETTO - LE SFIDE DEL GOVERNO',
#  "FILO DIRETTO - L'ADDIO A SILVIO BERLUSCONI",
#  'SKY TG24 - LIVE IN NAPOLI',
#  'QUARTA REPUBBLICA QUIRINALE',
#  'STASERA ITALIA WEEKEND (VN)',
#  'ANTEPRIMA RASSEGNA STAMPA',
#  'TG5 NOTTE (TGCOM24)',
#  'SPECIALE TG4 - LA CARICA DEI NUOVI SINDACI',
#  "L'INTERVISTA VERSIONE D",
#  'PETROLIO ANTIVIRUS',
#  'AL VOTO, AL VOTO...',
#  'SKY TG24 SPECIALE - VOTO 2020',
#  'ANTEPRIMA MI MANDA RAITRE (RETE)',
#  'TG3 SPECIALE',
#  'MEDIASET TGCOM 24 TOUR - IN MOVIMENTO TRA LE IMPRESE',
#  'RTL 102.5 NEWS',
#  'STUDIO APERTO LA DOMENICA 18:30',
#  '1938 DIVERSI',
#  'TGR - 66° RADUNO NAZIONALE BERSAGLIERI',
#  "MISTERI D'ITALIA",
#  'RAI NEWS - CHE FINE HA FATTO-',
#  'ANTEPRIMA CIAO MASCHIO',
#  'TG1 - PER NON DIMENTICARE',
#  'PALIO DI SIENA',
#  'QUARTA REPUBBLICA VINCITORI E VINTI (TGCOM24)',
#  'TGR - MEZZOGIORNO ITALIA',
#  'TG4',
#  'IN DIRETTA DAL QUIRINALE: LE CONSULTAZIONI',
#  'RAI NEWS24 - SORSI E MORSI',
#  'NEWS ROOM ITALIA - SPECIALE',
#  'RAI NEWS24 - #2020ADDIO',
#  'FRATELLI DI CROZZA CLASSIC (TESTATA)',
#  'DONNE AD ALTA QUOTA: XXX EDIZIONE DEL PREMIO MARISA BELLISARIO',
#  'TG2 - 64° REGATA DELLE ANTICHE REPUBBLICHE MARINARE',
#  'SEAT MUSIC AWARDS 2019',
#  'MEDIASET TGCOM 24 - OLTRE I FATTI',
#  'MATTINO CINQUE LE STORIE',
#  'SETTE STORIE SPECIALE TERREMOTO 5 ANNI DOPO (TESTATA)',
#  'CLIP: IVREA TRA I COMUNI AL VOTO IL PROSSIMO 10 GIUGNO 2018',
#  'DALLA VOSTRA PARTE ANCHE DI SABATO',
#  'PIAZZAPULITA - LA RICADUTA (TESTATA)',
#  'TG1 - ESEQUIE DI STATO DI SILVIO BERLUSCONI',
#  'DRITTO E ROVESCIO...E OLTRE',
#  'DIMARTEDÌ DIPIÙ (TESTATA)',
#  'PRES. REPORT (RETE)',
#  'PRES. RAI EDUCATIONAL - TV TALK',
#  'SKY TG24 - START',
#  'DA NOI...A RUOTA LIBERA (RETE)',
#  'CR4 - LA REPUBBLICA DELLE DONNE #I MIGLIORI MESI DELLA MIA VITA',
#  "ANTEPRIMA LIVE NON È LA D'URSO SPECIALE NATALE",
#  'ITALIA SÌ! GIORNO PER GIORNO',
#  'MI MANDA RAITRE (RETE)',
#  'CLIP: ACCOGLIENZA E INTEGRAZIONE SOCIALE - PROGETTI AVVIATI DA AMMINISTRAZIONI COMUNALI E COOPERATIVE IN VAL CAMONICA (LOMBARDIA)',
#  'ULISSE - IL PIACERE DELLA SCOPERTA',
#  'TG LA7 SPECIALE ELEZIONI 2019',
#  'SKY TG4 SPECIALE - GENOVA CITTÀ SPEZZATA',
#  'CHE SUCC3DE? GAME (RETE)',
#  'LA DOMENICA SPORTIVA',
#  'MEDIASET TGCOM 24 - SPECIALE CONSULTAZIONI',
#  'CLIP: INTERVISTA A RENZO PIANO',
#  'MEDIASET TGCOM 24 - DENTRO I FATTI (CIVETTA)',
#  'TG4 - DIARIO DELLA DOMENICA',
#  "TG1 - LE città D'EUROPA PER LA PACE",
#  'ATTACCO AL CLAN CACCIA AI CASALESI',
#  'TG3 (L.I.S.)',
#  'TG1 MATTINA - ESTATE',
#  'AL CONFINE DEI DIRITTI',
#  'CLIP: INTERVISTA A MARIO MONTI',
#  'CLIP: VICENZA - ANALISI E TESTIMONIANZE SU RECENTE ASCESA DI FENOMENI DI ESTREMISMO DI DESTRA',
#  'TG2 SPECIALE ELEZIONI 2020',
#  'GR 1',
#  'DRITTO E ROVESCIO REFERENDUM',
#  'ANNI 20',
#  'TG2 - SPECIALE ELEZIONI BASILICATA',
#  'STASERA ITALIA (VN)',
#  'TG1: LA CRISI',
#  'BELVE',
#  'NEMO - NESSUNO ESCLUSO - ANTEPRIMA (RETE)',
#  'RAI NEWS24 - STUDIO 24 - SPECIALE',
#  'PIAZZAPULITA - FANGO',
#  'TGR - 68° RADUNO NAZIONALE BERSAGLIERI',
#  'ESTATE IN DIRETTA (RETE)',
#  'AGORÀ EXTRA (TESTATA)',
#  'ANTEPRIMA CHE SUCC3DE? GAME',
#  'SPECIALE TELEGRAM - IL VACCINO DELLA MEMORIA',
#  'ANDREOTTI DIARIO PRIVATO',
#  'BERSAGLIO MOBILE (TESTATA)',
#  'FORREST',
#  'ZONA ROSSA',
#  "TG1 DIRETTA - RELAZIONE ANNUALE DELL'AUTORITÀ NAZIONALE ANTICORRUZIONE",
#  'DRITTO E ROVESCIO (TGCOM24)',
#  "L'ASSEDIO BEST OF",
#  'STUDIO APERTO 18:30',
#  'MATTINO CINQUE NEWS SPECIALE (TGCOM24)',
#  'CLIP: 25 APRILE 2022 - MANIFESTAZIONE ORGANIZZATA DALLA FIAP A ROMA',
#  'PORTA A PORTA (TESTATA)',
#  'RAI NEWS24 - IL TG DELLE 8',
#  "PORTA A PORTA POLITICHE '22 (TESTATA)",
#  'SPECIALE PORTA A PORTA (RETE)',
#  'QUINTA COLONNA - ULTIMO ROUND',
#  "PIAZZAPULITA - L'ABISSO",
#  'SPECIALE TG1 - UN MARE DI FANGO: CRONACA DI UN DISASTRO ANNUNCIATO',
#  'PIAZZAPULITA - CORPO A CORPO (TESTATA)',
#  'RAI NEWS24 SPECIALE: CENTOMILA LACRIME - LE VITTIME DEL COVID',
#  'CLIP: FATTI ED EVENTI INTERNAZIONALI CHE HANNO CARATTERIZZATO IL 2020',
#  'FILO DIRETTO - FRANA A ISCHIA',
#  'CONTROCORRENTE - SPECIALE GUERRA',
#  'PRES. AGORÀ ESTATE (RETE)',
#  'PROPAGANDA LIVE SPECIALE (TESTATA)',
#  'ANTEPRIMA TG LA7 SPECIALE ELECTION DAY',
#  'PRES. POMERIGGIO CINQUE',
#  'AGORÀ SPECIALE (RETE)',
#  'ESTATE IN DIRETTA (TESTATA)',
#  'PRES. SKY TG24 - BUONGIORNO TELEGIORNALE',
#  'POMERIGGIO CINQUE SOCIAL',
#  'QUARTA REPUBBLICA',
#  'POMERIGGIO CINQUE FESTIVO',
#  'PRES. STASERA ITALIA',
#  'ASPETTANDO TAGADÀ (TESTATA)',
#  '1/2H IN PIÙ (RETE)',
#  'STASERA ITALIA WEEKEND SPECIALE - CORONAVIRUS (TGCOM24)',
#  'TG1 - TRAGEDIA SULLA MARMOLADA',
#  'MEDIASET TGCOM 24 - DIRETTA DA ROMA: PARLA RENZI',
#  'DA NOI...A RUOTA LIBERA (TESTATA)',
#  'COFFEE BREAK SABATO',
#  'CLIP: DISCORSO DI LILINA SEGRE AL QUIRINALE',
#  'RAI NEWS - RASSEGNA STAMPA',
#  'IO E TE DI NOTTE',
#  "CERIMONIA DI CONSEGNA DEI COLLARI D'ORO 2019",
#  ...]

# %%
data.select('day').head(3)
# Out:
# shape: (3, 1)
# ┌─────────────────────┐
# │ day                 │
# │ ---                 │
# │ datetime[ns]        │
# ╞═════════════════════╡
# │ 2023-05-01 00:00:00 │
# │ 2023-05-01 00:00:00 │
# │ 2023-05-01 00:00:00 │
# └─────────────────────┘

# %%
name_unique = data.select('name').unique().to_series().to_list()
print(name_unique[:5])
# Out:
# ['Camillo', 'Matilde', 'Arturo', 'Vita', 'Maria Elisabetta']

# %%
data.select('lastname').unique().to_series().to_list()
# Out:
# ['Apolloni',
#  'Sinatra',
#  'Murgi',
#  'Latronico',
#  'Donina',
#  'Boccoli',
#  'Musse Ali',
#  'Zambito',
#  'Capone',
#  'Spagnuolo',
#  'Scialpi',
#  'Tubetti',
#  "Civici e Innovatori - Energie per l'Italia",
#  'Rey',
#  'Maggioni',
#  'Rospi',
#  'Curatella',
#  'Shehu',
#  'Invernizzi',
#  'Scapin',
#  'Bedori',
#  'Sapia',
#  'Ambrosini',
#  'Ambiente 2050',
#  'Polo',
#  'Dupont',
#  'Fotia',
#  'Provera',
#  'Menna',
#  'Campione',
#  'Locci',
#  'Di Matteo',
#  'Caizza',
#  'Iannetti',
#  'Guzzini',
#  'Salini',
#  'Zuccarini',
#  'Lendaro',
#  'Nappi',
#  'Canitano',
#  'Mennella',
#  'Campagnolo',
#  'Villa',
#  'Caminiti',
#  'Lanzo',
#  'Boero',
#  'Più Europa-Centro Democratico',
#  'Polizzi',
#  'Pesatori',
#  'Perrotta',
#  'Zanon',
#  "Noi con l'Italia-USEI",
#  'Punzo',
#  'Gazzani',
#  'Scaramellini',
#  'De Medici Almirante',
#  'Union Valdotaine Progressiste',
#  'Piccione',
#  'Bonfrisco',
#  'Cavazzi',
#  'Galella',
#  'Calvagna',
#  'Perrucci',
#  'Pendinelli-',
#  'Zini',
#  'Agostini',
#  'Centro Democratico-Italiani In Europa-Europeisti-MAIE',
#  'Ranfone',
#  'Di Cola',
#  'Timbro',
#  'Tripiedi',
#  'Severino',
#  'Riccetti',
#  'Nurra',
#  'Maiorano',
#  'Bachelet',
#  'Gasbarra',
#  'Ingroia',
#  'Tomasi',
#  'Guglielmelli',
#  'Terracciano',
#  'Favero',
#  'Figuccia',
#  'Ausserdorfer',
#  'Isidori',
#  'La Pietra',
#  'Marchisio',
#  'Camicia',
#  'Gratarola',
#  'Cervoni',
#  'Bussetti',
#  'Cabella',
#  'Pisu',
#  'Della Ragione',
#  'Cantoro',
#  'Sassone',
#  'Azzano Cantarutti',
#  'Dalmazzo',
#  'Innamorato',
#  'Pavanelli',
#  'Minervini',
#  'La Rocca',
#  'Dadone',
#  'Losacco',
#  'Damiolini',
#  'Parri',
#  'Corona',
#  'Salizzoni',
#  'Matarrelli',
#  'Scafarto',
#  'Scarpelli',
#  'Mattana',
#  'Caviglia',
#  'Spalenza',
#  'Panieri',
#  'Pavanello',
#  'Moscheni',
#  'Richichi',
#  'Borghi Aquilini',
#  'Silvestroni',
#  'Boraso',
#  'Bussiglieri',
#  'Errante',
#  'Campanile',
#  'Pizzimenti',
#  'Riberi',
#  'Intini',
#  'Castronovi',
#  'Muroni',
#  'Alparone',
#  'Montana',
#  'Giugni',
#  'Ubertini',
#  'Brosio',
#  'Stevelli',
#  'Galizzi',
#  'Perticone',
#  'Baccarini',
#  'Finardi',
#  'Samarati',
#  'Di Cerbo',
#  'Timpano',
#  'Costantini',
#  'Foglietta',
#  'Pardini',
#  'Fabiano',
#  'Vella',
#  'Cappuccio',
#  "Noi con l'Italia-USEI-Cambiamo!-Alleanza di Centro",
#  'Furlan',
#  'Liccati',
#  'Bisconti',
#  'Martini',
#  'Civica Calenda Sindaco',
#  'Cordaro',
#  'Lo Giudice',
#  'Roncoli',
#  'Solaroli',
#  'Occhionero',
#  'Alleanza Liberal Popolare-Partito Repubblicano Italiano (ALA-PRI)',
#  'Patuelli',
#  'Garreffa',
#  'Di Pumpo',
#  'Rughetti',
#  'Banchieri',
#  'Brogi',
#  'Fiocchi',
#  'Saltamartini',
#  'Granello',
#  'Paparelli',
#  'Chiti',
#  'Ferazzoli',
#  'Pagoto',
#  'Fabbiani',
#  'Gombia',
#  'Manganaro',
#  'Romanelli',
#  'Zappacosta',
#  'Dema Democrazia Autonomia',
#  'Cecchi',
#  'Torquato',
#  'Marsetti',
#  'Preacco',
#  'Masselli',
#  'Sardine',
#  'Cirinna',
#  'Buscemi',
#  'Incarnato',
#  'Marchionni',
#  'Corsini',
#  'Caccia',
#  'Di Carlo',
#  'Quarzo',
#  'Bessi',
#  'Precoma',
#  'Fiocchini',
#  'Nicolao',
#  'Vita',
#  'Suriano',
#  'Mainenti',
#  'Fentini',
#  'Toce',
#  'Marteddu',
#  'Fattorini',
#  'Ceresa',
#  'Marinaro',
#  'MAIE-Psi-Facciamo Eco',
#  'Ciuoffo',
#  'Golini',
#  'Pagliaro',
#  'Caldara',
#  'Razzi',
#  'Della Sala',
#  'Vighi',
#  'Cimminiello',
#  'Cossu',
#  'Antonione',
#  'Rolando',
#  'Moscarelli',
#  'Risatti',
#  'Cecconi',
#  'Carinelli',
#  'De Donatis',
#  'Barbisan',
#  'Conio',
#  'Partito Comunista dei Lavoratori',
#  'Corradin',
#  'Cuperlo',
#  'Lezzi',
#  'Durbiano',
#  'Picucci',
#  'Cacciari',
#  'Brugger',
#  'Santamaria',
#  'Bassani',
#  'Garozzo',
#  'Lissi',
#  'Pescini',
#  'Argento',
#  'Vigorelli',
#  'Piani',
#  "Dall'Omo",
#  'Fratus',
#  'Cacciatore',
#  'Troja',
#  'Montà',
#  'Dal Medico',
#  'Perniconi',
#  'Pagliai',
#  'Comitato Democratici per il Sì',
#  'Patassini',
#  'Ciriaci',
#  'Lazzeri',
#  'Zaccaria',
#  'Verra',
#  'Guolla',
#  'Sasso',
#  'Bulfaro',
#  'Fraleoni Morgera',
#  'Pertichini',
#  'Caverni',
#  'Gobbato',
#  'Brasseco',
#  'Anzalone',
#  'Batino',
#  'Bartaletti',
#  'Tolardo',
#  'Messi',
#  'Stefano',
#  'Caponi',
#  'Oberhofer',
#  'Rovasio',
#  'Feduzi',
#  'Bonazza',
#  'Crovato',
#  'Cristiani Democratici Uniti',
#  'Maieli',
#  'Gaudioso',
#  'Progetto Civico Progressista',
#  'Guarguaglini',
#  'Giampedrone',
#  'Pezzanesi',
#  'Cappelli',
#  'Trivero',
#  'Spada',
#  'Brancato',
#  'Del Turco',
#  'Buti',
#  'Casciano',
#  'Uberti',
#  'Dal Monte',
#  'Canale',
#  'Partito socialista democratico italiano',
#  'Lucà',
#  'Merlotti',
#  'Iacomella',
#  'Assenza',
#  'Polledrotti',
#  'Di Stasio',
#  'Ceraso',
#  'Sega',
#  'Grego',
#  'Umberti',
#  'Zorzo',
#  'Nisini',
#  'Marrocco',
#  'Preioni',
#  'Pelicioli',
#  'Villanova',
#  'Angelosante',
#  'Iarrera',
#  'Girardi',
#  'Del Zoppo',
#  'Croce Agnello',
#  'Tataranno',
#  'Bobba',
#  'Democrazia Solidale-Centro Democratico',
#  'Cecotti',
#  'Magistro',
#  'Albucci',
#  'Azzerboni',
#  'Stallone',
#  'Mariotti',
#  'Manzano Olivieri',
#  "Centristi per l'Europa",
#  'Pacini',
#  'Pallini',
#  'Laborante',
#  'Romanini',
#  'Lacarra',
#  'Sotgia',
#  'Comitato io Dico Sì',
#  'Cardiello',
#  'Adone',
#  'Sabia',
#  'Nati',
#  'Pavoncello',
#  'Abramo',
#  'Sensoli',
#  'Parcaroli',
#  'Licheri',
#  'Saija',
#  'Scaturchio',
#  'La Russa',
#  'Lavorato',
#  'Bacciga',
#  'Currò',
#  'Florido',
#  'Italia Viva',
#  'De Felicis',
#  'Morisi',
#  'Cirroni',
#  'Del Dotto',
#  'Gurinov',
#  'Colizza',
#  'Lucianaz',
#  'Cusano',
#  'Cotticelli',
#  'Trevisi',
#  'Moschetti',
#  'La Mantia',
#  'Di Paola',
#  'Evi',
#  'Regoli',
#  'Lamberti Castronuovo',
#  'Omoboni',
#  'Febbo',
#  'Nesto',
#  'De Simone',
#  'Amen',
#  "D'Alfonso",
#  'Polverini',
#  'Micheletti',
#  'Paladini',
#  'Gebhard',
#  'Pellicani',
#  'Lisei',
#  'Di Cesare',
#  'Stilo',
#  'Cerini',
#  'Furiozzi',
#  'Pescatori',
#  'Accardo',
#  'Cambiano',
#  'Infurna',
#  'Maietta',
#  "Alternativa Popolare-Centristi per l'Europa",
#  'Schellino',
#  'Ferricelli',
#  'Figaro',
#  'Micarelli',
#  'Partito Socialista Italiano',
#  'Bordonali',
#  'Nissoli',
#  'Mantovani',
#  'Laudani',
#  'Vesan',
#  'Malingieri',
#  "Civici e Innovatori-Energie per l'Italia",
#  'Alfieri',
#  'Monari',
#  'Sofo',
#  'Foglio',
#  'Barberi',
#  'Alpe',
#  'Perantoni',
#  'Carbone',
#  'Di Maria',
#  'Assenti',
#  'Corbucci',
#  'Olgiati',
#  'Carli',
#  'Trerotola',
#  'Rendina',
#  'Ursino',
#  'Migliorati',
#  'Echamanov',
#  'Touadi',
#  'Botta',
#  'Prasanna',
#  'Malacrida',
#  'Camusso',
#  'Rivolta',
#  'Gullotta',
#  'Nuovo PSI',
#  'Bellafiore',
#  'Titoni',
#  'Barra',
#  'Verri',
#  'Costalonga',
#  'Agnoletti',
#  'Autonomia Responsabile',
#  'Casarini',
#  'Bonomelli',
#  'Bonat',
#  'Risini',
#  'Riccardi',
#  'Aiello',
#  'Dionigi Palazzi',
#  'Casisi',
#  'Distante',
#  'Fare!',
#  'Giuliano',
#  'Galigani',
#  'Marelli',
#  'Lantieri',
#  'Bongiasca',
#  'Cauteruccio',
#  'Italiani con Draghi - Rinascimento',
#  'Branduzzi',
#  'Morani',
#  'Fusignani',
#  'Toppan',
#  'Parolo',
#  'Leon',
#  'Trasatti',
#  "D'Oria",
#  'De Petris',
#  'Gennaccaro',
#  'Duzioni',
#  'Castagna',
#  'Recupero Maltolto',
#  'Visigalli',
#  'Mereu',
#  'Peluffo',
#  'Millozzi',
#  'Giottoli',
#  'Comardi',
#  'Di Bari',
#  'De Vito',
#  'Dello Sbarba',
#  'Montebello',
#  'Leontini',
#  'Bancheri',
#  'Maestri',
#  'Fronte Verde',
#  'Segnalini',
#  'Melini',
#  'Squeri',
#  'Balliano',
#  'Della Figliola',
#  'Aguzzi',
#  'Dolce',
#  'De Iesu',
#  'Fragomeli',
#  'Addamiano',
#  'Luzzi',
#  'Catapano',
#  'Benni',
#  'Comba',
#  'Caproglio',
#  'Palmieri',
#  'Donnici',
#  'Mastacchi',
#  'Scaramelli',
#  'Correggia',
#  'Belloni',
#  'Di Micco',
#  'Giacomello',
#  'Barbagallo',
#  'Rocca',
#  'Lecci',
#  'Corrado',
#  'Trabucchi',
#  'Zanotti',
#  'Michelotti',
#  'Mantero',
#  'Iuppa',
#  'De Saro',
#  'Grassadonia',
#  'Marcozzi',
#  'Bizzotto',
#  'Tomeo',
#  'Attaguile',
#  'Balocchi',
#  'Quieti',
#  'Lega Nord',
#  "D'angelo",
#  'Gutgeld',
#  'Miraglia',
#  'Carapellese',
#  'Littarru',
#  'Binelli',
#  'Occhi',
#  'Italia dei valori',
#  'Bardi',
#  'Rauti',
#  'Barillari',
#  'Beccaria',
#  'Barbarella',
#  'Maquignaz',
#  'Caravaggio',
#  'Cantaluppi',
#  'Carusi',
#  'Guidolin',
#  'Triulzi',
#  'Ciaccheri',
#  'Carra',
#  'Vallenzona',
#  'Magi',
#  'Chiola',
#  'Sospiri',
#  'Fedeli',
#  'Bencivenga',
#  'Italia al Centro-Coraggio Italia',
#  'Callegaro',
#  'De Fanis',
#  'Lauro',
#  'Ternullo',
#  'Raugna',
#  'Di Nino',
#  'Biffoni',
#  'Bonaccorsi',
#  'Giangiulio',
#  'Murro',
#  'Galli',
#  'Sebastiano',
#  'Moric',
#  'Da Empoli',
#  'Truzzu',
#  'Di Maggio',
#  'Vicinelli',
#  'Rottoli',
#  'Scutellà',
#  'Graziani',
#  'Verruzzi',
#  'Gallera',
#  'Ciminelli',
#  'Zollino',
#  'Cutello',
#  'Bellanova',
#  'Masci',
#  'Gasser Fink',
#  'Minardo',
#  'Amati',
#  'Mastrandrea',
#  'Accorinti',
#  'Chiaraluce',
#  'Sagramoso',
#  'Restifo',
#  'Anaclerio',
#  'Zanchetta',
#  'Bedogni',
#  'Confalone',
#  "D'Amico",
#  'Urciuoli',
#  'Borace',
#  'Tonel',
#  'Blancardi',
#  'Sambrici',
#  'De Benedittis',
#  'De Faveri',
#  'Furfaro',
#  'Benvenuto',
#  'Scarciglia',
#  'Cusumano',
#  'Cannata',
#  'Giani',
#  'Ghezzani',
#  'Roggiani',
#  'Furegato',
#  'Mucchetti',
#  'Cerri',
#  'Segnana',
#  'Ronzulli',
#  'Alaia',
#  'Bazzarello',
#  'Secondi',
#  'Zanca',
#  'Montalti',
#  'Rotelli',
#  'Mazzina',
#  'Sudermania',
#  'Cacciola',
#  'Savoca',
#  'Falco',
#  'Frei',
#  'Zicchieri',
#  'Boscoscuro',
#  'Mazzetti',
#  'Checchi',
#  'Landini',
#  'Castelluccio',
#  'Giubilei',
#  'Galiati',
#  'Caporusso',
#  'Pitaro',
#  'Susta',
#  'Lintner',
#  'Pentenero',
#  'Sarti',
#  'Goldoni',
#  'Rossini',
#  'Boemo',
#  'Castriotta',
#  'Binatti',
#  'Orlandini',
#  'Pizio',
#  'Scoppa',
#  'Stefanazzi',
#  'Mangiante',
#  'Degli Innocenti',
#  'Tartaglia',
#  'Perilli',
#  'Movimento Animalista',
#  'Tripoli',
#  'Savoia',
#  'Cozzi',
#  'Vastola',
#  'Pazzaglini',
#  'De Rinaldis Saponaro',
#  'Pesca',
#  'Svaluto Ferro',
#  'Micheli',
#  'Croppi',
#  'Bano',
#  'Gurrieri',
#  'Lettieri',
#  'Consolo',
#  'Gallonetto',
#  'Gola',
#  'Gentile',
#  'Chiavenuto',
#  'Pagliarini',
#  'Saccardin',
#  'Ragghianti',
#  'Dipasquale',
#  'Bonsangue',
#  'Mar',
#  'Bagnai',
#  'Lorenzano',
#  'Gitti',
#  'Bertot',
#  'Zuccalà',
#  'Di Lascio',
#  'Ciocchetti',
#  'Cortese',
#  'Tinari',
#  'Insieme per il Futuro',
#  'Maruca',
#  'Dore',
#  'Ibba',
#  'Cappellacci',
#  'Spirlì',
#  'Baruffi',
#  'Semproni',
#  'Viscione',
#  'Talarico',
#  'Pappalardo',
#  'Gazzola',
#  'Simonetti',
#  'Silli',
#  'Temiloluwa Olayanju',
#  'Tormena',
#  'Cusimano',
#  'Oss Emer',
#  'Testamento',
#  'Barbabella',
#  'Bottoni',
#  'Ripamonti',
#  'Holzeisen',
#  'Capotosto',
#  'Perconti',
#  'Ghilardi',
#  'Scarnecchia',
#  'Rea',
#  "D'Ippolito",
#  'Soldan',
#  'Beorchia',
#  'Barachini',
#  'Bodoni',
#  'Pilotto',
#  'Barani',
#  'Pettinari',
#  'Pinassi',
#  'Pettazzi',
#  'Brandi',
#  'Luche',
#  'Cominciamo dal No',
#  'Denuzzo',
#  'Angelino',
#  'Porcelli',
#  'Iervolino',
#  'Migliore',
#  'Galluzzo Motolese',
#  'Fiorina',
#  'Soulene',
#  'Chessa',
#  'Zorzi',
#  'Rostagno',
#  'Antonetti',
#  'Friggeri',
#  'Cassì',
#  'Barontini',
#  'Grasso',
#  'Cimmino',
#  'Guerriero',
#  'Guanella',
#  'De Zotti',
#  'Bombardieri',
#  'Mariani',
#  'Sanzarello',
#  'Moretti',
#  'Di Lonardo',
#  'Carniti',
#  'Melilla',
#  'Beccalossi',
#  'Mastroianni',
#  'Spizzirri',
#  'Lo Cascio',
#  'Pietrasanta',
#  'Passiatore',
#  'Di Giuseppe',
#  'Ruffini',
#  'Calemme',
#  'Pinzi',
#  'Venturini',
#  'Pezzimenti',
#  'Parise',
#  'Donzelli',
#  'Martina',
#  'Patto Civico',
#  'Fanuli',
#  'Cozzani',
#  'Bosa',
#  'Gozzoli',
#  'Jakelich',
#  'De Ruggieri',
#  'Baccelli',
#  'Scoma',
#  'Congedo',
#  'Cescutti',
#  'Capriccioli',
#  'Sau',
#  'Fede',
#  'Lunesu',
#  'Misiano',
#  'Libera',
#  'Sartori',
#  'Cascini',
#  'Mazziotti Di Celso',
#  'Michetti',
#  'Brunelli',
#  'Cavone',
#  'Coletti',
#  'Cividati',
#  'Zinutti',
#  'Baglio',
#  'Moretto',
#  "ScarfòD'Incà",
#  'Agabiti in Urbani',
#  'Bevilacqua',
#  'Becattini',
#  'Cugusi',
#  'Morra',
#  'Nogarin',
#  'Acquafredda',
#  'Taddeo',
#  'Morselli',
#  'Capoccioni',
#  'Scalfaro',
#  'Caldoro',
#  'Magliocca',
#  'Cavazzuti',
#  'Nuzzo',
#  'Mancinelli',
#  'Piccolo',
#  'Lisanti',
#  'Contini',
#  'La Spina',
#  'Sposato',
#  'Arlacchi',
#  'Cosseddu',
#  'Graziadei',
#  'Palozzi',
#  'Susinno',
#  'Facinelli',
#  'Cinelli',
#  'Zingale',
#  'Restante',
#  'Corsi',
#  'Nisi',
#  'Sardone',
#  'Oggiano',
#  'Centro Democratico',
#  'Aronica',
#  'Sorial',
#  'Latini',
#  'Rinascimento',
#  'Panfilo',
#  'Carretta',
#  'Cecchin',
#  'Bontempi',
#  'Sabella',
#  'Zamparutti',
#  'Granucci',
#  'Ghidorzi',
#  'Moscatt',
#  'Loddo',
#  'Cascioli',
#  'Depaoli',
#  'Sonetti',
#  'Fatuzzo',
#  'Calderaro',
#  "L'Altro Piemonte a Sinistra",
#  'Galmozzi',
#  'Orsini',
#  'Giorgio',
#  'Rizzi',
#  'Dellai',
#  'Sposetti',
#  'Mastrorillo',
#  'Lanzarin',
#  'Torselli',
#  'Ragona',
#  'Berlinghieri',
#  'Groppelli',
#  'Montoneri',
#  'Deledda',
#  'Pantaleo',
#  'Movimento Gente Onesta',
#  'Per le autonomie-minoranze linguistiche',
#  'Gianstefani',
#  'Mazzocca',
#  'Cerotta',
#  'Zinzi',
#  'Marzana',
#  'Verlicchi',
#  'Bonelli',
#  'Patton',
#  'Lippari',
#  'Ciancio',
#  'Pedaci',
#  'Macina',
#  'Pigozzo',
#  'Ruggieri',
#  'Impegno Civico Luigi Di Maio-Centro Democratico',
#  'Cambiamo!-Popolo Protagonista',
#  'Balli',
#  'Straface',
#  'Zizzamia',
#  'Tasca',
#  'Barzanti',
#  'Ronconi',
#  'Aimetti',
#  'Villarosa',
#  'Procopio',
#  'Alfarano',
#  'Ravagli',
#  'Bruschini',
#  'Stanca',
#  'Motta',
#  'Sangiorgi',
#  'Buffone',
#  'Gaiotti',
#  'Renaudi',
#  'Castellano',
#  'Giaccone',
#  'Andruccioli',
#  'Caggiari',
#  'Marchionini',
#  'Argenziano',
#  'Toccalini',
#  'Isola',
#  'Sacconi',
#  'Coletta',
#  'Di Battista',
#  'Allera',
#  'Sisto',
#  'Menin',
#  'Kaswalder',
#  'Pondini',
#  'Balboni',
#  'Ippolito',
#  'Lista Civica con Giorgia',
#  'Musumeci',
#  'Niccoli',
#  'Lana',
#  'Rogliani',
#  'Forzese',
#  "Dell'Orco",
#  'Mattiotti',
#  'Rossetti',
#  'Raccagna',
#  'Vannucci',
#  'Nizzi',
#  'Venditti',
#  'Randi',
#  'Cucchi',
#  'Salvetti',
#  'Marchegiani',
#  'De Caro',
#  'Ferrini',
#  'Spacca',
#  'Bonel',
#  'Di Marco',
#  'Cardamuro',
#  'Zanini',
#  'Borgio',
#  'Guatteri',
#  'Catanzaro',
#  'Migliazzo',
#  'Laffranco',
#  'Maccanti',
#  'Mulas',
#  'Affronti',
#  'Stroscio',
#  'Melcore',
#  'Figura',
#  'Capelli',
#  'Avanza',
#  'Remigi',
#  'Santelli',
#  'Leoni',
#  'Alliance Valdotaine',
#  'Urbani',
#  'Cucinotta',
#  'Pippo',
#  'Abbaticchio',
#  'Samonà',
#  'Calia',
#  'Furgiuele',
#  "Noi con l'Italia-USEI-Rinascimento-AdC",
#  'Giardina',
#  'Bazzani',
#  'Susin',
#  'Rossano',
#  'Calisti',
#  'Ciacciarelli',
#  'Sanfilippo',
#  'Principi',
#  'Iezzi',
#  'Colletti',
#  'Klun',
#  'Schito',
#  'Italia Europa Insieme',
#  'Ravida',
#  'De Ruggeri',
#  'Imperadore',
#  'Castagnetti',
#  'Ortelli',
#  "Dell'Uomo",
#  'Geloni',
#  'Frezza',
#  'Rosatelli',
#  'Fiazza',
#  'Riboldi',
#  'Sette',
#  'Bordin',
#  'Bova',
#  'Calderoni',
#  'Baldazzi',
#  'Oliverio',
#  'Manzan',
#  'Fantone',
#  'Calabrese',
#  'Beppe Sala - Noi, Milano',
#  'Ciampolillo',
#  'Ghimenti',
#  'Roselli',
#  ...]

# %%
data.filter(pl.col("name") == "Soggetto collettivo").select("lastname").head(3)
# Out:
# shape: (0, 1)
# ┌──────────┐
# │ lastname │
# │ ---      │
# │ str      │
# ╞══════════╡
# └──────────┘

# %%
data.filter(pl.col("name") != "Soggetto collettivo").select("lastname").head(3)
# Out:
# shape: (3, 1)
# ┌─────────────────────┐
# │ lastname            │
# │ ---                 │
# │ str                 │
# ╞═════════════════════╡
# │ Partito Democratico │
# │ Rizzetto            │
# │ Rizzo               │
# └─────────────────────┘

# %%
data.select('topic').unique().to_series().to_list()
# Out:
# ['Mass media e spettacolo',
#  'Giustizia',
#  'Costume e societa',
#  'società',
#  'Societa',
#  'Economia, finanza e lavoro',
#  'Religione e questioni religiose',
#  'Politica e attività istituzionali',
#  'Medicina, salute e scienza',
#  'Cronaca',
#  'Altro',
#  'Fine',
#  'Informazioni di servizio',
#  'Pubblicita',
#  'Cultura e istruzione',
#  'Esteri',
#  'Programma',
#  'Politica e attivita istituzionali',
#  'Sport',
#  'pubblicità',
#  'Costume e società',
#  'Ambiente']

# %%
unique_affiliations = data.select('affiliation').unique().to_series().to_list()
print(unique_affiliations[:5])
# Out:
# ['Italia Sovrana e Popolare', 'Unione Popolare con De Magistris', 'Minoranze linguistiche', 'Partito Democratico', "Noi con l'ItaliaUSEIRinascimento-AdC"]

# %%
data.select('kind').unique().to_series().to_list()
# Out:
# ['Parola', 'Notizia']

# %%
data.select('duration').head(5).to_series().to_list()
# Out:
# [5, 542, 209, 362, 7]

# %%
data = data.with_columns((pl.col("name") + " " + pl.col("lastname")).alias("fullname"))
data
# Out:
# shape: (1_259_177, 11)
# ┌──────────┬────────────┬────────────┬────────────┬───┬──────────┬─────────┬───────────┬───────────┐
# │ channel  ┆ program    ┆ day        ┆ lastname   ┆ … ┆ duration ┆ kind    ┆ __index_l ┆ fullname  │
# │ ---      ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---      ┆ ---     ┆ evel_0__  ┆ ---       │
# │ str      ┆ str        ┆ datetime[n ┆ str        ┆   ┆ i64      ┆ str     ┆ ---       ┆ str       │
# │          ┆            ┆ s]         ┆            ┆   ┆          ┆         ┆ i64       ┆           │
# ╞══════════╪════════════╪════════════╪════════════╪═══╪══════════╪═════════╪═══════════╪═══════════╡
# │ CANALE 5 ┆ ANTICIPAZI ┆ 2023-05-01 ┆ Partito    ┆ … ┆ 5        ┆ Notizia ┆ 2         ┆ Soggetto  │
# │          ┆ ONI TG5    ┆ 00:00:00   ┆ Democratic ┆   ┆          ┆         ┆           ┆ collettiv │
# │          ┆            ┆            ┆ o          ┆   ┆          ┆         ┆           ┆ o Partito │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ De…       │
# │ CANALE 5 ┆ MATTINO    ┆ 2023-05-01 ┆ Rizzetto   ┆ … ┆ 542      ┆ Parola  ┆ 3         ┆ Walter    │
# │          ┆ CINQUE     ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Rizzetto  │
# │          ┆ NEWS LIFE  ┆            ┆            ┆   ┆          ┆         ┆           ┆           │
# │ CANALE 5 ┆ MATTINO    ┆ 2023-05-01 ┆ Rizzo      ┆ … ┆ 209      ┆ Parola  ┆ 4         ┆ Marco     │
# │          ┆ CINQUE     ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Rizzo     │
# │          ┆ NEWS LIFE  ┆            ┆            ┆   ┆          ┆         ┆           ┆           │
# │ CANALE 5 ┆ POMERIGGIO ┆ 2023-05-01 ┆ Pezzopane  ┆ … ┆ 362      ┆ Parola  ┆ 5         ┆ Stefania  │
# │          ┆ CINQUE     ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Pezzopane │
# │          ┆ FESTIVO    ┆            ┆            ┆   ┆          ┆         ┆           ┆           │
# │ CANALE 5 ┆ TG5        ┆ 2023-05-01 ┆ Azione-Ita ┆ … ┆ 7        ┆ Notizia ┆ 6         ┆ Soggetto  │
# │          ┆            ┆ 00:00:00   ┆ lia        ┆   ┆          ┆         ┆           ┆ Collettiv │
# │          ┆            ┆            ┆ Viva-Renew ┆   ┆          ┆         ┆           ┆ o Azione- │
# │          ┆            ┆            ┆ Europ…     ┆   ┆          ┆         ┆           ┆ Ita…      │
# │ …        ┆ …          ┆ …          ┆ …          ┆ … ┆ …        ┆ …       ┆ …         ┆ …         │
# │ TV8      ┆ TG8        ┆ 2021-01-30 ┆ Fontana    ┆ … ┆ 11       ┆ Parola  ┆ 30508     ┆ Attilio   │
# │          ┆            ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Fontana   │
# │ TV8      ┆ TG8        ┆ 2021-01-30 ┆ Mattarella ┆ … ┆ 41       ┆ Parola  ┆ 30509     ┆ Sergio    │
# │          ┆            ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Mattarell │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ a         │
# │ TV8      ┆ TG8        ┆ 2021-01-31 ┆ Movimento  ┆ … ┆ 3        ┆ Notizia ┆ 30510     ┆ Soggetto  │
# │          ┆            ┆ 00:00:00   ┆ 5 Stelle   ┆   ┆          ┆         ┆           ┆ collettiv │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ o         │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ Movimento │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ …         │
# │ TV8      ┆ TG8        ┆ 2021-01-31 ┆ Partito    ┆ … ┆ 4        ┆ Notizia ┆ 30511     ┆ Soggetto  │
# │          ┆            ┆ 00:00:00   ┆ Democratic ┆   ┆          ┆         ┆           ┆ collettiv │
# │          ┆            ┆            ┆ o          ┆   ┆          ┆         ┆           ┆ o Partito │
# │          ┆            ┆            ┆            ┆   ┆          ┆         ┆           ┆ De…       │
# │ TV8      ┆ TG8        ┆ 2021-01-31 ┆ Renzi      ┆ … ┆ 27       ┆ Parola  ┆ 30512     ┆ Matteo    │
# │          ┆            ┆ 00:00:00   ┆            ┆   ┆          ┆         ┆           ┆ Renzi     │
# └──────────┴────────────┴────────────┴────────────┴───┴──────────┴─────────┴───────────┴───────────┘

# %%
#divide political groups (var-->political_groups) and politicians (var-->politicians) in an array with names

political_groups = data.filter(pl.col("name") == "Soggetto collettivo").select("lastname").unique().to_series().to_list()

politicians = data.filter(pl.col("name") != "Soggetto collettivo").select("fullname").unique().to_series().to_list()

# %%
#find all values of all columns (var: channel, program, affiliation, topic) all arrays

channels = data.select('channel').unique().to_series().to_list()
programs = data.select('program').unique().to_series().to_list()
affiliations = data.select('affiliation').unique().to_series().to_list()
topics = data.select('topic').unique().to_series().to_list()

# %%
#how much a politician talked about all the possible topics (politicianTopics --> json variable {"topic", "minutes", "interventions"})

n = "Silvio Berlusconi"

x = data.filter(pl.col("fullname") == n)
politicianTopics = []

for t in topics:
  y = x.filter(pl.col("topic") == t)
  sum = y.select("duration").sum().to_series().to_list()
  politicianTopics.append({"topic": t, "minutes" : sum, "interventions" : y.shape[0]})


#how much a political group talked about all the possible topics (polGroupTopics --> json variable {"topic", "minutes", "interventions"})

m = "Azione-Italia Viva-Renew Europe"

w = data.filter(pl.col("lastname") == m)
polGroupTopics = []

for t in topics:
  z = w.filter(pl.col("topic") == t)
  sum = z.select("duration").sum().to_series().to_list()
  polGroupTopics.append({"topic": t, "minutes" : sum, "interventions" : z.shape[0]})

# %%
#how much a politician talked in a specific channel (politicianChannels --> json variable {"channel", "minutes", "interventions"})

n = "Silvio Berlusconi"

x = data.filter(pl.col("fullname") == n)
politicianChannels = []

for c in channels:
  y = x.filter(pl.col("channel") == c)
  sum = y.select("duration").sum().to_series().to_list()
  politicianChannels.append({"channel": c, "minutes" : sum, "interventions" : y.shape[0]})


#how much a political group talked about all the possible topics (polGroupTopics --> json variable {"topic", "minutes", "interventions"})

m = "Azione-Italia Viva-Renew Europe"

w = data.filter(pl.col("lastname") == m)
polGroupChannels = []

for c in channels:
  z = w.filter(pl.col("channel") == c)
  sum = z.select("duration").sum().to_series().to_list()
  polGroupChannels.append({"channel": c, "minutes" : sum, "interventions" : z.shape[0]})

# %%
#how many politicians participate (have participated) in every political group (politiciansAffiliation --> json variable {"affiliation", "politicians"[] })

politiciansAffiliation = []
y = data.filter(pl.col("name") != "political movement")

for a in affiliations:
  x = y.filter(pl.col("affiliation") == a)
  politiciansAffiliation.append({"affiliation": a, "politicians": x.select('fullname').unique().to_series().to_list()})

# %%
#how much a political group has intervened in tv (interventionsPoliticalGroup --> json variable {"affiliation", "interventions", "minutes"})

interventionsPoliticalGroup = []

for a in affiliations:
  x = data.filter(pl.col("affiliation") == a)
  sum = x.select("duration").sum().to_series().to_list()
  interventionsPoliticalGroup.append({"affiliation": a, "interventions": x.shape[0], "minutes": sum})

# %%
#how many political groups a politician have participated in (politicianPoliticalGroups[])

n = "Matteo Renzi"

x = data.filter(pl.col("fullname") == n)

politicianPoliticalGroups = x.select('affiliation').unique().to_series().to_list()

# %%
name = "Silvio Berlusconi"
politicians = data.filter(pl.col("name") != "political movement")

politician_channels = politicians.filter(pl.col('fullname') == name)
x = []

for c in channels:
    singleChannel = politician_channels.filter(pl.col('channel') == c)
    programsChannel = singleChannel.select('program').unique().to_series().to_list()
    arr = []
    for p in programsChannel:
        temp2 = singleChannel.filter(pl.col('program') == p)
        p1 = temp2.select('program').unique().to_series().to_list()
        total = temp2.select('duration').sum().to_series().to_list()
        arr.append({'program': p1[0], 'minutes': total[0]})
    x.append({'channel': singleChannel.select('channel').unique().to_series().to_list()[0], 'programs': arr})

final_list = {'politician': name, 'channels': x}

# %%
name = "Silvio Berlusconi"
channel = "RETE 4"


min_date = "2019/01/01"
max_date = "2022/01/01"
min_year = int(min_date.split('/')[0])
max_year = int(max_date.split('/')[0])

all_programs_channel = data.filter(pl.col('channel') == channel)
programs_channel = all_programs_channel.select('program').unique().to_series().to_list()
programs_channel.sort()

final_programs = []

for prog in programs_channel:
    temp_prgrm = {}
    temp_prgrm["program"] = prog
    temp = all_programs_channel.filter(pl.col('program') == prog)
    temp = temp.filter(pl.col('fullname') == name)
    data = {}
    m_y = 2019
    x_y = 2022
    while m_y != (x_y + 1):
        fy = datetime.strptime(str(min_year), '%Y')
        ly = datetime.strptime(str(min_year + 1), '%Y')
        a = temp.filter(pl.col('day') >= fy)
        a = a.filter(pl.col('day') <= ly)
        data[m_y] = a.select('duration').sum().to_series().to_list()[0]
        m_y += 1
    temp_prgrm["data"] = data
    final_programs.append(temp_prgrm)
